# %%
import pandas as pd
import numpy as np
import pickle
import time 
import os
from datetime import datetime
from operator import itemgetter

# 目前的这些文件路径都是之前用绝对路径写的，以后有时间了一定要改成相对路径
data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
daily_path =  "C:\\Users\\goodluck\\Desktop\\DB\\daily"

# 这个是DTBS.pkl的文件地址
DTBS_path = os.path.join(storage_path, "DTBS.pkl")


# re-open，读取DTBS.pkl存放到DTBS中
with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)
    
from WindPy import w
w.start()

# 更新主体评级的日期（按季度） 2023-03
time = '2023-03'
date = '2023-03-01'

w.start()

'''
for stock_code, information in DTBS['F'].items():
    # 获取某只股票（可转债）在date日期下的评级
    Wind_ZhuTiPingJi = w.wsd(stock_code, "latestissurercreditrating", date, date, "").Data
    print(Wind_ZhuTiPingJi)
    DTBS['F'][stock_code][time]['ztpj'] = Wind_ZhuTiPingJi[0][0]


# 将DTBS的F区的键取出，即取出所有的正股代码，并将其都存到一个列表stock_codes
stock_codes = list(DTBS['F'].keys())
print(stock_codes)

# 调用wind接口，获取正股对应的主体评级，传入一个列表stock_codes，传出数据格式为：[[主体评级1,主体评级2,...]]
Wind_ZhuTiPingJi = w.wsd(stock_codes, "latestissurercreditrating", date, date, "").Data
print(Wind_ZhuTiPingJi)

# 对DTBS的F区增加主体评级
for i in range(len(stock_codes)):
    DTBS['F'][stock_codes[i]][time]['ztpj'] = Wind_ZhuTiPingJi[0][i]
'''

print(DTBS['A']['113545.SH']['2023-07-06'])
print(DTBS['F'])
# Out:
# {'cpr': 41.02, 'dp': 115.56, 'dl': 156.58, 'ytm': -0.88, 'bl': 9.865, 'trt': 0.61, 'yl': 2.277, 'csp': 10.08, 'ia': 1, 'xx': 0, 'hs': 0, 'csv': 81.94444444444444, 'qs': 0, 'qs15': 0, 'qs30': 0}
# ...
