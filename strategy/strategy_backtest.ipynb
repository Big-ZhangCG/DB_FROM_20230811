# %%
# set up
import pandas as pd
import numpy as np
import pickle
import time 
import os
import matplotlib.pyplot as plt
import datetime
from operator import itemgetter
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from pylab import *
from matplotlib.font_manager import FontProperties  
data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")
font = FontProperties(fname=r"simsun.ttf", size=14)  
matplotlib.rcParams['axes.unicode_minus'] =False
mpl.rcParams['font.sans-serif'] = ['SimHei']
tick_spacing = 10

# re-open
with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)

# %%
# helper -- days
def select_days(s_d, e_d, wkd, gap):
    days = []
    flag = 0
    sdt = datetime.datetime.strptime(s_d, '%Y-%m-%d').date()
    edt = datetime.datetime.strptime(e_d, '%Y-%m-%d').date()
    for day in DTBS['D']['day']:
        cdt =  datetime.datetime.strptime(day, '%Y-%m-%d').date()
        if cdt >= sdt:
            flag = 1
        
        if cdt == edt:
            days.append(day)
            break
        
        if cdt > edt:
            break 
            
        if flag == 1:
            days.append(day)
            
    s_days = []
    count = 0
    for day in days:
        if day in DTBS['D'][wkd]:
            if count % gap == 0:
                s_days.append(day)
                
            count += 1
    
    
    return s_days

f20wm = select_days('2020-01-01', '2020-06-30', 'mon', 1)
f20fm = select_days('2020-01-01', '2020-06-30', 'mon', 2)
f20mm = select_days('2020-01-01', '2020-06-30', 'mon', 4)
s20wm = select_days('2020-07-01', '2020-12-31', 'mon', 1)
s20fm = select_days('2020-07-01', '2020-12-31', 'mon', 2)
s20mm = select_days('2020-07-01', '2020-12-31', 'mon', 4)
f21wm = select_days('2021-01-01', '2021-06-30', 'mon', 1)
f21fm = select_days('2021-01-01', '2021-06-30', 'mon', 2)
f21mm = select_days('2021-01-01', '2021-06-30', 'mon', 4)
s21wm = select_days('2021-07-01', '2021-12-31', 'mon', 1)
s21fm = select_days('2021-07-01', '2021-12-31', 'mon', 2)
s21mm = select_days('2021-07-01', '2021-12-31', 'mon', 4)
f22wm = select_days('2022-01-01', '2022-06-30', 'mon', 1)
f22fm = select_days('2022-01-01', '2022-06-30', 'mon', 2)
f22mm = select_days('2022-01-01', '2022-06-30', 'mon', 4)
s22wm = select_days('2022-07-01', '2022-12-31', 'mon', 1)
s22ww = select_days('2022-07-01', '2022-12-31', 'wed', 1)
s22fm = select_days('2022-07-01', '2022-12-31', 'mon', 2)
s22mm = select_days('2022-07-01', '2022-12-31', 'mon', 4)
f23wm = select_days('2023-01-01', '2023-06-26', 'mon', 1)
f23wt = select_days('2023-01-01', '2023-06-26', 'tue', 1)
f23ww = select_days('2023-01-01', '2023-06-26', 'wed', 1)
f23wh = select_days('2023-01-01', '2023-06-26', 'thu', 1)
f23wf = select_days('2023-01-01', '2023-06-26', 'fri', 1)
f23fm = select_days('2023-01-01', '2023-06-26', 'mon', 2)
f23mm = select_days('2023-01-01', '2023-06-26', 'mon', 4)
f23ww = select_days('2023-01-01', '2023-06-26', 'wed', 1)
f23mm.append('2023-04-10')
a20wm = select_days('2020-01-01', '2020-12-31', 'mon', 1)
a20fm = select_days('2020-01-01', '2020-12-31', 'mon', 2)
a20mm = select_days('2020-01-01', '2020-12-31', 'mon', 4)
a21wm = select_days('2021-01-01', '2021-12-31', 'mon', 1)
a21fm = select_days('2021-01-01', '2021-12-31', 'mon', 2)
a21mm = select_days('2021-01-01', '2021-12-31', 'mon', 4)
a22wm = select_days('2022-01-01', '2022-12-31', 'mon', 1)
a22fm = select_days('2022-01-01', '2022-12-31', 'mon', 2)
a22mm = select_days('2022-01-01', '2022-12-31', 'mon', 4)

a22wm = select_days('2022-01-01', '2022-12-31', 'mon', 1)
a22wt = select_days('2022-01-01', '2022-12-31', 'tue', 1)
a22ww = select_days('2022-01-01', '2022-12-31', 'wed', 1)
a22wh = select_days('2022-01-01', '2022-12-31', 'thu', 1)
a22wf = select_days('2022-01-01', '2022-12-31', 'fri', 1)



hywm = [f20wm, s20wm, f21wm, s21wm, f22wm, s22ww, f23ww]
hyfm = [f20fm, s20fm, f21fm, s21fm, f22fm, s22fm, f23fm]
hymm = [f20mm, s20mm, f21mm, s21mm, f22mm, s22mm, f23mm]
test = ['2023-04-12','2023-04-19']

# %%
# helper -- others

# 夏普比率
def sharpe(profit):
    avg_rate = np.mean(profit)
    std_rate = np.std(profit)
    Sharpe_Ratio = (avg_rate * 52 -0.028397) / (std_rate * sqrt(52))
    return(Sharpe_Ratio)

# 最大回撤
def down(profit):
    return_list = [i+1 for i in profit]
    i = np.argmax((np.maximum.accumulate(return_list) - return_list))
    if i == 0:
        return 0
    j = np.argmax(return_list[:i])  # 开始位置
    drawdown_rate = (return_list[j] - return_list[i]) / return_list[j]
    return drawdown_rate

# 年化波动率
def vola(profit):
    log_return_list = [log(i+1) for i in profit]
    Volatility = std(log_return_list) / sqrt(5)
    annualVolatility = Volatility * sqrt(252) 
    return annualVolatility


def select_group(nm, dt, codes, grp):
    select = []
    if nm == 'id':
        for code in codes:
            if DTBS['B'][code]['yqq'] == grp:
                select.append(code)
    elif nm == 'pr':
        for code in codes:
            if DTBS['A'][code][dt]['dp'] >= grp[0] and DTBS['A'][code][dt]['dp'] <= grp[1]:
                select.append(code)
                
    else:
        for code in codes:
            if DTBS['B'][code]['cat1']  == grp[0]:
                if DTBS['A'][code][dt]['dp'] >= grp[1][0] and DTBS['A'][code][dt]['dp'] <= grp[1][1]:
                    select.append(code)
    return select


def transform_group(grps):
    if len(grps) == 1:
        return grps[0]
    else:
        grp = ['idpr', []]
        for cd1 in grps[0][1]:
            for cd2 in grps[1][1]:
                grp[1].append((cd1, cd2))
        
        return grp
    
def ipo(codes, dt):
    exist = []
    for code in codes:
        if datetime.datetime.strptime(DTBS['B'][code]['ipo'], '%Y-%m-%d') >= (datetime.datetime.strptime(dt, '%Y-%m-%d') + datetime.timedelta(days=-180)):
            exist.append(code)
             
    return exist
    
def select_existing(dt):
    exist = []
    for code in DTBS['A'].keys():
        if DTBS['A'][code][dt]['ia'] == 1:
            if DTBS['B'][code]['sn'][:2] != 'st' and DTBS['B'][code]['sn'][:2] != 'ST' and DTBS['B'][code]['sn'][:3] != '*st' and DTBS['B'][code]['sn'][:3] != '*ST':
                if DTBS['A'][code][dt]['yl'] >= 0.5:
                    exist.append(code)
            
    return exist

def get_prcs(code, dts):
    prc = []
    for dt in dts:
        prc.append(DTBS['A'][code][dt]['dp'])
    prc.sort()
    return prc
    
def relative_low(lst, pos):
    return np.quantile(a=lst, q = pos)
    
def absolute_low(lst, pos):
    return min(lst) + pos * (max(lst) - min(lst))

def low_prc(code, dt, lm, pos):
    prc = get_prcs(code, lm)
#     lp = min([relative_low(prc, pos), absolute_low(prc, pos)])
    lp = absolute_low(prc, pos)
    tp = DTBS['A'][code][dt]['dp']
#     if (tp <= lp):
#         print(code, tp, lp)
#     if tp <= lp:
#         print(tp, lp)
    return tp <= lp

def calculate_time(dt, d, l):
    time = []
    days = DTBS['D']['day']
    if d == 'p':
        for i in range(len(days)):
            if days[i] == dt:
                break
                
    return days[i-l+1:i+1]
            
def select_condition(codes, dt, fcd):
    satisfy = []
    if fcd[0] == 'lp':
        lm = calculate_time(dt, 'p', 20)
        
        for code in codes:
            if low_prc(code, dt, lm, fcd[1]):
                satisfy.append(code)
    elif len(fcd) == 1:
        return ipo(codes, dt)
        
    else:
        for code in codes:
            if DTBS['A'][code][dt][fcd[0]] <= fcd[2] and DTBS['A'][code][dt][fcd[0]] >= fcd[1]:
                satisfy.append(code)
                    
    return satisfy

def takeSecond(elem):
    return elem[1]

def takeThird(elem):
    return elem[2]
def takeSeventh(elem):
    return elem[6]

def retrieve_low_nodes(codes,dt,num):
    dl_rank = []
    for code in codes:
        if DTBS['A'][code][dt]['dl'] != 999:
            dl_rank.append((code, DTBS['A'][code][dt]['dl']))
    
    dl_rank.sort(key=takeSecond)
    low = dl_rank[0:num]
    return [i[0] for i in low]

def rank(codes, dt, idx, num, d):
    
    rk = []
    if num == -1:
        num = len(codes)
    for code in codes:
        if idx == 'lp':
            if not np.isnan(DTBS['A'][code][dt]['dp']):
                lm = calculate_time(dt, 'p', 20)
                prc = get_prcs(code, lm)
                lp = absolute_low(prc, 0)
                rk.append((code, DTBS['A'][code][dt]['dp']/lp))
            
            
        elif idx != 'dl':
            if not np.isnan(DTBS['A'][code][dt][idx]):
                rk.append((code, DTBS['A'][code][dt][idx]))
        else:
            if not np.isnan(DTBS['A'][code][dt][idx]):
                if DTBS['A'][code][dt][idx] != 999:
                    rk.append((code, DTBS['A'][code][dt][idx]))
    if num >= len(rk):
        num = len(rk)
        
     
#     reverse = True 降序
    if d == 'd':
        rk.sort(key=takeSecond, reverse = True)
    else:
        rk.sort(key=takeSecond, reverse = False)

    if idx == 'lp':
        lp = [i for i in rk if i[1] == 1.0]
        ot = []
        if num - len(lp) > 0:
            ot = rk[len(lp):num]
        
        low = lp + ot
        
    else:    
        low = rk[0:num]
#     print("In",dt , len(low), "of", len(codes),  "is selected")   

#     print(low)
    
    
    return [i[0] for i in low]
        
    
idts = [['农林牧渔(2021)', '基础化工(2021)', '美容护理(2021)', '通信(2021)', '非银金融(2021)', '电力设备(2021)', '汽车(2021)', '电子(2021)'], ['家用电器(2021)', '基础化工(2021)', '建筑材料(2021)', '建筑装饰(2021)', '机械设备(2021)', '商贸零售(2021)', '计算机(2021)', '国防军工(2021)', '钢铁(2021)', '传媒(2021)'], ['汽车(2021)', '交通运输(2021)', '农林牧渔(2021)', '煤炭(2021)', '有色金属(2021)', '商贸零售(2021)', '机械设备(2021)', '钢铁(2021)', '电力设备(2021)', '基础化工(2021)'], ['电力设备(2021)', '有色金属(2021)', '交通运输(2021)', '钢铁(2021)', '通信(2021)', '汽车(2021)', '基础化工(2021)', '轻工制造(2021)', '国防军工(2021)', '医药生物(2021)'], ['有色金属(2021)', '机械社保(2021)', '基础化工(2021)', '农林牧渔(2021)', '汽车(2021)', '交通运输(2021)', '国防军工(2021)', '医药生物(2021)', '通信(2021)', '电力设备(2021)'], ['有色金属(2021)', '农林牧渔(2021)', '汽车(2021)', '电力设备(2021)', '公用事业(2021)', '社会服务(2021)', '食品饮料(2021)', '医药生物(2021)', '轻工制造(2021)', '建筑材料(2021)'], ['建筑材料(2021)', '建筑装饰(2021)', '国防军工(2021)', '计算机(2021)', '通信(2021)', '食品饮料(2021)', '社会服务(2021)', '纺织服饰(2021)', '交通运输(2021)', '轻工制造(2021)']]

# %%
# plot

def plot_profit(days, profit, mk_one, market = DTBS['C'], tt = '收益率'):
    plt.figure(figsize=(80,60))
    

        
    fig, ax = plt.subplots(1,1)
#     plt.plot(days[1:], one_profit, linestyle='dashdot',label='价格110-130+50%低价+市值<3+转股溢价率<50:低价前5')
    plt.plot(days[1:], profit, linestyle='dashdot',label='策略收益率')
    
    i_x = [days[1], days[-1]]

#     market_gain = (market['zi'][days[-1]]-market['zi'][days[0]])/(market['zi'][days[0]])
#     i_y = [0, market_gain]
#     plt.plot(i_x, i_y, linestyle='solid',label='中正转债指数')
    plt.plot(days[1:], mk_one, linestyle='solid',label='中证转债指数')
    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
    plt.ylabel('Increase per year/%')

    # 'dashed'
    #‘dotted'
    # 'dashdot'
    # 'solid'

    
    plt.legend(fontsize = 'x-small')

    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
#     plt.ylabel('收益率/%')
    plt.ylabel("increase per year/%")
#     tt = '收益率'
    plt.title(tt)
    plt.savefig(tt, dpi=300)
#     plt.show()
#     print("Final gain", profit[-1], ',',"Market gain", market_gain)

# statistics

# 胜率 跟市场比
def win_stat(res, mk):
    print("Max profit", max(res), ", Max loss", min(res))
    wins = []
    win = 0
    count = 0
    winm = 0
    winsm  = []
    summ = 0
    mksum = 0    
    for i in range(len(res)):
        # 如果要跟0比,那就把mk[i]换成0,mk[i]代表当时的指数表现
        if res[i] >= mk[i]:
            win += 1
            wins.append(True)
        else:
            wins.append(False)
        
        summ += res[i]
        mksum += mk[i]
        if (count + 1) % 4 == 0:
            if summ >= mksum:
                winm += 1
                winsm.append(True)
            else:
                winsm.append(False)
                
            summ = 0
            mksum = 0
            
        count += 1
    win_rate = win/len(res)
    winm_rate = winm/len(winsm)
    print("Weekly win rate & details", win_rate, ", ", wins)
    print("Monthly win rate & details", winm_rate,", ", winsm)

def avoid(dt):
    return False
    c = []
    for code in DTBS['A'].keys():
        if DTBS['A'][code][dt]['ia'] == 1:
#             if DTBS['A'][code][dt]['dp'] >= 120 and DTBS['A'][code][dt]['dp'] <= 130:
            if DTBS['A'][code][dt]['pd'] >= -20 and  DTBS['A'][code][dt]['pd'] <= 20:
                if not np.isnan(DTBS['A'][code][dt]['ytm']):
                    c.append(DTBS['A'][code][dt]['ytm'] )
#                 c.append(DTBS['A'][code][dt]['cpr'] + DTBS['A'][code][dt]['dp'])
                
    m = np.mean(c)
    
#     return m < -4

    return m


# def heat(dt, idt):
#     return False
    
#     for cd in DTBS['A'].keys:
#         p = []
#         if DTBS['B'][]

# 需要一个一段时间前，比如一个月前，一周前，自动计算

# %%
def market_median(dt):
    pl = []
    for cd in DTBS['A'].keys():
        if DTBS['A'][cd][dt]['ia'] == 1:
            pl.append(DTBS['A'][cd][dt]['dp'])
    
    m2 = np.median(pl)
    m1 = m2-5
    m3 = m2+5
    return m1,m2,m3

def market_median_a(dt, r):
    pl = []
    idx = DTBS['D']['day'].index(dt)
    for oid in range(idx-r+1,idx+1):
        dd = DTBS['D']['day'][oid]
        itm = []
        for cd in DTBS['A'].keys():
            if DTBS['A'][cd][dd]['ia'] == 1:
                itm.append(DTBS['A'][cd][dd]['dp'])
        pl.append(np.median(itm))
#     print(len(pl))
    m2 = np.mean(pl)
    m1 = m2-5
    m3 = m2+5
    return m1,m2,min(m3,130)

# %%
# calculate
def cumulative_profit(days, grp_cd, flt_cd, rk_cd):
    cm_profit = []
    one_profit = []
    all_select = []
    sum_profit = 0
    id_count = 0
    lock = False
    second_check = False
    
    # 中位置 += 5

    
    for i in range(len(days)): 
#         if i >= 1: 
#             m1,m2,m3 = market_median(days[i-1])
#         else:
#             m1,m2,m3 = market_median(days[i])
        m1,m2,m3 = market_median_a(days[i],20)    
        if i+1 == len(days):
            exist = select_existing(days[i])
            
            
        else: 
            exist_tr = select_existing(days[i])
            exist_nr = select_existing(days[i+1])
            exist =list(set(exist_tr).intersection(set(exist_nr)))
    
        select = exist.copy()
        candidate = []
        if grp_cd != []:
            grp = transform_group(grp_cd)
            
            # 忘了这里要干嘛 但不对
            # 一段回测内换行业，注意数据要对上     
#             if len(grp[1]) != 1:
#                 grp_c = grp[1][id_count].copy()
#                 id_count += 1
#             else:
            grp_c = grp[1].copy()
#             print(grp[1])
#             print(grp_c)
            ccc = 0
            grp_c = [[m1, m2], [m2, m3]]
            print(days[i], grp_c)
            for g in grp_c:
                select = exist.copy()
                select = select_group(grp[0], days[i], select, g)
             
                for fcd in flt_cd:
                    select = select_condition(select, days[i], fcd)
                for rk in rk_cd:
                    if ccc == 0:
                        select = rank(select, days[i], rk[0], rk[1]-0, rk[2])     
                    elif ccc == 1:
                        select = rank(select, days[i], rk[0], rk[1]+0, rk[2])    
                for cd in select:
                    candidate.append(cd)
                ccc+=1    
            # 一段回测内换行业 
#             print(days[i],grp_c)

                            

        
        else: 
            for fcd in flt_cd:
                select = select_condition(select, days[i], fcd)
            for rk in rk_cd:
                select = rank(select, days[i], rk[0], rk[1], rk[2])    
#             if dl > 0:
#                 select = retrieve_low_nodes(select, days[i], dl)
                
            candidate = select.copy()    
        
        
        if avoid(days[i]) != False and avoid(days[i]) <-3.68:
            lock = True
        

            
        if lock == True and avoid(days[i]) >- 2.9:
            lock = False
            
        if lock == True:
            candidate = []
        
        # 双低用,不然改成false
        second_check = True
        # 取市场前50%双低
        if second_check:
            candidate_sc = rank(exist, days[i], 'dl', len(exist)//2, 'a')
        
            candidate_new = [i for i in candidate if i in candidate_sc]
            candidate = candidate_new.copy()
#         if len(candidate) != 5: print(days[i], len(candidate))
#         print(days[i], len(candidate))
        all_select.append(candidate)
    
#         print(dt)
#         for cd in candidate:
#             print(DTBS['A'][cd][days[i]]['dp'])


#         print(days[i])
#         for cccc in candidate:
#             print(cccc, DTBS['B'][cccc]['cn'])
        
#         dl = []
#         for cd in candidate:
#             dl.append(DTBS['A'][cd][days[i]]['dl'])
#         for cd in candidate:
#             dl.append(DTBS['A'][cd][days[i]]['dp'])
            
#         for cd in candidate:
#             dl.append(DTBS['A'][cd][days[i]]['bl'])
#         print(days[i], candidate, dl)
        dl = []
        if i >= 1:
        
            tr = 0
            lr = 0

            for cd in all_select[i-1]:
                tr += DTBS['A'][cd][days[i]]['dp']
                lr += DTBS['A'][cd][days[i-1]]['dp']
                
            if len(all_select[i-1]) == 0:
                profit = 0
                print("short position in", days[i-1])
            else:
                profit = ((tr - lr)/ lr)
            one_profit.append(profit)

            sum_profit += profit

                
            cm_profit.append(sum_profit)
                                                                                                                

    return cm_profit, one_profit

# %%
tick_spacing = 4



tts = ['2020年上半年收益率',  '2020年下半年收益率', '2021年上半年收益率', '2021年下半年收益率','2022年上半年收益率', '2022年下半年收益率','2023年上半年收益率']



tts = ['2021年上半年收益率', '2021年下半年收益率','2022年上半年收益率', '2022年下半年收益率','2023年上半年收益率']



tf = [f20fm, s20fm, f21fm, s21fm, f22fm, s22fm, f23fm]
tm = [f20mm, s20mm, f21mm, s21mm, f22mm, s22mm, f23mm]
tw = [f20wm, s20wm, f21wm, s21wm, f22wm, s22wm, f23wm]
twy = [a20wm, a21wm, a22wm, f23wm]

acp = []
grp_cd = []
fil_cd = []
res2 = []
mk = []

tw = [f21wm, s21wm, f22wm, s22wm, f23wm]
tw = [s22wm, f23wm]
tw = [f20wm, s20wm, f21wm, s21wm, f22wm, s22wm, f23wm]
tw = [ f23wm]
tw = [f22wm, s22wm, f23wm]
# print("ytm>-1市值<7换手2-10双低100-130前5 2022年起每半年至今, 限制双低必须在当天市场前25%")
for i in range(len(tw)):
#     prlst = [[110,120], [120,130]] 



    prlst = [[115,120], [120,130]] 
    prlst = [[115,122.5], [122.5,130]]     


    
    prlst = [[115,120], [120,125]]      
    
    prlst = [[116,121], [121,126]]  
    prlst = [[110,120], [120,130]] 

    grp_cd = [['pr', prlst]]
    
    grp_cd = []
        
    fil_cd = [['dp',100,130]]
    
    fil_cd = [['dp',110,130],['ytm', -1, 999], ['bl', 0, 7], ['trt',2,10]]
    


    rk_cd = [['ytm', 5, 'd']]  
    
    rk_cd = [['dl', 3, 'a']]
    mk_one = []
    
    time = tw[i].copy()
    for k in range(1,len(time)):
        mk_one.append((DTBS['C']['zi'][time[k]]-DTBS['C']['zi'][time[k-1]])/(DTBS['C']['zi'][time[k-1]]))
        
    cm_profit, one_profit = cumulative_profit(time, grp_cd, fil_cd, rk_cd)
    win_stat(one_profit, mk_one)
    plot_profit(time, cm_profit, mk_one, tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'累计收益率')
    plot_profit(time, one_profit,mk_one, tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'单周收益率')
    
    res2.append(one_profit)
    mk.append(mk_one)
    acp.append(cm_profit[-1])
#     print(len(acp), i, acp)
    print(str(round(acp[i]*100,4)) + '%')
    print('sharpe', sharpe(one_profit))
#     with open('log.txt','a') as f:
#         print(cm_profit[-1], file=f)

# for i in range(7):
#     print(str(round(acp[i]*100,4)) + '%')
# Out:
# Max profit 0.15779718007403015 , Max loss -0.041719095887219025
# Weekly win rate & details 0.6190476190476191 ,  [True, False, False, True, True, True, True, False, True, False, True, True, False, True, False, True, True, False, True, True, False]
# Monthly win rate & details 1.0 ,  [True, True, True, True, True]
# 25.0953%
# sharpe 2.0528089761925896
# Max profit 0.06327008865548589 , Max loss -0.03555688616294184
# Weekly win rate & details 0.6956521739130435 ,  [False, True, True, True, False, True, True, True, True, False, True, True, True, True, False, True, True, True, False, True, False, False, True]
# Monthly win rate & details 0.8 ,  [True, True, False, True, True]
# 6.7472%
# sharpe 0.6830224227354793
# Max profit 0.026658952334327145 , Max loss -0.030040006812046285
# Weekly win rate & details 0.45454545454545453 ,  [False, True, True, True, False, False, False, True, False, True, False, False, False, False, False, False, True, True, False, True, True, True]
# Monthly win rate & details 0.4 ,  [True, False, False, False, True]
# 6.9533%
# sharpe 1.3122731426084835

# %%
yqqhcday = select_days('2023-01-01', '2023-05-17', 'fri', 1)
# yqqhcday = select_days('2023-01-01', '2023-05-14', 'mon', 1)
idts = [['能源','金融'],['消费','金融'],['环保'],['农业','环保','能源'],['农业','环保'],[],['能源','金融'],['金融','投资'],[],['农业'],['农业','金融'],[],['基建','金融','能源'],['能源','金融'],[],['能源','金融'],['金融'],[]]
tick_spacing = 2
time = yqqhcday.copy()


grp_cd = [['id',idts]]

fil_cd = [['dp',100,130]]
rk_cd = [['dl', 3, 'a']]
# rk_cd = [['ytm', 3, 'd']]
# fil_cd = [['dp',100,130],['ytm', 0.5, 999], ['bl', 0, 7], ['trt',2,10]]
    
mk_one = []
    

for k in range(1,len(time)):
    mk_one.append((DTBS['C']['zi'][time[k]]-DTBS['C']['zi'][time[k-1]])/(DTBS['C']['zi'][time[k-1]]))
        
cm_profit, one_profit = cumulative_profit(time, grp_cd, fil_cd, rk_cd)
win_stat(one_profit, mk_one)
plot_profit(time, cm_profit, mk_one, tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'累计收益率')
plot_profit(time, one_profit,mk_one, tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'单周收益率')
    

print(str(round(cm_profit[-1]*100,4)) + '%')
print('sharpe', round(sharpe(one_profit),2))
# Out:
# 2023-01-06 [[113.067875, 118.067875], [118.067875, 123.067875]]
# 2023-01-13 [[112.862425, 117.862425], [117.862425, 122.862425]]
# short position in 2023-01-06
# 2023-01-20 [[114.06177500000001, 119.06177500000001], [119.06177500000001, 124.06177500000001]]
# short position in 2023-01-13
# 2023-02-03 [[115.90259999999998, 120.90259999999998], [120.90259999999998, 125.90259999999998]]
# short position in 2023-01-20
# 2023-02-10 [[117.30170000000003, 122.30170000000003], [122.30170000000003, 127.30170000000003]]
# short position in 2023-02-03
# 2023-02-17 [[118.39782500000001, 123.39782500000001], [123.39782500000001, 128.397825]]
# short position in 2023-02-10
# 2023-02-24 [[118.769675, 123.769675], [123.769675, 128.769675]]
# short position in 2023-02-17
# 2023-03-03 [[118.619675, 123.619675], [123.619675, 128.619675]]
# short position in 2023-02-24
# 2023-03-10 [[118.45400000000002, 123.45400000000002], [123.45400000000002, 128.454]]
# short position in 2023-03-03
# 2023-03-17 [[117.85435, 122.85435], [122.85435, 127.85435]]
# short position in 2023-03-10
# 2023-03-24 [[117.70972499999998, 122.70972499999998], [122.70972499999998, 127.70972499999998]]
# short position in 2023-03-17
# 2023-03-31 [[117.49690000000001, 122.49690000000001], [122.49690000000001, 127.49690000000001]]
# short position in 2023-03-24
# 2023-04-07 [[117.62180000000001, 122.62180000000001], [122.62180000000001, 127.62180000000001]]
# short position in 2023-03-31
# 2023-04-14 [[118.15277499999999, 123.15277499999999], [123.15277499999999, 128.152775]]
# short position in 2023-04-07
# 2023-04-21 [[118.335075, 123.335075], [123.335075, 128.33507500000002]]
# short position in 2023-04-14
# 2023-04-28 [[117.76579999999998, 122.76579999999998], [122.76579999999998, 127.76579999999998]]
# short position in 2023-04-21
# 2023-05-05 [[117.50085000000001, 122.50085000000001], [122.50085000000001, 127.50085000000001]]
# short position in 2023-04-28
# 2023-05-12 [[116.39102499999998, 121.39102499999998], [121.39102499999998, 126.39102499999998]]
# short position in 2023-05-05
# Max profit 0 , Max loss 0
# Weekly win rate & details 0.35294117647058826 ,  [False, False, False, True, True, False, False, True, False, False, False, False, False, True, False, True, True]
# Monthly win rate & details 0.5 ,  [False, True, False, True]
# 0%
# sharpe -inf
# C:\Users\goodluck\AppData\Local\Temp\ipykernel_17928\1732823578.py:7: RuntimeWarning: divide by zero encountered in double_scalars
#   Sharpe_Ratio = (avg_rate * 52 -0.028397) / (std_rate * sqrt(52))

# %%
prlst = [[110,120], [120,130]]
prlst = [[110,120], [120,130], [130,140]]
# grp_cd = [['id', idlst], ['pr', prlst]]
# grp_cd = [['id', idlst]]
# grp_cd = [['pr', prlst]]
grp_cd = []
fil_cd = []
fil_cd = [['bl',0.3,7]]
fil_cd = []
dl = 0



tts = ['2020年上半年收益率',  '2020年下半年收益率', '2021年上半年收益率', '2021年下半年收益率','2022年上半年收益率', '2022年下半年收益率','2023年上半年收益率']



fil_cd = [['dp', 100, 9999], ['ytm', 1, 1000], ['trt', 2, 10]]







tf = [f20fm, s20fm, f21fm, s21fm, f22fm, s22fm, f23fm]
tm = [f20mm, s20mm, f21mm, s21mm, f22mm, s22mm, f23mm]
tw = [f20wm, s20wm, f21wm, s21wm, f22wm, s22wm, f23wm]
twy = [a20wm, a21wm, a22wm, f23wm]
# tw = [f22wm, s22wm, f23wm]
acp = []
grp_cd = []
fil_cd = []
# res1 = []
res2 = []
mk = []
# print("ytm>-1市值<7换手2-10双低100-130前5 2022年起每半年至今, 限制双低必须在当天市场前25%")
# print("ytm>-1市值<7换手2-10双低100-130前5 2022年起每半年至今, 不限制双低排名")
for i in range(len(tw)):
#     grp_cd = [['id', idts[i]], ['pr', prlst]]
    


    prlst = [[110,120], [120,130], [130,140]]
    prlst = [[110,120], [120,130]]
    prlst = [[110,130]]   

    grp_cd = [['pr', prlst]]
    grp_cd = []
#     fil_cd = [['dp', 100, 9999],['ytm', 0.5, 9999], ['bl', 0.3, 7], ['trt', 2, 10]]

    fil_cd = [['lp',0.5], ['dp',110,130],['bl', 0, 3], ['cpr',-999, 50]]

    fil_cd = [['dp',100,130],['bl', 0, 3]]
    fil_cd = [['cx'],['bl', 0, 7], ['dp',100,130]]


    fil_cd = [['dp',100,130]]
    fil_cd = [['dp',100,130],['ytm', -5, 999], ['bl', 0, 7], ['trt',2,7]]
    fil_cd = [['dp',100,130],['ytm', -1, 999], ['bl', 0, 7], ['trt',2,10]]
    fil_cd = [['dp',100,130]]
#     rk_cd = [['dl', 5, 'a']]
#     rk_cd = [['lp', 5, 'a']]

   

    
    rk_cd = [['ytm', 5, 'd']]  
    
    
    rk_cd = [['dl', 5, 'a']]
    mk_one = []
    
    time = tw[i].copy()
    for k in range(1,len(time)):
        mk_one.append((DTBS['C']['zi'][time[k]]-DTBS['C']['zi'][time[k-1]])/(DTBS['C']['zi'][time[k-1]]))
        
    cm_profit, one_profit = cumulative_profit(time, grp_cd, fil_cd, rk_cd)
#     win_stat(one_profit, mk_one)
#     plot_profit(time, cm_profit, mk_one, tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'累计收益率')
#     plot_profit(time, one_profit,mk_one, tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'单周收益率')
    
    res2.append(one_profit)
    mk.append(mk_one)
    acp.append(cm_profit[-1])
#     print(len(acp), i, acp)
    print(str(round(acp[i]*100,4)) + '%')
    print('sharpe', sharpe(one_profit))
#     with open('log.txt','a') as f:
#         print(cm_profit[-1], file=f)

# for i in range(7):
#     print(str(round(acp[i]*100,4)) + '%')
# Out:
# 27.8567%
# sharpe 2.047214899947997
# -5.6996%
# sharpe -0.7748639038429393
# 7.5949%
# sharpe 0.7428816596959483
# 21.868%
# sharpe 3.7534640368347763
# -3.2459%
# sharpe -0.831003243363325
# 0.3559%
# sharpe -0.2374891599836031
# -3.4549%
# sharpe -1.153911711281249

# %%
ttt1 = select_days('2020-01-21', '2022-04-25', 'mon', 1)
ttt2 = select_days('2022-04-20', '2023-04-25', 'mon', 1)
ttt = [ttt1, ttt2]

tw = [f22wm, s22wm, f23wm]
tick_spacing = 8

acp = []
grp_cd = []
fil_cd = []
# res1 = []
res2 = []
mk = []
for i in range(3):
#     grp_cd = [['id', idts[i]], ['pr', prlst]]
    


    prlst = [[110,120], [120,130], [130,140]]
    prlst = [[110,120], [120,130]]
    prlst = [[110,130]]   

    grp_cd = [['pr', prlst]]
    grp_cd = []
#     fil_cd = [['dp', 100, 9999],['ytm', 0.5, 9999], ['bl', 0.3, 7], ['trt', 2, 10]]



    fil_cd = [['dp',100,130],['bl', 0, 3]]


    fil_cd = [['lp',0.5], ['dp',110,130],['bl', 0, 3], ['cpr',-999, 50]]

    fil_cd = [['lp',0.5], ['dp',110,130],['bl', 0, 3], ['cpr',-999, 50]]
    fil_cd = [['dp',100,130], ['bl', 0, 7], ['trt',2,10]]
#     rk_cd = [['dl', 5, 'a']]
#     rk_cd = [['lp', 5, 'a']]‘






    rk_cd = [['ytm', 5, 'd']]
    rk_cd = [['lp', 5, 'a']]
    rk_cd = [['dl', 5, 'a']]
    
    mk_one = []
    mk_sum = []
    time = tw[i].copy()
    mk_s = 0
    for k in range(1,len(time)):
       
        mk_one.append((DTBS['C']['zi'][time[k]]-DTBS['C']['zi'][time[k-1]])/(DTBS['C']['zi'][time[k-1]]))
        mk_s += (DTBS['C']['zi'][time[k]]-DTBS['C']['zi'][time[k-1]])/(DTBS['C']['zi'][time[k-1]])

        mk_sum.append(mk_s)
        
    cm_profit, one_profit = cumulative_profit(time, grp_cd, fil_cd, rk_cd)
#     win_stat(one_profit, mk_one)
    plot_profit(time, cm_profit, one_profit, mk_one, tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'收益率')
    
    res2.append(one_profit)
    mk.append(mk_one)
    acp.append(cm_profit[-1])
    print(str(round(acp[i]*100,4)) + '%')
#     print('-----------------------------------------')
#     print(cm_profit[-1])
#     print(win_stat(one_profit, mk_one))
#     print(max(one_profit), time[one_profit.index(max(one_profit))])
#     print(min(one_profit), time[one_profit.index(min(one_profit))])
    print('sharpe', sharpe(one_profit))
#     print(down(one_profit))
#     print(vola(one_profit))
#     with open('log.txt','a') as f:
#         print(cm_profit[-1], file=f)
# Out:
# 19.5532%
# sharpe 2.54143357990718
# 9.7518%
# sharpe 1.1169116939984571
# 6.2209%
# sharpe 0.9566191456427549

# %%
print(cm_profit[-1])
print(one_profit)
print(mk_sum[-1])
print(mk_one)
# Out:
# 0.062208700093121905
# [0.002215848138360345, 0.0480573799683616, 0.012843434572036287, 0.01658550903397406, -0.002381658795357388, -0.006733402092328763, 0.01609861351034849, -0.020783979893793807, 0.006798949090238938, 0.00800074425527965, 0.010723435852217933, -0.009818951554707312, -0.003827937978693781, -0.03448191217430317, 0.01695583660472608, -0.02340685771513485, 0.015661176695404656, -0.00768844453548824, 0.020491037380864677, 0.0012210012210011581, 0.004587011844544285, -0.008908133334428924]
# 0.003317788077448902
# [0.006466820376717392, 0.015106021022984728, -0.007819943535078214, 0.007154737930445309, -0.009264063840879376, -0.005226644125954071, 0.00886961059130319, -0.010129031040349713, 0.00521539215484776, 0.0004912176976325196, 0.006276078510937655, 0.002904485019145895, 0.0056115997133692735, -0.023410752918792473, 0.01720899680559438, -0.011406224698865416, 0.005156224638556635, -0.008479575283881406, 0.005527874866760768, 0.002194063701804522, 0.001943276018990039, -0.011072375527840496]

# %%
win_stat(one_profit, mk_one)
# Out:
# Max profit 0.0480573799683616 , Max loss -0.03448191217430317
# Weekly win rate & details 0.5909090909090909 ,  [False, True, True, True, True, False, True, False, True, True, True, False, False, False, False, False, True, True, True, False, True, True]
# Monthly win rate & details 0.8 ,  [True, True, True, False, True]

# %%
print(max(one_profit), ttt1[one_profit.index(max(one_profit))])
print(min(one_profit), ttt1[one_profit.index(min(one_profit))])
# Out:
# 0.0480573799683616 2020-02-10
# -0.03448191217430317 2020-05-18

# %%
print(sharpe(one_profit))
print(down(one_profit))
print(vola(one_profit))
# Out:
# 0.9566191456427549
# 0.0787545545885632
# 0.12162125455151637

# %%
def plot_profit_compare(days, res1, res2, mk_one, tt = '收益率'):
    plt.figure(figsize=(80,60))
    

        
    fig, ax = plt.subplots(1,1)
#     plt.plot(days[1:], one_profit, linestyle='dashdot',label='价格110-130+50%低价+市值<3+转股溢价率<50:低价前5')
    plt.plot(days[1:], res1, linestyle='dashed',label='高ytm策略单周表现')
    plt.plot(days[1:], res2, linestyle='dotted',label='双低小市值策略单周表现')    



    plt.plot(days[1:], mk_one, linestyle='solid',label='中证转债指数单周表现')
    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
    plt.ylabel('Increase per year/%')

    # 'dashed'
    #‘dotted'
    # 'dashdot'
    # 'solid'

    
    plt.legend(fontsize = 'x-small')

    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
    plt.ylabel('收益率/%')
#     tt = '收益率'
    plt.title(tt)
    plt.savefig(tt, dpi=300)
#     plt.show()
#     print("Final gain", profit[-1], ',',"Market gain", market_gain)

# %%
tw = [f20wm, s20wm, f21wm, s21wm, f22wm, s22wm, f23wm]
for i in range(7):
    time = tw[i].copy()
    plot_profit_compare(time, res1[i], res2[i], mk[i], tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'收益率')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 4
#       2 for i in range(7):
#       3     time = tw[i].copy()
# ----> 4     plot_profit_compare(time, res1[i], res2[i], mk[i], tt = time[0][:4] + '年' + time[0][5:7] +'月' + '到' + time[-1][5:7] + '月' +'收益率')
#
# IndexError: list index out of range

# %%
sel = 0
al = 0
dt = '2023-04-19'
dt = '2017-12-29'
for code in DTBS['A'].keys():
    if DTBS['A'][code][dt]['ia'] == 1:
        if DTBS['B'][code]['cat1'] == '银行(2021)':
            sel += DTBS['A'][code][dt]['bl']
        elif DTBS['B'][code]['cat1'] == '非银金融(2021)':
            sel += DTBS['A'][code][dt]['bl']
        al += DTBS['A'][code][dt]['bl']
print(sel)
print(al)
print(str(round(sel/al * 100,2)) + '%')
# Out:
# 369.9987
# 854.4572879999998
# 43.3%

# %%
import os,random,time
f=open(os.getcwd()+r"/menu.txt","r",encoding="utf-8")
a=f.readlines()
li=[]
for aa in a:
    li.append(aa.strip())
print("程序正在从列表"+str(li)+"中进行随机选择，请稍后")
time.sleep(1)
print("选择结果为："+random.choice(li))
os.system("pause")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 2
#       1 import os,random,time
# ----> 2 f=open(os.getcwd()+r"/menu.txt","r",encoding="utf-8")
#       3 a=f.readlines()
#       4 li=[]
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\goodluck\\Desktop\\DB\\strategy/menu.txt'

# %%
a = [1,2]
b = [1,3]

# %%
a * b

# %%
codes = list(DTBS['A'].keys())
codes = rank(codes, '2023-04-10', 'ytm', num = -1)
for code in codes:
    print(code, DTBS['B'][code]['cn'],"YTM", DTBS['A'][code][ '2023-04-10']['ytm'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 codes = list(DTBS['A'].keys())
# ----> 2 codes = rank(codes, '2023-04-10', 'ytm', num = -1)
#       3 for code in codes:
#       4     print(code, DTBS['B'][code]['cn'],"YTM", DTBS['A'][code][ '2023-04-10']['ytm'])
#
# TypeError: rank() missing 1 required positional argument: 'd'

# %%
dt = DTBS['D']['day'][-1]

# %%
DTBS['A'].keys()
# Out:
# dict_keys(['110088.SH', '113545.SH', '113631.SH', '123128.SZ', '123156.SZ', '127027.SZ', '127061.SZ', '110047.SH', '110063.SH', '110070.SH', '110087.SH', '110089.SH', '110092.SH', '111001.SH', '111002.SH', '111003.SH', '111007.SH', '111012.SH', '113025.SH', '113027.SH', '113046.SH', '113047.SH', '113058.SH', '113059.SH', '113064.SH', '113534.SH', '113535.SH', '113566.SH', '113591.SH', '113600.SH', '113615.SH', '113621.SH', '113623.SH', '113632.SH', '113636.SH', '113638.SH', '113640.SH', '113641.SH', '113649.SH', '113650.SH', '113653.SH', '113657.SH', '113663.SH', '118000.SH', '118005.SH', '118006.SH', '118008.SH', '118010.SH', '118018.SH', '118020.SH', '118022.SH', '118023.SH', '118028.SH', '118029.SH', '123012.SZ', '123013.SZ', '123031.SZ', '123046.SZ', '123052.SZ', '123057.SZ', '123076.SZ', '123078.SZ', '123085.SZ', '123091.SZ', '123106.SZ', '123118.SZ', '123124.SZ', '123126.SZ', '123129.SZ
SH', '113662.SH', '123011.SZ', '123039.SZ', '123072.SZ', '123075.SZ', '123088.SZ', '123093.SZ', '123154.SZ', '123174.SZ', '127004.SZ', '127007.SZ', '127016.SZ', '127037.SZ', '127050.SZ', '127063.SZ', '127065.SZ', '127069.SZ', '128023.SZ', '128056.SZ', '128075.SZ', '128082.SZ', '128087.SZ', '128090.SZ', '128100.SZ', '110055.SH', '113565.SH', '113584.SH', '113605.SH', '113634.SH', '113647.SH', '113648.SH', '123056.SZ', '123107.SZ', '123133.SZ', '123172.SZ', '127015.SZ' ...

# %%
cats = [ '交通运输(2021)',
 '传媒(2021)',
 '公用事业(2021)',
 '农林牧渔(2021)',
 '医药生物(2021)',
 '商贸零售(2021)',
 '国防军工(2021)',
 '基础化工(2021)',
 '家用电器(2021)',
 '建筑材料(2021)',
 '建筑装饰(2021)',
 '有色金属(2021)',
 '机械设备(2021)',
 '汽车(2021)',
 '煤炭(2021)',
 '环保(2021)',
 '电力设备(2021)',
 '电子(2021)',
 '石油石化(2021)',
 '社会服务(2021)',
 '纺织服饰(2021)',
 '美容护理(2021)',
 '计算机(2021)',
 '轻工制造(2021)',
 '通信(2021)',
 '钢铁(2021)',
 '银行(2021)',
 '非银金融(2021)',
 '食品饮料(2021)']

len(cats)
# Out:
# 29

# %%
# after 2022
# 两个起止日期必须对应调整
# market
market = dict()
start = 1217 # 2022 1月
for cat in cats:
    market[cat] = []
    for dt in DTBS['D']['day'][start:]:
        r = []
        for cd in DTBS['A'].keys():
            if DTBS['B'][cd]['cat1'] == cat and DTBS['A'][cd][dt]['ia'] == 1 and not np.isnan(DTBS['A'][cd][dt]['trt']):
                r.append(DTBS['A'][cd][dt]['trt'])
        if r == []:
            print(cat, dt)
            market[cat].append(0)
        else:       
            market[cat].append(np.mean(r))            
market

# choose
# Out:
# {'交通运输(2021)': [3.1287970542857146,
#   1.7541399274285714,
#   2.2801763137142856,
#   1.2504440602857143,
#   1.9243495174285716,
#   1.7478723295714287,
#   1.1110205957142856,
#   1.9077916179999999,
#   1.567795965714286,
#   1.8086624105714288,
#   1.037452072142857,
#   1.3057383599999999,
#   2.5308755942857144,
#   1.7976441427142855,
#   1.1561113787142858,
#   1.3556816667142857,
#   1.2392781955714285,
#   1.217753849857143,
#   1.347681363,
#   1.4796788832857142,
#   1.6707659202857141,
#   2.460339145,
#   2.7592423,
#   1.8047497585714285,
#   3.0586031455714284,
#   3.570691661714285,
#   2.8872235662857135,
#   1.6105143109999998,
#   1.2450568814285714,
#   1.1950892737142857,
#   1.534107521142857,
#   1.5636272367142856,
#   0.8865544745714286,
#   1.9272183615714287,
#   11.093076735714286,
#   3.746861557142857,
#   34.38873302857143,
#   157.1720156142857,
#   105.46599298571428,
#   63.53453913,
#   22.45007505857143,
#   25.81205520571428,
#   16.247589499999997,
#   41.623186465714284,
#   15.027353281285716,
#   8.765742738285715,
#   7.840223438142858,
#   7.342732465714286,
#   7.373522926571431,
#   3.3140707764285717,
#   3.147855925285714,
#   3.6287805417142858,
#   6.281670568571428,
#   4.826862500000001,
#   2.862975,
#   1.6660375000000003,
#   2.15105,
#   2.3104375,
#   2.0955874999999997,
#   2.1350124999999998,
#   2.3936125,
#   2.2131375,
#   4.9729375000000005,
#   1.6073,
#   1.2397125,
#   2.478025,
#   1.8069250000000001,
#   3.9832875000000003,
#   1.67,
#   2.412425,
#   1.3792624999999998,
#   1.3085,
#   2.0144375,
#   0.8755875,
#   0.6758875,
#   1.0833125,
#   1.0129000000000001,
#   1.559225,
#   1.4379374999999999,
#   2.0833500000000003,
#   1.1309875,
#   1.6543750000000002,
#   1.7091249999999998,
#   2.1034625,
#   3.769725,
#   2.5883875,
#   1.2069125,
#   1.87995,
#   1.4368,
#   1.647275,
#   1.398325,
#   0.9533125,
#   1.0362125,
#   0.9032500000000001,
#   0.91105,
#   0.6292875,
#   0.6995500000000001,
#   1.7023125,
#   0.7132624999999999,
#   0.7615000000000001,
#   0.71485,
#   0.7624,
#   0.8835000000000001,
#   0.73415,
#   0.9160999999999999,
#   0.9136875,
#   0.7363374999999999,
#   0.8279624999999999,
#   0.5424875,
#   0.6573125,
#   1.4824125000000001,
#   1.357525,
#   1.0682375,
#   0.9713375000000001,
#   0.8267,
#   1.0200875,
#   0.9242625,
#   1.1221,
#   1.2504,
#   0.7948249999999999,
#   1.5811875,
#   1.9259125,
#   3.233575,
#   2.1639625000000002,
#   1.1285125,
#   1.3738875,
#   1.9544875,
#   1.2933875000000001,
#   0.833975,
#   1.8153375,
#   1.2381624999999998,
#   1.33985,
#   1.1684875,
#   0.6928125,
#   0.5873499999999999,
#   0.9614875,
#   0.6635125,
#   0.9592875000000001,
#   1.3147375000000001,
#   0.6907625000000001,
#   0.9848875000000001,
#   1.5584500000000001,
#   0.89625,
#   0.902525,
#   0.7897375,
#   2.67155,
#   1.5592375,
#   2.55785,
#   1.3286875,
#   1.6428625000000001,
#   1.2525,
#   1.46875,
#   1.53125,
#   1.30125,
#   1.1912500000000001,
#   1.36625,
#   1.6287500000000001,
#   1.0025,
#   1.22,
#   1.0675,
#   1.45625,
#   1.9850000000000003,
#   1.73125,
#   1.44,
#   1.05625,
#   1.11875,
#   1.2325,
#   1.1675,
#   1.105,
#   2.035,
#   2.3000000000000003,
#   1.21,
#   0.92125,
#   1.17625,
#   1.2525,
#   1.5462500000000001,
#   1.5125000000000002,
#   1.04125,
#   1.7225000000000001,
#   2.48375,
#   1.87125,
#   2.5,
#   2.5475000000000003,
#   1.5375,
#   1.57375,
#   2.615,
#   2.52625,
#   1.30125,
#   1.0875,
#   1.68875,
#   1.2075,
#   8.50625,
#   5.3475,
#   2.1550000000000002,
#   1.9649999999999999,
#   1.4625,
#   1.4037499999999998,
#   1.2575,
#   1.555,
#   1.67,
#   1.3599999999999999,
#   1.15,
#   0.9725,
#   1.44375,
#   1.93,
#   2.0925000000000002,
#   1.6437499999999998,
#   2.4275,
#   4.63375,
#   2.6562499999999996,
#   1.7350000000000003,
#   1.53125,
#   1.47125,
#   1.0450000000000002,
#   1.78375,
#   29.495,
#   16.8975,
#   19.33125,
#   26.87,
#   7.3,
#   34.21,
#   38.49,
#   45.337500000000006,
#   17.237499999999997,
#   19.788749999999997,
#   14.11625,
#   9.428749999999999,
#   9.1575,
#   5.65625,
#   8.4425,
#   5.877500000000001,
#   14.29125,
#   8.82125,
#   6.8175,
#   7.822500000000001,
#   6.29625,
#   8.86,
#   17.69125,
#   9.16875,
#   16.517500000000002,
#   41.738749999999996,
#   13.78,
#   18.79375,
#   9.701250000000002,
#   17.218750000000004,
#   5.603749999999999,
#   5.56875,
#   4.7475,
#   5.83625,
#   6.095000000000001,
#   5.148750000000001,
#   8.9325,
#   16.607499999999998,
#   20.8025,
#   6.3149999999999995,
#   3.9875,
#   3.75,
#   3.6312499999999996,
#   2.675,
#   2.5675,
#   2.9625,
#   11.7225,
#   8.6075,
#   6.284999999999999,
#   5.02125,
#   4.75,
#   24.985,
#   4.57625,
#   10.165,
#   6.680000000000001,
#   20.298750000000002,
#   12.10875,
#   10.11,
#   4.98375,
#   5.11125,
#   7.50875,
#   5.828749999999999,
#   7.6875,
#   4.251250000000001,
#   4.413749999999999,
#   6.48875,
#   7.0075,
#   6.99375,
#   4.0275,
#   16.294999999999998]}

# %%
# backtest

cats = [ '交通运输(2021)',
 '传媒(2021)',
 '公用事业(2021)',
 '农林牧渔(2021)',
 '医药生物(2021)',
 '商贸零售(2021)',
 '国防军工(2021)',
 '基础化工(2021)',
 '家用电器(2021)',
 '建筑材料(2021)',
 '建筑装饰(2021)',
 '有色金属(2021)',
 '机械设备(2021)',
 '汽车(2021)',
 '煤炭(2021)',
 '环保(2021)',
 '电力设备(2021)',
 '电子(2021)',
 '石油石化(2021)',
 '社会服务(2021)',
 '纺织服饰(2021)',
 '美容护理(2021)',
 '计算机(2021)',
 '轻工制造(2021)',
 '通信(2021)',
 '钢铁(2021)',
 '银行(2021)',
 '非银金融(2021)',
 '食品饮料(2021)']

start2 = 243 # 2022 3月
increase_cat = []
dt = '2023-05-16'
print('今天（'+ dt +'）')
# cats = ['计算机(2021)']
for cat in cats:
    idx = DTBS['D']['day'].index(dt)
    idx_d5 = idx - 5
    idx_d20 = idx - 20
    idx_d5r = [i for i in range(idx_d5, idx)]
    idx_d20r = [i for i in range(idx_d20, idx)]
    
    dt20 = DTBS['D']['day'][idx_d20]
    cd_cat = [cd for cd in DTBS['A'].keys() if DTBS['B'][cd]['cat1'] == cat and DTBS['A'][cd][dt]['ia'] == 1 and DTBS['A'][cd][dt20]['ia'] == 1 ]
    td = []
    
    for cd in cd_cat:
        td.append(DTBS['A'][cd][dt]['trt'])
            
    
    h5 = []
    h20 = []
    
    for cd in cd_cat:   
        o5 = []
        o20 = []
        for i in idx_d20r:
            pdt = DTBS['D']['day'][i]

            if i in idx_d5r:
                o5.append(DTBS['A'][cd][pdt]['trt'])
                
            o20.append(DTBS['A'][cd][pdt]['trt'])
        
        h5.append(np.mean(o5))
        h20.append(np.mean(o20))
        
        
        
        
        
    h5m = np.mean(h5)
    h20m = np.mean(h20)
    tdm = np.mean(td)

    h5d = []
    h20d = []
    for i in idx_d20r:    
      
        o5 = []
        o20 = []
        for cd in cd_cat: 
            pdt = DTBS['D']['day'][i]

            if i in idx_d5r:
                o5.append(DTBS['A'][cd][pdt]['trt'])
                
                    
            o20.append(DTBS['A'][cd][pdt]['trt'])
        if i in idx_d5r:
            h5d.append(np.mean(o5))
        h20d.append(np.mean(o20))
        
        
        
        
        
    h5m = np.mean(h5)
    h20m = np.mean(h20)
    tdm = np.mean(td)
    print( cat[:-6] + '行业热度', round(tdm,2), '前一周:', round(h5m,2), '前一月:', round(h20m,2))
    
#     x = [i for i in range(1,21)]
#     plt.figure()
#     plt.plot(x,h20d,label = '原始数据')

#     ser = pd.Series(h20d)
#     z = np.polyfit(range(1, ser.size + 1), ser, 10)
#     p = np.poly1d(z)
#     y = [p(i) for i in x]
#     plt.plot(x,y,label = '十项式拟合')


#     dp = p.deriv()
#     y = [dp(i) for i in x]
#     plt.plot(x,y, label = '拟合一阶导')
#     plt.title(cat[:-6])
#     plt.legend()
#     print('前一月（之前二十个交易日））'+ cat[:-6] + '行业热度', h20m)

# %%
cats = [ '交通运输(2021)',
 '传媒(2021)',
 '公用事业(2021)',
 '农林牧渔(2021)',
 '医药生物(2021)',
 '商贸零售(2021)',
 '国防军工(2021)',
 '基础化工(2021)',
 '家用电器(2021)',
 '建筑材料(2021)',
 '建筑装饰(2021)',
 '有色金属(2021)',
 '机械设备(2021)',
 '汽车(2021)',
 '煤炭(2021)',
 '环保(2021)',
 '电力设备(2021)',
 '电子(2021)',
 '石油石化(2021)',
 '社会服务(2021)',
 '纺织服饰(2021)',
 '美容护理(2021)',
 '计算机(2021)',
 '轻工制造(2021)',
 '通信(2021)',
 '钢铁(2021)',
 '银行(2021)',
 '非银金融(2021)',
 '食品饮料(2021)']

fri20 = DTBS['D']['fri'][145:]
fri20 = DTBS['D']['fri'][250:]


md = ['2022-10-21','2022-11-18','2022-12-16','2023-01-13','2023-02-17','2023-03-17','2023-04-14','2023-05-12']
nf = ['2022-11-25','2022-12-23','2023-01-20','2023-02-24','2023-03-24','2023-04-21','2023-05-18']
days = md.copy()
past = []
for i in range(len(days)):
    print(days[i])
    if i+1 == len(days):
        exist = select_existing(days[i])
            
            
    else: 
        exist_tr = select_existing(days[i])
        exist_nr = select_existing(days[i+1])
        exist =list(set(exist_tr).intersection(set(exist_nr)))

    select = exist.copy()

    if i >= 1:
        res = []
        for cat in cats:
            twp = []
            twh = []
            lwp = []
            lwh = []
            for cd in exist:
                if DTBS['B'][cd]['cat1'] == cat:
                    twp.append(DTBS['A'][cd][days[i]]['dp'])
                    twh.append(DTBS['A'][cd][days[i]]['trt'])        
                
            for cd in past:
                if DTBS['B'][cd]['cat1'] == cat:
                    lwp.append(DTBS['A'][cd][days[i-1]]['dp'])
                    lwh.append(DTBS['A'][cd][days[i-1]]['trt'])
                
            tp = np.mean(twp)
            th = np.mean(twh)
            lp = np.mean(lwp)
            lh = np.mean(lwh)      
            
            wkpf = (tp-lp) / lp 
            wkpfa = tp-lp
            wkht = (th - lh) / lp
            wkhta = th-lh
#             print(cat, wkpf, wkht)
            res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
        res.sort(key=takeSecond, reverse = True)
        res_10 = res[:10]
        print('本月热门行业监测：')
        for o in res_10:
            print(o[0][:-6] + '行业本月共有' + str(o[3]) + '支,平均热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ',平均收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
        
        res = []
        for resss in res_10:
            cat = resss[0]
            twp = []
            twh = []
            lwp = []
            lwh = []
            for cd in exist:
                if DTBS['B'][cd]['cat1'] == cat:
                    twp.append(DTBS['A'][cd][nf[i-1]]['dp'])
                    twh.append(DTBS['A'][cd][nf[i-1]]['trt'])        
                
            for cd in past:
                if DTBS['B'][cd]['cat1'] == cat:
                    lwp.append(DTBS['A'][cd][days[i-1]]['dp'])
                    lwh.append(DTBS['A'][cd][days[i-1]]['trt'])
                
            tp = np.mean(twp)
            th = np.mean(twh)
            lp = np.mean(lwp)
            lh = np.mean(lwh)      
            
            wkpf = (tp-lp) / lp 
            wkpfa = tp-lp
            wkht = (th - lh) / lp
            wkhta = th-lh
#             print(cat, wkpf, wkht)
            res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
        res.sort(key=takeThird, reverse = True)
        res_111 = res[:10]
        print(nf[i-1])
        print('下一周监测：')    
        for o in res_111:
            print(o[0][:-6] + '行业本月共有' + str(o[3]) + '支,平均热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ',平均收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
        
    res = []
#     if i>=2:

#         for cat in past_cat:
#             twp = []
#             twh = []
#             lwp = []
#             lwh = []
#             for cd in exist:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     twp.append(DTBS['A'][cd][days[i]]['dp'])
#                     twh.append(DTBS['A'][cd][days[i]]['trt'])        
                
#             for cd in past:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     lwp.append(DTBS['A'][cd][days[i-1]]['dp'])
#                     lwh.append(DTBS['A'][cd][days[i-1]]['trt'])
                
#             tp = np.mean(twp)
#             th = np.mean(twh)
#             lp = np.mean(lwp)
#             lh = np.mean(lwh)      
            
#             wkpf = (tp-lp) / lp 
#             wkpfa = tp-lp
#             wkht = (th - lh) / lp
#             wkhta = th-lh
# #             print(cat, wkpf, wkht)
#             res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
#         res.sort(key=takeThird, reverse = True)
#         print('上月热门行业继续监测：')
#         for o in res:
#             print(o[0][:-6] + '行业本月共有' + str(o[3]) + '支,平均热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ',平均收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
    
    
    past_cat = [j[0] for j in res_10]
    past = exist.copy()
# Out:
# 2022-10-21
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 156
#     121     res = []
#     122 #     if i>=2:
#     123
#     124 #         for cat in past_cat:
#    (...)
#     152 #         for o in res:
#     153 #             print(o[0][:-6] + '行业本月共有' + str(o[3]) + '支,平均热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ',平均收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
# --> 156     past_cat = [j[0] for j in res_10]
#     157     past = exist.copy()
#
# NameError: name 'res_10' is not defined

# %%
cats = [ '交通运输(2021)',
 '传媒(2021)',
 '公用事业(2021)',
 '农林牧渔(2021)',
 '医药生物(2021)',
 '商贸零售(2021)',
 '国防军工(2021)',
 '基础化工(2021)',
 '家用电器(2021)',
 '建筑材料(2021)',
 '建筑装饰(2021)',
 '有色金属(2021)',
 '机械设备(2021)',
 '汽车(2021)',
 '煤炭(2021)',
 '环保(2021)',
 '电力设备(2021)',
 '电子(2021)',
 '石油石化(2021)',
 '社会服务(2021)',
 '纺织服饰(2021)',
 '美容护理(2021)',
 '计算机(2021)',
 '轻工制造(2021)',
 '通信(2021)',
 '钢铁(2021)',
 '银行(2021)',
 '非银金融(2021)',
 '食品饮料(2021)']







cats = ['投资', '制造', '服务', '消费']
cats = ['环保', '医药', '周期', '能源', '科技', '消费', '新能源', '金融']
ctnm = 'zs'
fri20 = DTBS['D']['fri'][145:]
fri20 = DTBS['D']['fri'][258:]


md = ['2022-10-21','2022-11-18','2022-12-16','2023-01-13','2023-02-17','2023-03-17','2023-04-14','2023-05-12']
nf = ['2022-11-25','2022-12-23','2023-01-20','2023-02-24','2023-03-24','2023-04-21','2023-05-18']
days = fri20.copy()
past = []
for i in range(len(days)):
    




    if i > 3 and i < len(days) -2:
        exist_tr = select_existing(days[i-4])
        exist_nr = select_existing(days[i+2])
        exist =list(set(exist_tr).intersection(set(exist_nr)))
        select = exist.copy()

        res = []
        for cat in cats:
            twp = []
            twh = []
            lwp = []
            lwh = []
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    twp.append(DTBS['A'][cd][days[i]]['dp'])
                    twh.append(DTBS['A'][cd][days[i]]['trt'])        
                
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    lwp.append(DTBS['A'][cd][days[i-4]]['dp'])
                    lwh.append(DTBS['A'][cd][days[i-4]]['trt'])
                
            tp = np.mean(twp)
            th = np.mean(twh)
            lp = np.mean(lwp)
            lh = np.mean(lwh)      
            
            wkpf = (tp-lp) / lp 
            wkpfa = tp-lp
            wkht = (th - lh) / lp
            wkhta = th-lh
#             print(cat, wkpf, wkht)
            res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
        res.sort(key=takeSecond, reverse = True)
        res_10 = res[:10]
        res_10 = res
        print('最近一月热门行业监测：' + days[i-4] + '至'+days[i])
        for o in res_10:
#             print(o[0][:-6] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
            print(o[0] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
        
        res = []
        for resss in res_10:
            cat = resss[0]
            twp = []
            twh = []
            lwp = []
            lwh = []
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    twp.append(DTBS['A'][cd][days[i+1]]['dp'])
                    twh.append(DTBS['A'][cd][days[i+1]]['trt'])        
                
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    lwp.append(DTBS['A'][cd][days[i]]['dp'])
                    lwh.append(DTBS['A'][cd][days[i]]['trt'])
                
            tp = np.mean(twp)
            th = np.mean(twh)
            lp = np.mean(lwp)
            lh = np.mean(lwh)      
            
            wkpf = (tp-lp) / lp 
            wkpfa = tp-lp
            wkht = (th - lh) / lp
            wkhta = th-lh
#             print(cat, wkpf, wkht)
            res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
#         res.sort(key=takeThird, reverse = True)
        res_111 = res
        print('下一周监测：'+ days[i] + '至'+days[i+1]) 
        for o in res_111:
#             print(o[0][:-6] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
            print(o[0] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
        
        res = []
        for resss in res_10:
            cat = resss[0]
            twp = []
            twh = []
            lwp = []
            lwh = []
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    twp.append(DTBS['A'][cd][days[i+2]]['dp'])
                    twh.append(DTBS['A'][cd][days[i+2]]['trt'])        
                
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    lwp.append(DTBS['A'][cd][days[i+1]]['dp'])
                    lwh.append(DTBS['A'][cd][days[i+1]]['trt'])
                
            tp = np.mean(twp)
            th = np.mean(twh)
            lp = np.mean(lwp)
            lh = np.mean(lwh)      
            
            wkpf = (tp-lp) / lp 
            wkpfa = tp-lp
            wkht = (th - lh) / lp
            wkhta = th-lh
#             print(cat, wkpf, wkht)
            res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
#         res.sort(key=takeThird, reverse = True)
        res_111 = res
        print('下两周监测：'+ days[i+1] + '至'+days[i+2]) 
        for o in res_111:
#             print(o[0][:-6] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
            print(o[0] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
              
    res = []
#     if i>=2:

#         for cat in past_cat:
#             twp = []
#             twh = []
#             lwp = []
#             lwh = []
#             for cd in exist:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     twp.append(DTBS['A'][cd][days[i]]['dp'])
#                     twh.append(DTBS['A'][cd][days[i]]['trt'])        
                
#             for cd in past:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     lwp.append(DTBS['A'][cd][days[i-1]]['dp'])
#                     lwh.append(DTBS['A'][cd][days[i-1]]['trt'])
                
#             tp = np.mean(twp)
#             th = np.mean(twh)
#             lp = np.mean(lwp)
#             lh = np.mean(lwh)      
            
#             wkpf = (tp-lp) / lp 
#             wkpfa = tp-lp
#             wkht = (th - lh) / lp
#             wkhta = th-lh
# #             print(cat, wkpf, wkht)
#             res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
#         res.sort(key=takeThird, reverse = True)
#         print('上月热门行业继续监测：')
#         for o in res:
#             print(o[0][:-6] + '行业本月共有' + str(o[3]) + '支,平均热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ',平均收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
    
    
    past_cat = [j[0] for j in res_10]
    past = exist.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 200
#     165     res = []
#     166 #     if i>=2:
#     167
#     168 #         for cat in past_cat:
#    (...)
#     196 #         for o in res:
#     197 #             print(o[0][:-6] + '行业本月共有' + str(o[3]) + '支,平均热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ',平均收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
# --> 200     past_cat = [j[0] for j in res_10]
#     201     past = exist.copy()
#
# NameError: name 'res_10' is not defined

# %%
cats = [ '交通运输(2021)',
 '传媒(2021)',
 '公用事业(2021)',
 '农林牧渔(2021)',
 '医药生物(2021)',
 '商贸零售(2021)',
 '国防军工(2021)',
 '基础化工(2021)',
 '家用电器(2021)',
 '建筑材料(2021)',
 '建筑装饰(2021)',
 '有色金属(2021)',
 '机械设备(2021)',
 '汽车(2021)',
 '煤炭(2021)',
 '环保(2021)',
 '电力设备(2021)',
 '电子(2021)',
 '石油石化(2021)',
 '社会服务(2021)',
 '纺织服饰(2021)',
 '美容护理(2021)',
 '计算机(2021)',
 '轻工制造(2021)',
 '通信(2021)',
 '钢铁(2021)',
 '银行(2021)',
 '非银金融(2021)',
 '食品饮料(2021)']

cats = ['消费',
 '环保',
 '农业',
 '新能源',
 '电子',
 '能源',
 '医药',
 '投资',
 '金融',
 '科技',
 '制造',
 '基建']


# cats = ['投资', '制造', '服务', '消费']

# cats = ['环保', '医药', '周期', '能源', '科技', '消费', '新能源', '金融']
ctnm = 'yqq'
fri20 = DTBS['D']['fri'][145:]
fri20 = DTBS['D']['fri'][260:]


md = ['2022-10-21','2022-11-18','2022-12-16','2023-01-13','2023-02-17','2023-03-17','2023-04-14','2023-05-12']
nf = ['2022-11-25','2022-12-23','2023-01-20','2023-02-24','2023-03-24','2023-04-21','2023-05-18']
days = fri20.copy()
past = []
for i in range(len(days)):
    




    if i > 2 and i < len(days) -1:
        exist_tr = select_existing(days[i-2])
        exist_nr = select_existing(days[i+1])
        exist =list(set(exist_tr).intersection(set(exist_nr)))
        select = exist.copy()

        res = []
        for cat in cats:
            twp = []
            twh = []
            lwp = []
            lwh = []
            for cd in select:
                
                if DTBS['B'][cd][ctnm] == cat:
                    twp.append(DTBS['A'][cd][days[i]]['dp'])
                    
                    wks = []
                    id1 = DTBS['D']['day'].index(days[i-1]) 
                    id2 = DTBS['D']['day'].index(days[i]) 
                    wks = DTBS['D']['day'][id1+1:id2+1].copy()
                    for k in wks:
                        twh.append(DTBS['A'][cd][k]['trt'])     
                    
                
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    lwp.append(DTBS['A'][cd][days[i-1]]['dp'])
                    
                    wks = []
                    id1 = DTBS['D']['day'].index(days[i-2]) 
                    id2 = DTBS['D']['day'].index(days[i-1]) 
                    wks = DTBS['D']['day'][id1+1:id2+1].copy()
                    for k in wks:
                        lwh.append(DTBS['A'][cd][k]['trt'])   
            tp = np.mean(twp)
            th = np.mean(twh)
            lp = np.mean(lwp)
            lh = np.mean(lwh)      
            
            wkpf = (tp-lp) / lp 
            wkpfa = tp-lp
            wkht = (th - lh) / lp
            wkhta = th-lh
#             print(cat, wkpf, wkht)
            res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta, abs(wkht)))
        res.sort(key=takeSeventh, reverse = True)
        res_10 = res[:10]
        res_10 = res
        print('最近一周热门行业监测：' + days[i-1] + '至'+days[i])
        for o in res_10:
#             print(o[0][:-6] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
            print(o[0] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
        
        res = []
        for resss in res_10:
            cat = resss[0]
            twp = []
            twh = []
            lwp = []
            lwh = []
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:

                    twp.append(DTBS['A'][cd][days[i+1]]['dp'])
                    
                    wks = []
                    id1 = DTBS['D']['day'].index(days[i]) 
                    id2 = DTBS['D']['day'].index(days[i+1]) 
                    wks = DTBS['D']['day'][id1+1:id2+1].copy()
                    for k in wks:
                        twh.append(DTBS['A'][cd][k]['trt'])  
                    
                
            for cd in select:
                if DTBS['B'][cd][ctnm] == cat:
                    lwp.append(DTBS['A'][cd][days[i]]['dp'])
                    wks = []
                    id1 = DTBS['D']['day'].index(days[i-1]) 
                    id2 = DTBS['D']['day'].index(days[i]) 
                    wks = DTBS['D']['day'][id1+1:id2+1].copy()
                    for k in wks:
                        lwh.append(DTBS['A'][cd][k]['trt']) 

                
            tp = np.mean(twp)
            th = np.mean(twh)
            lp = np.mean(lwp)
            lh = np.mean(lwh)      
            
            wkpf = (tp-lp) / lp 
            wkpfa = tp-lp
            wkht = (th - lh) / lp
            wkhta = th-lh
#             print(cat, wkpf, wkht)
            res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta,abs(wkht)))
        res.sort(key=takeThird, reverse = True)
        res_111 = res
        print('下一周监测：'+ days[i] + '至'+days[i+1]) 
        for o in res_111:
#             print(o[0][:-6] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
            print(o[0]+ str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
        
#         res = []
#         for resss in res_10:
#             cat = resss[0]
#             twp = []
#             twh = []
#             lwp = []
#             lwh = []
#             for cd in select:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     twp.append(DTBS['A'][cd][days[i+2]]['dp'])
#                     twh.append(DTBS['A'][cd][days[i+2]]['trt'])        
                
#             for cd in select:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     lwp.append(DTBS['A'][cd][days[i+1]]['dp'])
#                     lwh.append(DTBS['A'][cd][days[i+1]]['trt'])
                
#             tp = np.mean(twp)
#             th = np.mean(twh)
#             lp = np.mean(lwp)
#             lh = np.mean(lwh)      
            
#             wkpf = (tp-lp) / lp 
#             wkpfa = tp-lp
#             wkht = (th - lh) / lp
#             wkhta = th-lh
# #             print(cat, wkpf, wkht)
#             res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
# #         res.sort(key=takeThird, reverse = True)
#         res_111 = res
#         print('下两周监测：'+ days[i+1] + '至'+days[i+2]) 
#         for o in res_111:
#             print(o[0][:-6] + str(o[3]) + '支, 热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ', 收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
        
        res = []
#     if i>=2:

#         for cat in past_cat:
#             twp = []
#             twh = []
#             lwp = []
#             lwh = []
#             for cd in exist:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     twp.append(DTBS['A'][cd][days[i]]['dp'])
#                     twh.append(DTBS['A'][cd][days[i]]['trt'])        
                
#             for cd in past:
#                 if DTBS['B'][cd]['cat1'] == cat:
#                     lwp.append(DTBS['A'][cd][days[i-1]]['dp'])
#                     lwh.append(DTBS['A'][cd][days[i-1]]['trt'])
                
#             tp = np.mean(twp)
#             th = np.mean(twh)
#             lp = np.mean(lwp)
#             lh = np.mean(lwh)      
            
#             wkpf = (tp-lp) / lp 
#             wkpfa = tp-lp
#             wkht = (th - lh) / lp
#             wkhta = th-lh
# #             print(cat, wkpf, wkht)
#             res.append((cat,wkht,wkpf, len(twp),wkpfa, wkhta))
#         res.sort(key=takeThird, reverse = True)
#         print('上月热门行业继续监测：')
#         for o in res:
#             print(o[0][:-6] + '行业本月共有' + str(o[3]) + '支,平均热度变化幅度' +str(round(o[1]*100,2)) + '%, 变化量' + str(round(o[5],2)) + ',平均收益率变化幅度' + str(round(o[2]*100,2))+ '%, 变化量' + str(round(o[4],2)) )
    
    
        past_cat = [j[0] for j in res_10]
        past = exist.copy()
# Out:
# 最近一周热门行业监测：2022-06-10至2022-06-17
# 新能源21支, 热度变化幅度26.96%, 变化量40.17, 收益率变化幅度4.16%, 变化量6.19
# 消费25支, 热度变化幅度25.39%, 变化量37.59, 收益率变化幅度3.41%, 变化量5.05
# 农业14支, 热度变化幅度21.47%, 变化量28.04, 收益率变化幅度3.06%, 变化量4.0
# 制造70支, 热度变化幅度15.87%, 变化量21.91, 收益率变化幅度2.38%, 变化量3.28
# 金融25支, 热度变化幅度13.05%, 变化量14.73, 收益率变化幅度1.2%, 变化量1.35
# 电子36支, 热度变化幅度10.88%, 变化量15.47, 收益率变化幅度1.61%, 变化量2.3
# 投资56支, 热度变化幅度10.13%, 变化量16.2, 收益率变化幅度1.49%, 变化量2.39
# 医药34支, 热度变化幅度-8.03%, 变化量-10.74, 收益率变化幅度2.0%, 变化量2.68
# 基建26支, 热度变化幅度-6.28%, 变化量-8.24, 收益率变化幅度-0.56%, 变化量-0.74
# 能源15支, 热度变化幅度3.23%, 变化量4.57, 收益率变化幅度-0.03%, 变化量-0.04
# 科技29支, 热度变化幅度-1.75%, 变化量-2.36, 收益率变化幅度0.88%, 变化量1.19
# 环保14支, 热度变化幅度1.42%, 变化量1.68, 收益率变化幅度0.72%, 变化量0.85
# 下一周监测：2022-06-17至2022-06-24
# 新能源21支, 热度变化幅度61.49%, 变化量95.41, 收益率变化幅度7.19%, 变化量11.15
# 消费25支, 热度变化幅度-65.46%, 变化量-100.24, 收益率变化幅度1.32%, 变化量2.02
# 电子36支, 热度变化幅度-3.59%, 变化量-5.19, 收益率变化幅度1.13%, 变化量1.63
# 医药34支, 热度变化幅度9.87%, 变化量13.46, 收益率变化幅度0.72%, 变化量0.98
# 投资56支, 热度变化幅度-4.63%, 变化量-7.51, 收益率变化幅度0.39%, 变化量0.63
# 农业14支, 热度变化幅度-32.79%, 变化量-44.14, 收益率变化幅度0.06%, 变化量0.08
# 制造70支, 热度变化幅度6.72%, 变化量9.5, 收益率变化幅度-0.37%, 变化量-0.52
# 环保14支, 热度变化幅度15.93%, 变化量18.88, 收益率变化幅度-0.46%, 变化量-0.54
# 能源15支, 热度变化幅度-9.95%, 变化量-14.05, 收益率变化幅度-0.49%, 变化量-0.69
# 科技29支, 热度变化幅度-12.56%, 变化量-17.08, 收益率变化幅度-0.75%, 变化量-1.02
# 金融25支, 热度变化幅度-10.09%, 变化量-11.52, 收益率变化幅度-0.75%, 变化量-0.86
# 基建26支, 热度变化幅度-1.03%, 变化量-1.34, 收益率变化幅度-1.74%, 变化量-2.26
# 最近一周热门行业监测：2022-06-17至2022-06-24
# 消费25支, 热度变化幅度-65.46%, 变化量-100.24, 收益率变化幅度1.32%, 变化量2.02
# 新能源21支, 热度变化幅度61.49%, 变化量95.41, 收益率变化幅度7.19%, 变化量11.15
# 农业15支, 热度变化幅度-32.96%, 变化量-44.26, 收益率变化幅度0.01%, 变化量0.01
# 环保14支, 热度变化幅度15.93%, 变化量18.88, 收益率变化幅度-0.46%, 变化量-0.54
# 科技29支, 热度变化幅度-12.56%, 变化量-17.08, 收益率变化幅度-0.75%, 变化量-1.02
# 金融25支, 热度变化幅度-10.09%, 变化量-11.52, 收益率变化幅度-0.75%, 变化量-0.86
# 医药34支, 热度变化幅度9.87%, 变化量13.46, 收益率变化幅度0.72%, 变化量0.98
# 能源16支, 热度变化幅度-9.61%, 变化量-13.43, 收益率变化幅度-0.45%, 变化量-0.63
# 制造71支, 热度变化幅度6.82%, 变化量9.61, 收益率变化幅度-0.27%, 变化量-0.38
# 投资56支, 热度变化幅度-4.63%, 变化量-7.51, 收益率变化幅度0.39%, 变化量0.63
# 电子36支, 热度变化幅度-3.59%, 变化量-5.19, 收益率变化幅度1.13%, 变化量1.63
# 基建26支, 热度变化幅度-1.03%, 变化量-1.34, 收益率变化幅度-1.74%, 变化量-2.26
# 下一周监测：2022-06-24至2022-07-01
# 投资56支, 热度变化幅度17.56%, 变化量28.63, 收益率变化幅度4.18%, 变化量6.82
# 能源16支, 热度变化幅度4.45%, 变化量6.19, 收益率变化幅度2.71%, 变化量3.77
# 电子36支, 热度变化幅度34.63%, 变化量50.59, 收益率变化幅度2.11%, 变化量3.09
# 基建26支, 热度变化幅度7.49%, 变化量9.6, 收益率变化幅度1.82%, 变化量2.34
# 环保14支, 热度变化幅度-11.45%, 变化量-13.51, 收益率变化幅度1.69%, 变化量1.99
# 金融25支, 热度变化幅度-1.7%, 变化量-1.93, 收益率变化幅度0.86%, 变化量0.97
# 科技29支, 热度变化幅度-14.18%, 变化量-19.13, 收益率变化幅度0.03%, 变化量0.05
# 农业15支, 热度变化幅度-3.45%, 变化量-4.63, 收益率变化幅度0.02%, 变化量0.03
# 制造71支, 热度变化幅度-22.86%, 变化量-32.13, 收益率变化幅度-0.31%, 变化量-0.44
# 医药34支, 热度变化幅度-15.27%, 变化量-20.97, 收益率变化幅度-0.56%, 变化量-0.77
# 消费25支, 热度变化幅度-10.79%, 变化量-16.74, 收益率变化幅度-0.88%, 变化量-1.37
# 新能源21支, 热度变化幅度-12.48%, 变化量-20.75, 收益率变化幅度-1.1%, 变化量-1.83
# 最近一周热门行业监测：2022-06-24至2022-07-01
# 电子36支, 热度变化幅度34.63%, 变化量50.59, 收益率变化幅度2.11%, 变化量3.09
# 制造70支, 热度变化幅度-22.74%, 变化量-31.83, 收益率变化幅度-0.29%, 变化量-0.4
# 投资56支, 热度变化幅度17.56%, 变化量28.63, 收益率变化幅度4.18%, 变化量6.82
# 医药34支, 热度变化幅度-15.27%, 变化量-20.97, 收益率变化幅度-0.56%, 变化量-0.77
# 科技29支, 热度变化幅度-14.18%, 变化量-19.13, 收益率变化幅度0.03%, 变化量0.05
# 新能源22支, 热度变化幅度-12.07%, 变化量-19.86, 收益率变化幅度-1.1%, 变化量-1.82
# 环保14支, 热度变化幅度-11.45%, 变化量-13.51, 收益率变化幅度1.69%, 变化量1.99
# 消费25支, 热度变化幅度-10.79%, 变化量-16.74, 收益率变化幅度-0.88%, 变化量-1.37
# 基建26支, 热度变化幅度7.49%, 变化量9.6, 收益率变化幅度1.82%, 变化量2.34
# 能源16支, 热度变化幅度4.45%, 变化量6.19, 收益率变化幅度2.71%, 变化量3.77
# 农业15支, 热度变化幅度-3.45%, 变化量-4.63, 收益率变化幅度0.02%, 变化量0.03
# 金融25支, 热度变化幅度-1.7%, 变化量-1.93, 收益率变化幅度0.86%, 变化量0.97
# 下一周监测：2022-07-01至2022-07-08
# 农业15支, 热度变化幅度27.64%, 变化量37.12, 收益率变化幅度2.66%, 变化量3.58
# 能源16支, 热度变化幅度-2.06%, 变化量-2.95, 收益率变化幅度1.03%, 变化量1.47
# 医药34支, 热度变化幅度-21.89%, 变化量-29.91, 收益率变化幅度0.61%, 变化量0.84
# 投资56支, 热度变化幅度-25.96%, 变化量-44.09, 收益率变化幅度0.16%, 变化量0.27
# 消费25支, 热度变化幅度-19.9%, 变化量-30.6, 收益率变化幅度-0.47%, 变化量-0.72
# 金融25支, 热度变化幅度-0.9%, 变化量-1.03, 收益率变化幅度-0.56%, 变化量-0.64
# 环保14支, 热度变化幅度-10.78%, 变化量-12.94, 收益率变化幅度-0.65%, 变化量-0.78
# 新能源22支, 热度变化幅度-40.84%, 变化量-66.48, 收益率变化幅度-0.98%, 变化量-1.59
# 制造70支, 热度变化幅度-20.41%, 变化量-28.48, 收益率变化幅度-1.06%, 变化量-1.48
# 基建26支, 热度变化幅度-2.44%, 变化量-3.19, 收益率变化幅度-1.11%, 变化量-1.45
# 电子36支, 热度变化幅度-42.93%, 变化量-64.04, 收益率变化幅度-1.24%, 变化量-1.85
# 科技29支, 热度变化幅度-21.06%, 变化量-28.42, 收益率变化幅度-1.39%, 变化量-1.87
# 最近一周热门行业监测：2022-07-01至2022-07-08
# 电子36支, 热度变化幅度-42.93%, 变化量-64.04, 收益率变化幅度-1.24%, 变化量-1.85
# 新能源23支, 热度变化幅度-39.99%, 变化量-64.59, 收益率变化幅度-0.96%, 变化量-1.56
# 农业15支, 热度变化幅度27.64%, 变化量37.12, 收益率变化幅度2.66%, 变化量3.58
# 投资55支, 热度变化幅度-26.29%, 变化量-44.89, 收益率变化幅度0.14%, 变化量0.23
# 医药34支, 热度变化幅度-21.89%, 变化量-29.91, 收益率变化幅度0.61%, 变化量0.84
# 科技29支, 热度变化幅度-21.06%, 变化量-28.42, 收益率变化幅度-1.39%, 变化量-1.87
# 制造70支, 热度变化幅度-20.41%, 变化量-28.48, 收益率变化幅度-1.06%, 变化量-1.48
# 消费24支, 热度变化幅度-20.06%, 变化量-30.51, 收益率变化幅度-0.49%, 变化量-0.74
# 环保14支, 热度变化幅度-10.78%, 变化量-12.94, 收益率变化幅度-0.65%, 变化量-0.78
# 基建26支, 热度变化幅度-2.44%, 变化量-3.19, 收益率变化幅度-1.11%, 变化量-1.45
# 能源16支, 热度变化幅度-2.06%, 变化量-2.95, 收益率变化幅度1.03%, 变化量1.47
# 金融25支, 热度变化幅度-0.9%, 变化量-1.03, 收益率变化幅度-0.56%, 变化量-0.64
# 下一周监测：2022-07-08至2022-07-15
# 新能源23支, 热度变化幅度-22.02%, 变化量-35.22, 收益率变化幅度0.39%, 变化量0.63
# 环保14支, 热度变化幅度-0.7%, 变化量-0.83, 收益率变化幅度-0.71%, 变化量-0.84
# 金融25支, 热度变化幅度0.23%, 变化量0.26, 收益率变化幅度-0.98%, 变化量-1.11
# 消费24支, 热度变化幅度-8.18%, 变化量-12.38, 收益率变化幅度-1.19%, 变化量-1.8
# 能源16支, 热度变化幅度-1.47%, 变化量-2.12, 收益率变化幅度-1.49%, 变化量-2.15
# 科技29支, 热度变化幅度-3.53%, 变化量-4.7, 收益率变化幅度-1.55%, 变化量-2.07
# 制造70支, 热度变化幅度-0.81%, 变化量-1.12, 收益率变化幅度-1.56%, 变化量-2.15
# 投资55支, 热度变化幅度-24.85%, 变化量-42.48, 收益率变化幅度-1.57%, 变化量-2.69
# 电子36支, 热度变化幅度-10.33%, 变化量-15.21, 收益率变化幅度-1.72%, 变化量-2.53
# 基建26支, 热度变化幅度2.14%, 变化量2.76, 收益率变化幅度-1.8%, 变化量-2.32
# 医药34支, 热度变化幅度7.1%, 变化量9.76, 收益率变化幅度-2.25%, 变化量-3.09
# 农业15支, 热度变化幅度-31.09%, 变化量-42.87, 收益率变化幅度-2.32%, 变化量-3.2
# 最近一周热门行业监测：2022-07-08至2022-07-15
# 农业15支, 热度变化幅度-31.09%, 变化量-42.87, 收益率变化幅度-2.32%, 变化量-3.2
# 投资55支, 热度变化幅度-24.85%, 变化量-42.48, 收益率变化幅度-1.57%, 变化量-2.69
# 新能源24支, 热度变化幅度-24.58%, 变化量-39.73, 收益率变化幅度0.74%, 变化量1.19
# 电子36支, 热度变化幅度-10.33%, 变化量-15.21, 收益率变化幅度-1.72%, 变化量-2.53
# 消费24支, 热度变化幅度-8.18%, 变化量-12.38, 收益率变化幅度-1.19%, 变化量-1.8
# 医药34支, 热度变化幅度7.1%, 变化量9.76, 收益率变化幅度-2.25%, 变化量-3.09
# 科技29支, 热度变化幅度-3.53%, 变化量-4.7, 收益率变化幅度-1.55%, 变化量-2.07
# 基建26支, 热度变化幅度2.14%, 变化量2.76, 收益率变化幅度-1.8%, 变化量-2.32
# 能源16支, 热度变化幅度-1.47%, 变化量-2.12, 收益率变化幅度-1.49%, 变化量-2.15
# 制造70支, 热度变化幅度-0.81%, 变化量-1.12, 收益率变化幅度-1.56%, 变化量-2.15
# 环保14支, 热度变化幅度-0.7%, 变化量-0.83, 收益率变化幅度-0.71%, 变化量-0.84
# 金融25支, 热度变化幅度0.23%, 变化量0.26, 收益率变化幅度-0.98%, 变化量-1.11
# 下一周监测：2022-07-15至2022-07-22
# 制造70支, 热度变化幅度17.81%, 变化量24.21, 收益率变化幅度3.08%, 变化量4.19
# 环保14支, 热度变化幅度20.37%, 变化量24.1, 收益率变化幅度2.79%, 变化量3.3
# 投资55支, 热度变化幅度3.96%, 变化量6.66, 收益率变化幅度2.59%, 变化量4.36
# 电子36支, 热度变化幅度18.51%, 变化量26.8, 收益率变化幅度2.19%, 变化量3.18
# 能源16支, 热度变化幅度3.7%, 变化量5.26, 收益率变化幅度2.15%, 变化量3.05
# 科技29支, 热度变化幅度10.09%, 变化量13.22, 收益率变化幅度2.06%, 变化量2.7
# 新能源24支, 热度变化幅度10.51%, 变化量17.11, 收益率变化幅度0.91%, 变化量1.48
# 金融25支, 热度变化幅度-0.14%, 变化量-0.16, 收益率变化幅度0.64%, 变化量0.72
# 基建26支, 热度变化幅度-9.57%, 变化量-12.14, 收益率变化幅度0.63%, 变化量0.79
# 医药34支, 热度变化幅度-18.23%, 变化量-24.5, 收益率变化幅度-0.01%, 变化量-0.02
# 农业15支, 热度变化幅度-4.94%, 变化量-6.65, 收益率变化幅度-0.88%, 变化量-1.19
# 消费24支, 热度变化幅度-3.64%, 变化量-5.44, 收益率变化幅度-2.01%, 变化量-3.0
# 最近一周热门行业监测：2022-07-15至2022-07-22
# 环保14支, 热度变化幅度20.37%, 变化量24.1, 收益率变化幅度2.79%, 变化量3.3
# 电子36支, 热度变化幅度18.51%, 变化量26.8, 收益率变化幅度2.19%, 变化量3.18
# 医药34支, 热度变化幅度-18.23%, 变化量-24.5, 收益率变化幅度-0.01%, 变化量-0.02
# 制造71支, 热度变化幅度16.79%, 变化量22.88, 收益率变化幅度3.07%, 变化量4.19
# 新能源24支, 热度变化幅度10.51%, 变化量17.11, 收益率变化幅度0.91%, 变化量1.48
# 科技29支, 热度变化幅度10.09%, 变化量13.22, 收益率变化幅度2.06%, 变化量2.7
# 基建26支, 热度变化幅度-9.57%, 变化量-12.14, 收益率变化幅度0.63%, 变化量0.79
# 农业15支, 热度变化幅度-4.94%, 变化量-6.65, 收益率变化幅度-0.88%, 变化量-1.19
# 投资55支, 热度变化幅度3.96%, 变化量6.66, 收益率变化幅度2.59%, 变化量4.36
# 能源16支, 热度变化幅度3.7%, 变化量5.26, 收益率变化幅度2.15%, 变化量3.05
# 消费24支, 热度变化幅度-3.64%, 变化量-5.44, 收益率变化幅度-2.01%, 变化量-3.0
# 金融26支, 热度变化幅度-0.23%, 变化量-0.26, 收益率变化幅度0.69%, 变化量0.79
# 下一周监测：2022-07-22至2022-07-29
# 投资55支, 热度变化幅度8.65%, 变化量14.94, 收益率变化幅度3.65%, 变化量6.3
# 制造71支, 热度变化幅度9.82%, 变化量13.79, 收益率变化幅度3.41%, 变化量4.79
# 能源16支, 热度变化幅度1.73%, 变化量2.52, 收益率变化幅度2.13%, 变化量3.1
# 消费24支, 热度变化幅度1.89%, 变化量2.77, 收益率变化幅度2.0%, 变化量2.92
# 环保14支, 热度变化幅度-16.48%, 变化量-20.04, 收益率变化幅度1.46%, 变化量1.78
# 科技29支, 热度变化幅度-1.57%, 变化量-2.1, 收益率变化幅度1.28%, 变化量1.71
# 电子36支, 热度变化幅度13.83%, 变化量20.46, 收益率变化幅度1.12%, 变化量1.66
# 金融26支, 热度变化幅度-0.29%, 变化量-0.33, 收益率变化幅度0.53%, 变化量0.6
# 新能源24支, 热度变化幅度-19.37%, 变化量-31.82, 收益率变化幅度0.35%, 变化量0.58
# 农业15支, 热度变化幅度1.88%, 变化量2.51, 收益率变化幅度0.3%, 变化量0.4
# 基建26支, 热度变化幅度0.47%, 变化量0.6, 收益率变化幅度-0.3%, 变化量-0.38
# 医药34支, 热度变化幅度-7.38%, 变化量-9.92, 收益率变化幅度-0.41%, 变化量-0.55
# 最近一周热门行业监测：2022-07-22至2022-07-29
# 新能源25支, 热度变化幅度-19.32%, 变化量-31.54, 收益率变化幅度0.37%, 变化量0.6
# 环保14支, 热度变化幅度-16.48%, 变化量-20.04, 收益率变化幅度1.46%, 变化量1.78
# 电子36支, 热度变化幅度13.83%, 变化量20.46, 收益率变化幅度1.12%, 变化量1.66
# 制造71支, 热度变化幅度9.82%, 变化量13.79, 收益率变化幅度3.41%, 变化量4.79
# 投资55支, 热度变化幅度8.65%, 变化量14.94, 收益率变化幅度3.65%, 变化量6.3
# 医药34支, 热度变化幅度-7.38%, 变化量-9.92, 收益率变化幅度-0.41%, 变化量-0.55
# 消费24支, 热度变化幅度1.89%, 变化量2.77, 收益率变化幅度2.0%, 变化量2.92
# 农业15支, 热度变化幅度1.88%, 变化量2.51, 收益率变化幅度0.3%, 变化量0.4
# 能源16支, 热度变化幅度1.73%, 变化量2.52, 收益率变化幅度2.13%, 变化量3.1
# 科技29支, 热度变化幅度-1.57%, 变化量-2.1, 收益率变化幅度1.28%, 变化量1.71
# 基建26支, 热度变化幅度0.47%, 变化量0.6, 收益率变化幅度-0.3%, 变化量-0.38
# 金融26支, 热度变化幅度-0.29%, 变化量-0.33, 收益率变化幅度0.53%, 变化量0.6
# 下一周监测：2022-07-29至2022-08-05
# 电子36支, 热度变化幅度12.83%, 变化量19.2, 收益率变化幅度3.56%, 变化量5.33
# 科技29支, 热度变化幅度0.61%, 变化量0.83, 收益率变化幅度-0.07%, 变化量-0.09
# 金融26支, 热度变化幅度-0.04%, 变化量-0.05, 收益率变化幅度-0.32%, 变化量-0.36
# 农业15支, 热度变化幅度8.42%, 变化量11.27, 收益率变化幅度-0.58%, 变化量-0.77
# 新能源25支, 热度变化幅度-2.31%, 变化量-3.79, 收益率变化幅度-1.13%, 变化量-1.85
# 环保14支, 热度变化幅度-3.03%, 变化量-3.74, 收益率变化幅度-1.26%, 变化量-1.55
# 投资55支, 热度变化幅度-7.77%, 变化量-13.91, 收益率变化幅度-1.33%, 变化量-2.37
# 医药34支, 热度变化幅度-3.39%, 变化量-4.53, 收益率变化幅度-1.6%, 变化量-2.14
# 消费24支, 热度变化幅度-5.36%, 变化量-8.01, 收益率变化幅度-1.65%, 变化量-2.46
# 基建26支, 热度变化幅度-0.89%, 变化量-1.13, 收益率变化幅度-1.82%, 变化量-2.32
# 能源16支, 热度变化幅度-5.82%, 变化量-8.63, 收益率变化幅度-2.01%, 变化量-2.99
# 制造71支, 热度变化幅度-22.94%, 变化量-33.32, 收益率变化幅度-2.92%, 变化量-4.23
# 最近一周热门行业监测：2022-07-29至2022-08-05
# 制造72支, 热度变化幅度-22.89%, 变化量-33.25, 收益率变化幅度-2.87%, 变化量-4.17
# 电子36支, 热度变化幅度12.83%, 变化量19.2, 收益率变化幅度3.56%, 变化量5.33
# 农业15支, 热度变化幅度8.42%, 变化量11.27, 收益率变化幅度-0.58%, 变化量-0.77
# 投资57支, 热度变化幅度-7.59%, 变化量-13.43, 收益率变化幅度-1.29%, 变化量-2.28
# 能源16支, 热度变化幅度-5.82%, 变化量-8.63, 收益率变化幅度-2.01%, 变化量-2.99
# 消费24支, 热度变化幅度-5.36%, 变化量-8.01, 收益率变化幅度-1.65%, 变化量-2.46
# 医药36支, 热度变化幅度-3.38%, 变化量-4.51, 收益率变化幅度-1.54%, 变化量-2.06
# 环保14支, 热度变化幅度-3.03%, 变化量-3.74, 收益率变化幅度-1.26%, 变化量-1.55
# 新能源26支, 热度变化幅度-2.29%, 变化量-3.73, 收益率变化幅度-1.17%, 变化量-1.9
# 基建26支, 热度变化幅度-0.89%, 变化量-1.13, 收益率变化幅度-1.82%, 变化量-2.32
# 科技29支, 热度变化幅度0.61%, 变化量0.83, 收益率变化幅度-0.07%, 变化量-0.09
# 金融26支, 热度变化幅度-0.04%, 变化量-0.05, 收益率变化幅度-0.32%, 变化量-0.36
# 下一周监测：2022-08-05至2022-08-12
# 能源16支, 热度变化幅度-0.14%, 变化量-0.2, 收益率变化幅度5.59%, 变化量8.13
# 投资57支, 热度变化幅度-2.88%, 变化量-5.03, 收益率变化幅度2.46%, 变化量4.29
# 制造72支, 热度变化幅度-4.74%, 变化量-6.69, 收益率变化幅度1.61%, 变化量2.27
# 电子36支, 热度变化幅度-19.05%, 变化量-29.52, 收益率变化幅度1.38%, 变化量2.14
# 新能源26支, 热度变化幅度-11.4%, 变化量-18.35, 收益率变化幅度1.29%, 变化量2.08
# 环保14支, 热度变化幅度-0.89%, 变化量-1.08, 收益率变化幅度1.1%, 变化量1.34
# 金融26支, 热度变化幅度0.15%, 变化量0.18, 收益率变化幅度0.91%, 变化量1.04
# 消费24支, 热度变化幅度-4.48%, 变化量-6.59, 收益率变化幅度0.88%, 变化量1.3
# 医药36支, 热度变化幅度-1.37%, 变化量-1.8, 收益率变化幅度0.78%, 变化量1.03
# 基建26支, 热度变化幅度5.24%, 变化量6.55, 收益率变化幅度0.58%, 变化量0.73
# 科技29支, 热度变化幅度-3.46%, 变化量-4.68, 收益率变化幅度0.56%, 变化量0.76
# 农业15支, 热度变化幅度-12.5%, 变化量-16.64, 收益率变化幅度0.03%, 变化量0.04
# 最近一周热门行业监测：2022-08-05至2022-08-12
# 电子36支, 热度变化幅度-19.05%, 变化量-29.52, 收益率变化幅度1.38%, 变化量2.14
# 农业15支, 热度变化幅度-12.5%, 变化量-16.64, 收益率变化幅度0.03%, 变化量0.04
# 新能源26支, 热度变化幅度-11.4%, 变化量-18.35, 收益率变化幅度1.29%, 变化量2.08
# 基建26支, 热度变化幅度5.24%, 变化量6.55, 收益率变化幅度0.58%, 变化量0.73
# 制造74支, 热度变化幅度-4.99%, 变化量-7.07, 收益率变化幅度1.53%, 变化量2.18
# 消费24支, 热度变化幅度-4.48%, 变化量-6.59, 收益率变化幅度0.88%, 变化量1.3
# 科技30支, 热度变化幅度-3.41%, 变化量-4.62, 收益率变化幅度0.66%, 变化量0.89
# 投资58支, 热度变化幅度-2.83%, 变化量-4.93, 收益率变化幅度2.47%, 变化量4.29
# 医药37支, 热度变化幅度-1.0%, 变化量-1.32, 收益率变化幅度1.0%, 变化量1.32
# 环保14支, 热度变化幅度-0.89%, 变化量-1.08, 收益率变化幅度1.1%, 变化量1.34
# 金融26支, 热度变化幅度0.15%, 变化量0.18, 收益率变化幅度0.91%, 变化量1.04
# 能源16支, 热度变化幅度-0.14%, 变化量-0.2, 收益率变化幅度5.59%, 变化量8.13
# 下一周监测：2022-08-12至2022-08-19
# 农业15支, 热度变化幅度5.11%, 变化量6.81, 收益率变化幅度2.58%, 变化量3.43
# 基建26支, 热度变化幅度2.44%, 变化量3.07, 收益率变化幅度0.45%, 变化量0.56
# 能源16支, 热度变化幅度0.57%, 变化量0.87, 收益率变化幅度-0.12%, 变化量-0.18
# 新能源26支, 热度变化幅度1.75%, 变化量2.86, 收益率变化幅度-0.19%, 变化量-0.31
# 金融26支, 热度变化幅度-0.2%, 变化量-0.23, 收益率变化幅度-0.26%, 变化量-0.3
# 消费24支, 热度变化幅度2.97%, 变化量4.41, 收益率变化幅度-0.53%, 变化量-0.78
# 环保14支, 热度变化幅度-0.53%, 变化量-0.65, 收益率变化幅度-0.88%, 变化量-1.08
# 制造74支, 热度变化幅度-7.63%, 变化量-10.99, 收益率变化幅度-1.59%, 变化量-2.29
# 医药37支, 热度变化幅度-2.5%, 变化量-3.31, 收益率变化幅度-2.22%, 变化量-2.94
# 科技30支, 热度变化幅度-7.32%, 变化量-10.0, 收益率变化幅度-2.36%, 变化量-3.22
# 投资58支, 热度变化幅度-7.89%, 变化量-14.06, 收益率变化幅度-3.21%, 变化量-5.72
# 电子36支, 热度变化幅度-22.55%, 变化量-35.42, 收益率变化幅度-3.8%, 变化量-5.96
# 最近一周热门行业监测：2022-08-12至2022-08-19
# 电子37支, 热度变化幅度-22.67%, 变化量-35.56, 收益率变化幅度-3.88%, 变化量-6.08
# 投资58支, 热度变化幅度-7.89%, 变化量-14.06, 收益率变化幅度-3.21%, 变化量-5.72
# 制造74支, 热度变化幅度-7.63%, 变化量-10.99, 收益率变化幅度-1.59%, 变化量-2.29
# 科技30支, 热度变化幅度-7.32%, 变化量-10.0, 收益率变化幅度-2.36%, 变化量-3.22
# 农业15支, 热度变化幅度5.11%, 变化量6.81, 收益率变化幅度2.58%, 变化量3.43
# 消费24支, 热度变化幅度2.97%, 变化量4.41, 收益率变化幅度-0.53%, 变化量-0.78
# 医药38支, 热度变化幅度-2.5%, 变化量-3.32, 收益率变化幅度-2.21%, 变化量-2.93
# 基建26支, 热度变化幅度2.44%, 变化量3.07, 收益率变化幅度0.45%, 变化量0.56
# 新能源27支, 热度变化幅度1.68%, 变化量2.72, 收益率变化幅度-0.24%, 变化量-0.39
# 能源16支, 热度变化幅度0.57%, 变化量0.87, 收益率变化幅度-0.12%, 变化量-0.18
# 环保14支, 热度变化幅度-0.53%, 变化量-0.65, 收益率变化幅度-0.88%, 变化量-1.08
# 金融26支, 热度变化幅度-0.2%, 变化量-0.23, 收益率变化幅度-0.26%, 变化量-0.3
# 下一周监测：2022-08-19至2022-08-26
# 金融26支, 热度变化幅度0.04%, 变化量0.04, 收益率变化幅度0.02%, 变化量0.02
# 环保14支, 热度变化幅度26.38%, 变化量32.22, 收益率变化幅度-0.92%, 变化量-1.12
# 农业15支, 热度变化幅度-1.89%, 变化量-2.58, 收益率变化幅度-0.99%, 变化量-1.35
# 医药38支, 热度变化幅度1.33%, 变化量1.73, 收益率变化幅度-1.56%, 变化量-2.03
# 基建26支, 热度变化幅度-2.16%, 变化量-2.72, 收益率变化幅度-1.6%, 变化量-2.02
# 能源16支, 热度变化幅度-0.11%, 变化量-0.17, 收益率变化幅度-2.8%, 变化量-4.3
# 科技30支, 热度变化幅度-0.63%, 变化量-0.84, 收益率变化幅度-2.91%, 变化量-3.88
# 消费24支, 热度变化幅度-1.0%, 变化量-1.48, 收益率变化幅度-2.98%, 变化量-4.4
# 投资58支, 热度变化幅度0.54%, 变化量0.93, 收益率变化幅度-3.74%, 变化量-6.45
# 制造74支, 热度变化幅度1.25%, 变化量1.77, 收益率变化幅度-4.04%, 变化量-5.72
# 新能源27支, 热度变化幅度-3.48%, 变化量-5.63, 收益率变化幅度-6.2%, 变化量-10.03
# 电子37支, 热度变化幅度-2.54%, 变化量-3.84, 收益率变化幅度-6.31%, 变化量-9.51
# 最近一周热门行业监测：2022-08-19至2022-08-26
# 环保15支, 热度变化幅度24.36%, 变化量29.86, 收益率变化幅度-0.9%, 变化量-1.11
# 新能源27支, 热度变化幅度-3.44%, 变化量-5.56, 收益率变化幅度-6.08%, 变化量-9.83
# 电子38支, 热度变化幅度-3.25%, 变化量-4.9, 收益率变化幅度-6.24%, 变化量-9.39
# 基建26支, 热度变化幅度-2.16%, 变化量-2.72, 收益率变化幅度-1.6%, 变化量-2.02
# 农业15支, 热度变化幅度-1.89%, 变化量-2.58, 收益率变化幅度-0.99%, 变化量-1.35
# 医药38支, 热度变化幅度1.33%, 变化量1.73, 收益率变化幅度-1.56%, 变化量-2.03
# 制造75支, 热度变化幅度1.14%, 变化量1.62, 收益率变化幅度-4.0%, 变化量-5.67
# 科技30支, 热度变化幅度-0.63%, 变化量-0.84, 收益率变化幅度-2.91%, 变化量-3.88
# 投资59支, 热度变化幅度0.2%, 变化量0.34, 收益率变化幅度-3.85%, 变化量-6.64
# 能源16支, 热度变化幅度-0.11%, 变化量-0.17, 收益率变化幅度-2.8%, 变化量-4.3
# 消费23支, 热度变化幅度-0.1%, 变化量-0.15, 收益率变化幅度-2.89%, 变化量-4.26
# 金融26支, 热度变化幅度0.04%, 变化量0.04, 收益率变化幅度0.02%, 变化量0.02
# 下一周监测：2022-08-26至2022-09-02
# 医药38支, 热度变化幅度2.96%, 变化量3.77, 收益率变化幅度-0.26%, 变化量-0.34
# 金融26支, 热度变化幅度-0.01%, 变化量-0.01, 收益率变化幅度-0.36%, 变化量-0.41
# 农业15支, 热度变化幅度-0.95%, 变化量-1.29, 收益率变化幅度-0.51%, 变化量-0.69
# 基建26支, 热度变化幅度4.38%, 变化量5.44, 收益率变化幅度-0.68%, 变化量-0.84
# 科技30支, 热度变化幅度11.09%, 变化量14.36, 收益率变化幅度-0.91%, 变化量-1.18
# 电子38支, 热度变化幅度12.11%, 变化量17.08, 收益率变化幅度-1.33%, 变化量-1.88
# 环保15支, 热度变化幅度-19.51%, 变化量-23.7, 收益率变化幅度-1.48%, 变化量-1.8
# 消费23支, 热度变化幅度1.43%, 变化量2.05, 收益率变化幅度-1.92%, 变化量-2.75
# 制造75支, 热度变化幅度-6.66%, 变化量-9.07, 收益率变化幅度-2.55%, 变化量-3.47
# 投资59支, 热度变化幅度-1.03%, 变化量-1.71, 收益率变化幅度-3.41%, 变化量-5.65
# 能源16支, 热度变化幅度-1.73%, 变化量-2.57, 收益率变化幅度-4.24%, 变化量-6.32
# 新能源27支, 热度变化幅度-1.68%, 变化量-2.55, 收益率变化幅度-5.17%, 变化量-7.84
# 最近一周热门行业监测：2022-08-26至2022-09-02
# 环保15支, 热度变化幅度-19.51%, 变化量-23.7, 收益率变化幅度-1.48%, 变化量-1.8
# 电子39支, 热度变化幅度11.63%, 变化量16.37, 收益率变化幅度-1.42%, 变化量-2.0
# 科技29支, 热度变化幅度11.56%, 变化量14.9, 收益率变化幅度-0.78%, 变化量-1.01
# 制造76支, 热度变化幅度-6.83%, 变化量-9.31, 收益率变化幅度-2.53%, 变化量-3.44
# 基建26支, 热度变化幅度4.38%, 变化量5.44, 收益率变化幅度-0.68%, 变化量-0.84
# 医药38支, 热度变化幅度2.96%, 变化量3.77, 收益率变化幅度-0.26%, 变化量-0.34
# 能源17支, 热度变化幅度-1.79%, 变化量-2.64, 收益率变化幅度-4.07%, 变化量-5.99
# 新能源27支, 热度变化幅度-1.68%, 变化量-2.55, 收益率变化幅度-5.17%, 变化量-7.84
# 消费23支, 热度变化幅度1.43%, 变化量2.05, 收益率变化幅度-1.92%, 变化量-2.75
# 投资59支, 热度变化幅度-1.03%, 变化量-1.71, 收益率变化幅度-3.41%, 变化量-5.65
# 农业15支, 热度变化幅度-0.95%, 变化量-1.29, 收益率变化幅度-0.51%, 变化量-0.69
# 金融26支, 热度变化幅度-0.01%, 变化量-0.01, 收益率变化幅度-0.36%, 变化量-0.41
# 下一周监测：2022-09-02至2022-09-09
# 科技29支, 热度变化幅度20.47%, 变化量26.26, 收益率变化幅度-2.29%, 变化量-2.94
# 电子39支, 热度变化幅度-1.82%, 变化量-2.57, 收益率变化幅度-2.66%, 变化量-3.77
# 制造75支, 热度变化幅度-1.55%, 变化量-2.09, 收益率变化幅度-3.04%, 变化量-4.11
# 医药38支, 热度变化幅度-1.08%, 变化量-1.37, 收益率变化幅度-3.1%, 变化量-3.96
# 投资60支, 热度变化幅度-0.94%, 变化量-1.55, 收益率变化幅度-4.09%, 变化量-6.74
# 能源17支, 热度变化幅度-1.1%, 变化量-1.6, 收益率变化幅度-5.2%, 变化量-7.55
# 新能源27支, 热度变化幅度-4.9%, 变化量-7.26, 收益率变化幅度-5.72%, 变化量-8.47
# 最近一周热门行业监测：2022-09-09至2022-09-16
# 科技29支, 热度变化幅度20.47%, 变化量26.26, 收益率变化幅度-2.29%, 变化量-2.94
# 基建26支, 热度变化幅度13.32%, 变化量16.81, 收益率变化幅度-1.78%, 变化量-2.25
# 新能源28支, 热度变化幅度-5.4%, 变化量-7.95, 收益率变化幅度-5.64%, 变化量-8.3
# 能源18支, 热度变化幅度-2.5%, 变化量-3.61, 收益率变化幅度-5.2%, 变化量-7.49
# 环保16支, 热度变化幅度-1.94%, 变化量-2.36, 收益率变化幅度-2.21%, 变化量-2.68
# 制造78支, 热度变化幅度-1.93%, 变化量-2.61, 收益率变化幅度-3.02%, 变化量-4.08
# 电子39支, 热度变化幅度-1.82%, 变化量-2.57, 收益率变化幅度-2.66%, 变化量-3.77
# 医药38支, 热度变化幅度-1.08%, 变化量-1.37, 收益率变化幅度-3.1%, 变化量-3.96
# 投资60支, 热度变化幅度-0.94%, 变化量-1.55, 收益率变化幅度-4.09%, 变化量-6.74
# 消费24支, 热度变化幅度0.52%, 变化量0.73, 收益率变化幅度-2.11%, 变化量-2.96
# 农业15支, 热度变化幅度0.32%, 变化量0.42, 收益率变化幅度-1.88%, 变化量-2.5
# 金融25支, 热度变化幅度0.1%, 变化量0.12, 收益率变化幅度-1.09%, 变化量-1.27
# 下一周监测：2022-09-16至2022-09-23
# 投资60支, 热度变化幅度2.87%, 变化量4.54, 收益率变化幅度1.19%, 变化量1.88
# 新能源28支, 热度变化幅度0.4%, 变化量0.56, 收益率变化幅度0.5%, 变化量0.7
# 能源18支, 热度变化幅度-1.62%, 变化量-2.21, 收益率变化幅度0.15%, 变化量0.2
# 制造78支, 热度变化幅度2.46%, 变化量3.23, 收益率变化幅度0.06%, 变化量0.07
# 电子39支, 热度变化幅度3.73%, 变化量5.14, 收益率变化幅度-0.02%, 变化量-0.02
# 金融25支, 热度变化幅度-0.2%, 变化量-0.23, 收益率变化幅度-0.15%, 变化量-0.18
# 科技29支, 热度变化幅度-11.15%, 变化量-13.98, 收益率变化幅度-0.6%, 变化量-0.75
# 消费24支, 热度变化幅度0.26%, 变化量0.36, 收益率变化幅度-0.79%, 变化量-1.08
# 环保16支, 热度变化幅度-0.15%, 变化量-0.18, 收益率变化幅度-0.84%, 变化量-1.0
# 基建26支, 热度变化幅度-12.09%, 变化量-14.99, 收益率变化幅度-1.02%, 变化量-1.26
# 医药38支, 热度变化幅度3.71%, 变化量4.59, 收益率变化幅度-1.15%, 变化量-1.42
# 农业15支, 热度变化幅度-0.89%, 变化量-1.16, 收益率变化幅度-2.73%, 变化量-3.56
# 最近一周热门行业监测：2022-09-16至2022-09-23
# 基建26支, 热度变化幅度-12.09%, 变化量-14.99, 收益率变化幅度-1.02%, 变化量-1.26
# 科技29支, 热度变化幅度-11.15%, 变化量-13.98, 收益率变化幅度-0.6%, 变化量-0.75
# 电子39支, 热度变化幅度3.73%, 变化量5.14, 收益率变化幅度-0.02%, 变化量-0.02
# 医药38支, 热度变化幅度3.71%, 变化量4.59, 收益率变化幅度-1.15%, 变化量-1.42
# 投资61支, 热度变化幅度2.81%, 变化量4.43, 收益率变化幅度1.19%, 变化量1.88
# 制造78支, 热度变化幅度2.46%, 变化量3.23, 收益率变化幅度0.06%, 变化量0.07
# 能源18支, 热度变化幅度-1.62%, 变化量-2.21, 收益率变化幅度0.15%, 变化量0.2
# 农业15支, 热度变化幅度-0.89%, 变化量-1.16, 收益率变化幅度-2.73%, 变化量-3.56
# 新能源28支, 热度变化幅度0.4%, 变化量0.56, 收益率变化幅度0.5%, 变化量0.7
# 金融25支, 热度变化幅度-0.2%, 变化量-0.23, 收益率变化幅度-0.15%, 变化量-0.18
# 环保16支, 热度变化幅度-0.15%, 变化量-0.18, 收益率变化幅度-0.84%, 变化量-1.0
# 消费25支, 热度变化幅度0.11%, 变化量0.15, 收益率变化幅度-0.79%, 变化量-1.09
# 下一周监测：2022-09-23至2022-09-30
# 医药38支, 热度变化幅度12.87%, 变化量15.73, 收益率变化幅度0.3%, 变化量0.37
# 农业15支, 热度变化幅度0.1%, 变化量0.13, 收益率变化幅度-0.11%, 变化量-0.14
# 金融25支, 热度变化幅度-0.07%, 变化量-0.08, 收益率变化幅度-1.14%, 变化量-1.31
# 环保16支, 热度变化幅度-0.05%, 变化量-0.06, 收益率变化幅度-1.6%, 变化量-1.89
# 消费25支, 热度变化幅度-1.0%, 变化量-1.36, 收益率变化幅度-1.95%, 变化量-2.65
# 科技29支, 热度变化幅度2.72%, 变化量3.38, 收益率变化幅度-2.25%, 变化量-2.81
# 基建26支, 热度变化幅度-6.33%, 变化量-7.77, 收益率变化幅度-2.55%, 变化量-3.12
# 新能源28支, 热度变化幅度-0.4%, 变化量-0.55, 收益率变化幅度-2.55%, 变化量-3.55
# 能源18支, 热度变化幅度0.61%, 变化量0.84, 收益率变化幅度-2.88%, 变化量-3.94
# 制造78支, 热度变化幅度-5.92%, 变化量-7.76, 收益率变化幅度-2.9%, 变化量-3.81
# 电子39支, 热度变化幅度-8.28%, 变化量-11.42, 收益率变化幅度-4.43%, 变化量-6.11
# 投资61支, 热度变化幅度-8.89%, 变化量-14.18, 收益率变化幅度-4.5%, 变化量-7.17
# 最近一周热门行业监测：2022-09-23至2022-09-30
# 医药38支, 热度变化幅度12.87%, 变化量15.73, 收益率变化幅度0.3%, 变化量0.37
# 投资62支, 热度变化幅度-8.82%, 变化量-14.0, 收益率变化幅度-4.47%, 变化量-7.1
# 电子39支, 热度变化幅度-8.28%, 变化量-11.42, 收益率变化幅度-4.43%, 变化量-6.11
# 基建26支, 热度变化幅度-6.33%, 变化量-7.77, 收益率变化幅度-2.55%, 变化量-3.12
# 制造78支, 热度变化幅度-5.92%, 变化量-7.76, 收益率变化幅度-2.9%, 变化量-3.81
# 科技29支, 热度变化幅度2.72%, 变化量3.38, 收益率变化幅度-2.25%, 变化量-2.81
# 消费25支, 热度变化幅度-1.0%, 变化量-1.36, 收益率变化幅度-1.95%, 变化量-2.65
# 能源18支, 热度变化幅度0.61%, 变化量0.84, 收益率变化幅度-2.88%, 变化量-3.94
# 新能源28支, 热度变化幅度-0.4%, 变化量-0.55, 收益率变化幅度-2.55%, 变化量-3.55
# 农业15支, 热度变化幅度0.1%, 变化量0.13, 收益率变化幅度-0.11%, 变化量-0.14
# 金融25支, 热度变化幅度-0.07%, 变化量-0.08, 收益率变化幅度-1.14%, 变化量-1.31
# 环保16支, 热度变化幅度-0.05%, 变化量-0.06, 收益率变化幅度-1.6%, 变化量-1.89
# 下一周监测：2022-09-30至2022-10-14
# 新能源28支, 热度变化幅度11.77%, 变化量16.0, 收益率变化幅度6.93%, 变化量9.42
# 投资62支, 热度变化幅度7.92%, 变化量12.02, 收益率变化幅度5.28%, 变化量8.01
# 医药38支, 热度变化幅度3.44%, 变化量4.21, 收益率变化幅度4.92%, 变化量6.03
# 农业15支, 热度变化幅度10.38%, 变化量13.17, 收益率变化幅度4.91%, 变化量6.23
# 制造78支, 热度变化幅度4.44%, 变化量5.66, 收益率变化幅度4.71%, 变化量6.0
# 电子39支, 热度变化幅度3.57%, 变化量4.71, 收益率变化幅度4.47%, 变化量5.89
# 科技29支, 热度变化幅度4.5%, 变化量5.48, 收益率变化幅度4.4%, 变化量5.36
# 能源18支, 热度变化幅度-0.83%, 变化量-1.1, 收益率变化幅度3.72%, 变化量4.94
# 环保16支, 热度变化幅度0.44%, 变化量0.51, 收益率变化幅度2.74%, 变化量3.17
# 基建26支, 热度变化幅度-1.83%, 变化量-2.19, 收益率变化幅度2.01%, 变化量2.41
# 消费25支, 热度变化幅度9.12%, 变化量12.17, 收益率变化幅度1.72%, 变化量2.29
# 金融25支, 热度变化幅度0.25%, 变化量0.29, 收益率变化幅度0.95%, 变化量1.08
# 最近一周热门行业监测：2022-09-30至2022-10-14
# 新能源28支, 热度变化幅度11.77%, 变化量16.0, 收益率变化幅度6.93%, 变化量9.42
# 农业15支, 热度变化幅度10.38%, 变化量13.17, 收益率变化幅度4.91%, 变化量6.23
# 消费25支, 热度变化幅度9.12%, 变化量12.17, 收益率变化幅度1.72%, 变化量2.29
# 投资61支, 热度变化幅度8.03%, 变化量12.23, 收益率变化幅度5.31%, 变化量8.08
# 科技30支, 热度变化幅度4.48%, 变化量5.44, 收益率变化幅度4.47%, 变化量5.42
# 制造79支, 热度变化幅度4.36%, 变化量5.55, 收益率变化幅度4.72%, 变化量6.01
# 电子40支, 热度变化幅度3.46%, 变化量4.54, 收益率变化幅度4.44%, 变化量5.84
# 医药38支, 热度变化幅度3.44%, 变化量4.21, 收益率变化幅度4.92%, 变化量6.03
# 基建26支, 热度变化幅度-1.83%, 变化量-2.19, 收益率变化幅度2.01%, 变化量2.41
# 能源18支, 热度变化幅度-0.83%, 变化量-1.1, 收益率变化幅度3.72%, 变化量4.94
# 环保16支, 热度变化幅度0.44%, 变化量0.51, 收益率变化幅度2.74%, 变化量3.17
# 金融25支, 热度变化幅度0.25%, 变化量0.29, 收益率变化幅度0.95%, 变化量1.08
# 下一周监测：2022-10-14至2022-10-21
# 医药38支, 热度变化幅度15.09%, 变化量19.41, 收益率变化幅度0.61%, 变化量0.78
# 电子40支, 热度变化幅度14.32%, 变化量19.66, 收益率变化幅度0.14%, 变化量0.19
# 科技30支, 热度变化幅度-10.28%, 变化量-13.05, 收益率变化幅度-0.38%, 变化量-0.48
# 环保16支, 热度变化幅度2.1%, 变化量2.5, 收益率变化幅度-0.44%, 变化量-0.53
# 基建26支, 热度变化幅度1.71%, 变化量2.09, 收益率变化幅度-0.45%, 变化量-0.55
# 制造79支, 热度变化幅度0.17%, 变化量0.23, 收益率变化幅度-0.86%, 变化量-1.15
# 金融25支, 热度变化幅度-0.09%, 变化量-0.11, 收益率变化幅度-1.01%, 变化量-1.16
# 农业15支, 热度变化幅度-6.99%, 变化量-9.3, 收益率变化幅度-1.56%, 变化量-2.07
# 新能源28支, 热度变化幅度3.53%, 变化量5.13, 收益率变化幅度-1.73%, 变化量-2.51
# 消费25支, 热度变化幅度-3.24%, 变化量-4.4, 收益率变化幅度-2.13%, 变化量-2.9
# 投资61支, 热度变化幅度0.2%, 变化量0.32, 收益率变化幅度-2.15%, 变化量-3.45
# 能源18支, 热度变化幅度-0.89%, 变化量-1.23, 收益率变化幅度-3.01%, 变化量-4.15
# 最近一周热门行业监测：2022-10-14至2022-10-21
# 医药38支, 热度变化幅度15.09%, 变化量19.41, 收益率变化幅度0.61%, 变化量0.78
# 电子40支, 热度变化幅度14.32%, 变化量19.66, 收益率变化幅度0.14%, 变化量0.19
# 科技30支, 热度变化幅度-10.28%, 变化量-13.05, 收益率变化幅度-0.38%, 变化量-0.48
# 农业15支, 热度变化幅度-6.99%, 变化量-9.3, 收益率变化幅度-1.56%, 变化量-2.07
# 新能源28支, 热度变化幅度3.53%, 变化量5.13, 收益率变化幅度-1.73%, 变化量-2.51
# 消费25支, 热度变化幅度-3.24%, 变化量-4.4, 收益率变化幅度-2.13%, 变化量-2.9
# 环保16支, 热度变化幅度2.1%, 变化量2.5, 收益率变化幅度-0.44%, 变化量-0.53
# 基建26支, 热度变化幅度1.71%, 变化量2.09, 收益率变化幅度-0.45%, 变化量-0.55
# 能源18支, 热度变化幅度-0.89%, 变化量-1.23, 收益率变化幅度-3.01%, 变化量-4.15
# 投资61支, 热度变化幅度0.2%, 变化量0.32, 收益率变化幅度-2.15%, 变化量-3.45
# 制造79支, 热度变化幅度0.17%, 变化量0.23, 收益率变化幅度-0.86%, 变化量-1.15
# 金融25支, 热度变化幅度-0.09%, 变化量-0.11, 收益率变化幅度-1.01%, 变化量-1.16
# 下一周监测：2022-10-21至2022-10-28
# 医药38支, 热度变化幅度-7.54%, 变化量-9.76, 收益率变化幅度-0.56%, 变化量-0.73
# 科技30支, 热度变化幅度-4.92%, 变化量-6.22, 收益率变化幅度-1.2%, 变化量-1.52
# 金融25支, 热度变化幅度0.12%, 变化量0.13, 收益率变化幅度-1.96%, 变化量-2.22
# 环保16支, 热度变化幅度-1.12%, 变化量-1.33, 收益率变化幅度-2.01%, 变化量-2.38
# 基建26支, 热度变化幅度-2.49%, 变化量-3.02, 收益率变化幅度-2.02%, 变化量-2.46
# 电子40支, 热度变化幅度-8.93%, 变化量-12.27, 收益率变化幅度-2.08%, 变化量-2.86
# 制造79支, 热度变化幅度-4.15%, 变化量-5.48, 收益率变化幅度-2.15%, 变化量-2.84
# 农业15支, 热度变化幅度-1.18%, 变化量-1.55, 收益率变化幅度-2.22%, 变化量-2.91
# 新能源28支, 热度变化幅度-12.04%, 变化量-17.21, 收益率变化幅度-2.77%, 变化量-3.96
# 投资61支, 热度变化幅度-1.23%, 变化量-1.93, 收益率变化幅度-2.92%, 变化量-4.59
# 能源18支, 热度变化幅度0.1%, 变化量0.13, 收益率变化幅度-3.25%, 变化量-4.35
# 消费25支, 热度变化幅度-2.09%, 变化量-2.78, 收益率变化幅度-3.54%, 变化量-4.71
# 最近一周热门行业监测：2022-10-21至2022-10-28
# 新能源29支, 热度变化幅度-12.34%, 变化量-17.68, 收益率变化幅度-2.83%, 变化量-4.05
# 电子40支, 热度变化幅度-8.93%, 变化量-12.27, 收益率变化幅度-2.08%, 变化量-2.86
# 医药38支, 热度变化幅度-7.54%, 变化量-9.76, 收益率变化幅度-0.56%, 变化量-0.73
# 科技30支, 热度变化幅度-4.92%, 变化量-6.22, 收益率变化幅度-1.2%, 变化量-1.52
# 制造79支, 热度变化幅度-4.15%, 变化量-5.48, 收益率变化幅度-2.15%, 变化量-2.84
# 基建27支, 热度变化幅度-2.49%, 变化量-3.02, 收益率变化幅度-2.04%, 变化量-2.47
# 消费25支, 热度变化幅度-2.09%, 变化量-2.78, 收益率变化幅度-3.54%, 变化量-4.71
# 投资62支, 热度变化幅度-1.64%, 变化量-2.57, 收益率变化幅度-2.92%, 变化量-4.56
# 农业15支, 热度变化幅度-1.18%, 变化量-1.55, 收益率变化幅度-2.22%, 变化量-2.91
# 环保16支, 热度变化幅度-1.12%, 变化量-1.33, 收益率变化幅度-2.01%, 变化量-2.38
# 金融25支, 热度变化幅度0.12%, 变化量0.13, 收益率变化幅度-1.96%, 变化量-2.22
# 能源18支, 热度变化幅度0.1%, 变化量0.13, 收益率变化幅度-3.25%, 变化量-4.35
# 下一周监测：2022-10-28至2022-11-04
# 消费25支, 热度变化幅度6.77%, 变化量8.69, 收益率变化幅度5.51%, 变化量7.06
# 制造79支, 热度变化幅度2.4%, 变化量3.11, 收益率变化幅度4.53%, 变化量5.85
# 新能源29支, 热度变化幅度-2.09%, 变化量-2.91, 收益率变化幅度4.46%, 变化量6.21
# 能源18支, 热度变化幅度0.23%, 变化量0.3, 收益率变化幅度4.07%, 变化量5.27
# 科技30支, 热度变化幅度5.85%, 变化量7.3, 收益率变化幅度3.43%, 变化量4.29
# 投资62支, 热度变化幅度-2.19%, 变化量-3.33, 收益率变化幅度3.22%, 变化量4.88
# 电子40支, 热度变化幅度-5.71%, 变化量-7.68, 收益率变化幅度2.84%, 变化量3.83
# 农业15支, 热度变化幅度0.51%, 变化量0.66, 收益率变化幅度2.82%, 变化量3.62
# 环保16支, 热度变化幅度0.5%, 变化量0.57, 收益率变化幅度2.66%, 变化量3.08
# 基建27支, 热度变化幅度-1.06%, 变化量-1.26, 收益率变化幅度2.2%, 变化量2.61
# 医药38支, 热度变化幅度-3.17%, 变化量-4.07, 收益率变化幅度1.76%, 变化量2.26
# 金融25支, 热度变化幅度0.2%, 变化量0.23, 收益率变化幅度1.15%, 变化量1.28
# 最近一周热门行业监测：2022-10-28至2022-11-04
# 消费25支, 热度变化幅度6.77%, 变化量8.69, 收益率变化幅度5.51%, 变化量7.06
# 科技30支, 热度变化幅度5.85%, 变化量7.3, 收益率变化幅度3.43%, 变化量4.29
# 电子40支, 热度变化幅度-5.71%, 变化量-7.68, 收益率变化幅度2.84%, 变化量3.83
# 医药38支, 热度变化幅度-3.17%, 变化量-4.07, 收益率变化幅度1.76%, 变化量2.26
# 制造79支, 热度变化幅度2.4%, 变化量3.11, 收益率变化幅度4.53%, 变化量5.85
# 新能源30支, 热度变化幅度-2.33%, 变化量-3.23, 收益率变化幅度4.5%, 变化量6.24
# 投资62支, 热度变化幅度-2.19%, 变化量-3.33, 收益率变化幅度3.22%, 变化量4.88
# 基建27支, 热度变化幅度-1.06%, 变化量-1.26, 收益率变化幅度2.2%, 变化量2.61
# 农业15支, 热度变化幅度0.51%, 变化量0.66, 收益率变化幅度2.82%, 变化量3.62
# 环保16支, 热度变化幅度0.5%, 变化量0.57, 收益率变化幅度2.66%, 变化量3.08
# 金融26支, 热度变化幅度0.24%, 变化量0.26, 收益率变化幅度1.12%, 变化量1.24
# 能源19支, 热度变化幅度0.16%, 变化量0.21, 收益率变化幅度3.97%, 变化量5.12
# 下一周监测：2022-11-04至2022-11-11
# 基建27支, 热度变化幅度1.79%, 变化量2.18, 收益率变化幅度1.71%, 变化量2.07
# 医药38支, 热度变化幅度21.47%, 变化量28.1, 收益率变化幅度1.19%, 变化量1.56
# 能源19支, 热度变化幅度0.14%, 变化量0.18, 收益率变化幅度0.8%, 变化量1.07
# 金融26支, 热度变化幅度-0.35%, 变化量-0.39, 收益率变化幅度0.6%, 变化量0.68
# 环保16支, 热度变化幅度3.01%, 变化量3.59, 收益率变化幅度0.56%, 变化量0.67
# 科技30支, 热度变化幅度9.06%, 变化量11.7, 收益率变化幅度0.04%, 变化量0.06
# 农业15支, 热度变化幅度-1.55%, 变化量-2.04, 收益率变化幅度-0.05%, 变化量-0.07
# 投资62支, 热度变化幅度-4.68%, 变化量-7.34, 收益率变化幅度-0.19%, 变化量-0.31
# 消费25支, 热度变化幅度-5.12%, 变化量-6.92, 收益率变化幅度-0.29%, 变化量-0.4
# 制造79支, 热度变化幅度-1.53%, 变化量-2.06, 收益率变化幅度-1.24%, 变化量-1.68
# 电子40支, 热度变化幅度-3.2%, 变化量-4.42, 收益率变化幅度-1.28%, 变化量-1.77
# 新能源30支, 热度变化幅度-3.98%, 变化量-5.77, 收益率变化幅度-2.83%, 变化量-4.1
# 最近一周热门行业监测：2022-11-04至2022-11-11
# 医药38支, 热度变化幅度21.47%, 变化量28.1, 收益率变化幅度1.19%, 变化量1.56
# 科技30支, 热度变化幅度9.06%, 变化量11.7, 收益率变化幅度0.04%, 变化量0.06
# 消费25支, 热度变化幅度-5.12%, 变化量-6.92, 收益率变化幅度-0.29%, 变化量-0.4
# 投资63支, 热度变化幅度-4.65%, 变化量-7.27, 收益率变化幅度-0.21%, 变化量-0.32
# 新能源33支, 热度变化幅度-3.77%, 变化量-5.39, 收益率变化幅度-2.65%, 变化量-3.79
# 电子40支, 热度变化幅度-3.2%, 变化量-4.42, 收益率变化幅度-1.28%, 变化量-1.77
# 环保16支, 热度变化幅度3.01%, 变化量3.59, 收益率变化幅度0.56%, 变化量0.67
# 基建28支, 热度变化幅度1.66%, 变化量2.02, 收益率变化幅度1.56%, 变化量1.89
# 制造81支, 热度变化幅度-1.6%, 变化量-2.17, 收益率变化幅度-1.21%, 变化量-1.63
# 农业15支, 热度变化幅度-1.55%, 变化量-2.04, 收益率变化幅度-0.05%, 变化量-0.07
# 金融26支, 热度变化幅度-0.35%, 变化量-0.39, 收益率变化幅度0.6%, 变化量0.68
# 能源19支, 热度变化幅度0.14%, 变化量0.18, 收益率变化幅度0.8%, 变化量1.07
# 下一周监测：2022-11-11至2022-11-18
# 医药38支, 热度变化幅度37.6%, 变化量49.81, 收益率变化幅度1.94%, 变化量2.56
# 金融26支, 热度变化幅度0.49%, 变化量0.56, 收益率变化幅度-1.92%, 变化量-2.17
# 科技30支, 热度变化幅度-2.07%, 变化量-2.68, 收益率变化幅度-2.39%, 变化量-3.09
# 环保16支, 热度变化幅度-2.5%, 变化量-2.99, 收益率变化幅度-2.4%, 变化量-2.88
# 农业15支, 热度变化幅度0.02%, 变化量0.02, 收益率变化幅度-2.53%, 变化量-3.34
# 电子40支, 热度变化幅度-1.51%, 变化量-2.06, 收益率变化幅度-2.79%, 变化量-3.81
# 消费25支, 热度变化幅度0.33%, 变化量0.44, 收益率变化幅度-3.01%, 变化量-4.06
# 制造81支, 热度变化幅度6.07%, 变化量8.1, 收益率变化幅度-3.06%, 变化量-4.08
# 基建28支, 热度变化幅度0.6%, 变化量0.74, 收益率变化幅度-3.38%, 变化量-4.18
# 能源19支, 热度变化幅度-0.13%, 变化量-0.18, 收益率变化幅度-4.07%, 变化量-5.5
# 新能源33支, 热度变化幅度-1.11%, 变化量-1.55, 收益率变化幅度-4.76%, 变化量-6.63
# 投资63支, 热度变化幅度2.98%, 变化量4.65, 收益率变化幅度-5.05%, 变化量-7.87
# 最近一周热门行业监测：2022-11-11至2022-11-18
# 医药38支, 热度变化幅度37.6%, 变化量49.81, 收益率变化幅度1.94%, 变化量2.56
# 制造83支, 热度变化幅度5.6%, 变化量7.46, 收益率变化幅度-3.04%, 变化量-4.06
# 投资65支, 热度变化幅度2.77%, 变化量4.3, 收益率变化幅度-5.01%, 变化量-7.77
# 环保16支, 热度变化幅度-2.5%, 变化量-2.99, 收益率变化幅度-2.4%, 变化量-2.88
# 科技31支, 热度变化幅度-2.49%, 变化量-3.23, 收益率变化幅度-2.46%, 变化量-3.18
# 电子40支, 热度变化幅度-1.51%, 变化量-2.06, 收益率变化幅度-2.79%, 变化量-3.81
# 新能源33支, 热度变化幅度-1.11%, 变化量-1.55, 收益率变化幅度-4.76%, 变化量-6.63
# 基建28支, 热度变化幅度0.6%, 变化量0.74, 收益率变化幅度-3.38%, 变化量-4.18
# 金融26支, 热度变化幅度0.49%, 变化量0.56, 收益率变化幅度-1.92%, 变化量-2.17
# 消费25支, 热度变化幅度0.33%, 变化量0.44, 收益率变化幅度-3.01%, 变化量-4.06
# 能源19支, 热度变化幅度-0.13%, 变化量-0.18, 收益率变化幅度-4.07%, 变化量-5.5
# 农业15支, 热度变化幅度0.02%, 变化量0.02, 收益率变化幅度-2.53%, 变化量-3.34
# 下一周监测：2022-11-18至2022-11-25
# 能源19支, 热度变化幅度-0.77%, 变化量-1.0, 收益率变化幅度1.94%, 变化量2.51
# 基建28支, 热度变化幅度5.99%, 变化量7.15, 收益率变化幅度1.33%, 变化量1.58
# 金融26支, 热度变化幅度-0.52%, 变化量-0.57, 收益率变化幅度1.26%, 变化量1.4
# 环保16支, 热度变化幅度8.46%, 变化量9.89, 收益率变化幅度1.04%, 变化量1.22
# 投资65支, 热度变化幅度7.16%, 变化量10.56, 收益率变化幅度0.82%, 变化量1.21
# 制造83支, 热度变化幅度9.09%, 变化量11.76, 收益率变化幅度-0.01%, 变化量-0.02
# 消费25支, 热度变化幅度-3.59%, 变化量-4.7, 收益率变化幅度-0.26%, 变化量-0.35
# 农业15支, 热度变化幅度-1.04%, 变化量-1.33, 收益率变化幅度-0.32%, 变化量-0.41
# 新能源33支, 热度变化幅度4.22%, 变化量5.6, 收益率变化幅度-0.32%, 变化量-0.43
# 电子40支, 热度变化幅度3.3%, 变化量4.39, 收益率变化幅度-0.33%, 变化量-0.44
# 科技31支, 热度变化幅度-10.1%, 变化量-12.74, 收益率变化幅度-0.7%, 变化量-0.89
# 医药38支, 热度变化幅度-5.07%, 变化量-6.85, 收益率变化幅度-1.72%, 变化量-2.32
# 最近一周热门行业监测：2022-11-18至2022-11-25
# 科技31支, 热度变化幅度-10.1%, 变化量-12.74, 收益率变化幅度-0.7%, 变化量-0.89
# 环保16支, 热度变化幅度8.46%, 变化量9.89, 收益率变化幅度1.04%, 变化量1.22
# 农业15支, 热度变化幅度1.97%, 变化量2.52, 收益率变化幅度1.76%, 变化量2.25
# 基建28支, 热度变化幅度-1.55%, 变化量-1.87, 收益率变化幅度1.66%, 变化量2.0
# 制造83支, 热度变化幅度1.32%, 变化量1.7, 收益率变化幅度2.38%, 变化量3.06
# 科技32支, 热度变化幅度0.71%, 变化量0.89, 收益率变化幅度2.47%, 变化量3.1
# 金融26支, 热度变化幅度0.44%, 变化量0.49, 收益率变化幅度0.85%, 变化量0.96
# 下一周监测：2022-12-02至2022-12-09
# 环保16支, 热度变化幅度1.84%, 变化量2.22, 收益率变化幅度0.93%, 变化量1.11
# 基建28支, 热度变化幅度0.21%, 变化量0.26, 收益率变化幅度0.84%, 变化量1.04
# 电子40支, 热度变化幅度9.86%, 变化量13.19, 收益率变化幅度0.24%, 变化量0.32
# 消费26支, 热度变化幅度1.55%, 变化量2.08, 收益率变化幅度0.17%, 变化量0.23
# 金融26支, 热度变化幅度-0.25%, 变化量-0.28, 收益率变化幅度0.03%, 变化量0.04
# 投资68支, 热度变化幅度0.85%, 变化量1.28, 收益率变化幅度-0.18%, 变化量-0.28
# 农业15支, 热度变化幅度-0.93%, 变化量-1.21, 收益率变化幅度-1.05%, 变化量-1.37
# 制造83支, 热度变化幅度-12.3%, 变化量-16.22, 收益率变化幅度-1.16%, 变化量-1.53
# 科技32支, 热度变化幅度4.12%, 变化量5.29, 收益率变化幅度-1.19%, 变化量-1.53
# 新能源38支, 热度变化幅度0.94%, 变化量1.25, 收益率变化幅度-1.2%, 变化量-1.61
# 医药39支, 热度变化幅度-10.3%, 变化量-14.37, 收益率变化幅度-1.95%, 变化量-2.72
# 能源19支, 热度变化幅度-3.48%, 变化量-4.71, 收益率变化幅度-1.96%, 变化量-2.66
# 最近一周热门行业监测：2022-12-02至2022-12-09
# 制造84支, 热度变化幅度-12.22%, 变化量-16.1, 收益率变化幅度-1.16%, 变化量-1.53
# 医药39支, 热度变化幅度-10.3%, 变化量-14.37, 收益率变化幅度-1.95%, 变化量-2.72
# 电子40支, 热度变化幅度9.86%, 变化量13.19, 收益率变化幅度0.24%, 变化量0.32
# 科技32支, 热度变化幅度4.12%, 变化量5.29, 收益率变化幅度-1.19%, 变化量-1.53
# 能源19支, 热度变化幅度-3.48%, 变化量-4.71, 收益率变化幅度-1.96%, 变化量-2.66
# 环保16支, 热度变化幅度1.84%, 变化量2.22, 收益率变化幅度0.93%, 变化量1.11
# 消费26支, 热度变化幅度1.55%, 变化量2.08, 收益率变化幅度0.17%, 变化量0.23
# 新能源38支, 热度变化幅度0.94%, 变化量1.25, 收益率变化幅度-1.2%, 变化量-1.61
# 农业16支, 热度变化幅度-0.93%, 变化量-1.2, 收益率变化幅度-1.06%, 变化量-1.37
# 金融26支, 热度变化幅度-0.25%, 变化量-0.28, 收益率变化幅度0.03%, 变化量0.04
# 投资69支, 热度变化幅度0.25%, 变化量0.37, 收益率变化幅度-0.19%, 变化量-0.29
# 基建28支, 热度变化幅度0.21%, 变化量0.26, 收益率变化幅度0.84%, 变化量1.04
# 下一周监测：2022-12-09至2022-12-16
# 农业16支, 热度变化幅度0.36%, 变化量0.47, 收益率变化幅度-1.4%, 变化量-1.79
# 科技32支, 热度变化幅度-4.92%, 变化量-6.24, 收益率变化幅度-1.87%, 变化量-2.38
# 金融26支, 热度变化幅度-0.44%, 变化量-0.5, 收益率变化幅度-2.0%, 变化量-2.26
# 消费26支, 热度变化幅度-0.78%, 变化量-1.04, 收益率变化幅度-2.37%, 变化量-3.18
# 基建28支, 热度变化幅度-4.29%, 变化量-5.32, 收益率变化幅度-2.62%, 变化量-3.25
# 医药39支, 热度变化幅度-23.0%, 变化量-31.47, 收益率变化幅度-2.74%, 变化量-3.74
# 环保16支, 热度变化幅度14.55%, 变化量17.67, 收益率变化幅度-2.88%, 变化量-3.5
# 制造84支, 热度变化幅度-2.14%, 变化量-2.79, 收益率变化幅度-3.03%, 变化量-3.95
# 能源19支, 热度变化幅度-0.97%, 变化量-1.29, 收益率变化幅度-3.12%, 变化量-4.14
# 电子40支, 热度变化幅度-1.28%, 变化量-1.71, 收益率变化幅度-3.52%, 变化量-4.73
# 投资69支, 热度变化幅度-5.67%, 变化量-8.55, 收益率变化幅度-3.96%, 变化量-5.97
# 新能源38支, 热度变化幅度-4.02%, 变化量-5.31, 收益率变化幅度-3.98%, 变化量-5.26
# 最近一周热门行业监测：2022-12-09至2022-12-16
# 医药39支, 热度变化幅度-23.0%, 变化量-31.47, 收益率变化幅度-2.74%, 变化量-3.74
# 环保16支, 热度变化幅度14.55%, 变化量17.67, 收益率变化幅度-2.88%, 变化量-3.5
# 投资69支, 热度变化幅度-5.67%, 变化量-8.55, 收益率变化幅度-3.96%, 变化量-5.97
# 科技32支, 热度变化幅度-4.92%, 变化量-6.24, 收益率变化幅度-1.87%, 变化量-2.38
# 基建28支, 热度变化幅度-4.29%, 变化量-5.32, 收益率变化幅度-2.62%, 变化量-3.25
# 新能源38支, 热度变化幅度-4.02%, 变化量-5.31, 收益率变化幅度-3.98%, 变化量-5.26
# 制造86支, 热度变化幅度-2.3%, 变化量-3.0, 收益率变化幅度-3.03%, 变化量-3.95
# 电子40支, 热度变化幅度-1.28%, 变化量-1.71, 收益率变化幅度-3.52%, 变化量-4.73
# 能源19支, 热度变化幅度-0.97%, 变化量-1.29, 收益率变化幅度-3.12%, 变化量-4.14
# 消费26支, 热度变化幅度-0.78%, 变化量-1.04, 收益率变化幅度-2.37%, 变化量-3.18
# 金融26支, 热度变化幅度-0.44%, 变化量-0.5, 收益率变化幅度-2.0%, 变化量-2.26
# 农业16支, 热度变化幅度0.36%, 变化量0.47, 收益率变化幅度-1.4%, 变化量-1.79
# 下一周监测：2022-12-16至2022-12-23
# 环保16支, 热度变化幅度-18.48%, 变化量-21.8, 收益率变化幅度-1.65%, 变化量-1.95
# 科技32支, 热度变化幅度7.18%, 变化量8.94, 收益率变化幅度-1.8%, 变化量-2.24
# 金融26支, 热度变化幅度0.14%, 变化量0.16, 收益率变化幅度-1.85%, 变化量-2.06
# 消费26支, 热度变化幅度1.7%, 变化量2.23, 收益率变化幅度-1.96%, 变化量-2.56
# 农业16支, 热度变化幅度5.38%, 变化量6.79, 收益率变化幅度-2.18%, 变化量-2.76
# 基建28支, 热度变化幅度-1.71%, 变化量-2.06, 收益率变化幅度-2.26%, 变化量-2.73
# 电子40支, 热度变化幅度-0.6%, 变化量-0.77, 收益率变化幅度-2.5%, 变化量-3.24
# 制造86支, 热度变化幅度-1.55%, 变化量-1.96, 收益率变化幅度-2.52%, 变化量-3.18
# 新能源38支, 热度变化幅度8.68%, 变化量11.02, 收益率变化幅度-2.63%, 变化量-3.34
# 能源19支, 热度变化幅度-0.19%, 变化量-0.25, 收益率变化幅度-3.31%, 变化量-4.26
# 医药39支, 热度变化幅度-7.01%, 变化量-9.33, 收益率变化幅度-3.72%, 变化量-4.95
# 投资69支, 热度变化幅度-0.76%, 变化量-1.09, 收益率变化幅度-4.01%, 变化量-5.8
# 最近一周热门行业监测：2022-12-16至2022-12-23
# 环保16支, 热度变化幅度-18.48%, 变化量-21.8, 收益率变化幅度-1.65%, 变化量-1.95
# 新能源38支, 热度变化幅度8.68%, 变化量11.02, 收益率变化幅度-2.63%, 变化量-3.34
# 科技32支, 热度变化幅度7.18%, 变化量8.94, 收益率变化幅度-1.8%, 变化量-2.24
# 医药39支, 热度变化幅度-7.01%, 变化量-9.33, 收益率变化幅度-3.72%, 变化量-4.95
# 农业16支, 热度变化幅度5.38%, 变化量6.79, 收益率变化幅度-2.18%, 变化量-2.76
# 基建28支, 热度变化幅度-1.71%, 变化量-2.06, 收益率变化幅度-2.26%, 变化量-2.73
# 消费26支, 热度变化幅度1.7%, 变化量2.23, 收益率变化幅度-1.96%, 变化量-2.56
# 制造86支, 热度变化幅度-1.55%, 变化量-1.96, 收益率变化幅度-2.52%, 变化量-3.18
# 投资69支, 热度变化幅度-0.76%, 变化量-1.09, 收益率变化幅度-4.01%, 变化量-5.8
# 电子42支, 热度变化幅度-0.71%, 变化量-0.92, 收益率变化幅度-2.59%, 变化量-3.34
# 能源19支, 热度变化幅度-0.19%, 变化量-0.25, 收益率变化幅度-3.31%, 变化量-4.26
# 金融26支, 热度变化幅度0.14%, 变化量0.16, 收益率变化幅度-1.85%, 变化量-2.06
# 下一周监测：2022-12-23至2022-12-30
# 新能源38支, 热度变化幅度-1.85%, 变化量-2.29, 收益率变化幅度1.78%, 变化量2.21
# 环保16支, 热度变化幅度7.06%, 变化量8.19, 收益率变化幅度1.64%, 变化量1.9
# 能源19支, 热度变化幅度0.68%, 变化量0.84, 收益率变化幅度1.6%, 变化量2.0
# 科技32支, 热度变化幅度8.92%, 变化量10.91, 收益率变化幅度1.54%, 变化量1.89
# 金融26支, 热度变化幅度0.05%, 变化量0.06, 收益率变化幅度1.38%, 变化量1.51
# 制造86支, 热度变化幅度-2.85%, 变化量-3.52, 收益率变化幅度1.02%, 变化量1.26
# 电子42支, 热度变化幅度4.01%, 变化量5.04, 收益率变化幅度0.78%, 变化量0.99
# 农业16支, 热度变化幅度-5.21%, 变化量-6.43, 收益率变化幅度0.74%, 变化量0.92
# 投资69支, 热度变化幅度1.68%, 变化量2.34, 收益率变化幅度0.72%, 变化量1.0
# 基建28支, 热度变化幅度0.14%, 变化量0.17, 收益率变化幅度0.71%, 变化量0.84
# 消费26支, 热度变化幅度-4.52%, 变化量-5.81, 收益率变化幅度-0.02%, 变化量-0.02
# 医药39支, 热度变化幅度0.5%, 变化量0.64, 收益率变化幅度-0.25%, 变化量-0.33
# 最近一周热门行业监测：2022-12-23至2022-12-30
# 科技32支, 热度变化幅度8.92%, 变化量10.91, 收益率变化幅度1.54%, 变化量1.89
# 环保16支, 热度变化幅度7.06%, 变化量8.19, 收益率变化幅度1.64%, 变化量1.9
# 农业16支, 热度变化幅度-5.21%, 变化量-6.43, 收益率变化幅度0.74%, 变化量0.92
# 消费26支, 热度变化幅度-4.52%, 变化量-5.81, 收益率变化幅度-0.02%, 变化量-0.02
# 电子43支, 热度变化幅度3.89%, 变化量4.89, 收益率变化幅度0.78%, 变化量0.98
# 医药41支, 热度变化幅度-3.27%, 变化量-4.19, 收益率变化幅度-0.35%, 变化量-0.44
# 制造86支, 热度变化幅度-2.85%, 变化量-3.52, 收益率变化幅度1.02%, 变化量1.26
# 新能源38支, 热度变化幅度-1.85%, 变化量-2.29, 收益率变化幅度1.78%, 变化量2.21
# 投资73支, 热度变化幅度1.49%, 变化量2.05, 收益率变化幅度0.82%, 变化量1.13
# 能源19支, 热度变化幅度0.68%, 变化量0.84, 收益率变化幅度1.6%, 变化量2.0
# 基建28支, 热度变化幅度0.14%, 变化量0.17, 收益率变化幅度0.71%, 变化量0.84
# 金融25支, 热度变化幅度0.06%, 变化量0.06, 收益率变化幅度1.43%, 变化量1.56
# 下一周监测：2022-12-30至2023-01-06
# 新能源38支, 热度变化幅度5.4%, 变化量6.8, 收益率变化幅度4.8%, 变化量6.04
# 投资73支, 热度变化幅度0.53%, 变化量0.74, 收益率变化幅度4.39%, 变化量6.11
# 制造86支, 热度变化幅度14.63%, 变化量18.23, 收益率变化幅度3.65%, 变化量4.55
# 科技32支, 热度变化幅度2.79%, 变化量3.47, 收益率变化幅度3.53%, 变化量4.38
# 医药41支, 热度变化幅度-16.98%, 变化量-21.68, 收益率变化幅度3.29%, 变化量4.21
# 能源19支, 热度变化幅度0.28%, 变化量0.35, 收益率变化幅度3.2%, 变化量4.05
# 电子43支, 热度变化幅度-3.36%, 变化量-4.25, 收益率变化幅度2.5%, 变化量3.17
# 消费26支, 热度变化幅度-4.34%, 变化量-5.58, 收益率变化幅度2.12%, 变化量2.73
# 基建28支, 热度变化幅度2.27%, 变化量2.69, 收益率变化幅度2.05%, 变化量2.43
# 金融25支, 热度变化幅度0.18%, 变化量0.2, 收益率变化幅度1.51%, 变化量1.67
# 环保16支, 热度变化幅度-13.14%, 变化量-15.5, 收益率变化幅度0.89%, 变化量1.04
# 农业16支, 热度变化幅度-1.43%, 变化量-1.78, 收益率变化幅度0.81%, 变化量1.0
# 最近一周热门行业监测：2022-12-30至2023-01-06
# 医药41支, 热度变化幅度-16.98%, 变化量-21.68, 收益率变化幅度3.29%, 变化量4.21
# 制造87支, 热度变化幅度14.42%, 变化量17.94, 收益率变化幅度3.67%, 变化量4.57
# 环保16支, 热度变化幅度-13.14%, 变化量-15.5, 收益率变化幅度0.89%, 变化量1.04
# 新能源39支, 热度变化幅度5.21%, 变化量6.56, 收益率变化幅度4.99%, 变化量6.28
# 消费26支, 热度变化幅度-4.34%, 变化量-5.58, 收益率变化幅度2.12%, 变化量2.73
# 电子43支, 热度变化幅度-3.36%, 变化量-4.25, 收益率变化幅度2.5%, 变化量3.17
# 科技33支, 热度变化幅度2.53%, 变化量3.14, 收益率变化幅度3.52%, 变化量4.37
# 基建28支, 热度变化幅度2.27%, 变化量2.69, 收益率变化幅度2.05%, 变化量2.43
# 农业16支, 热度变化幅度-1.43%, 变化量-1.78, 收益率变化幅度0.81%, 变化量1.0
# 投资73支, 热度变化幅度0.53%, 变化量0.74, 收益率变化幅度4.39%, 变化量6.11
# 能源19支, 热度变化幅度0.28%, 变化量0.35, 收益率变化幅度3.2%, 变化量4.05
# 金融26支, 热度变化幅度0.18%, 变化量0.2, 收益率变化幅度1.51%, 变化量1.66
# 下一周监测：2023-01-06至2023-01-13
# 消费26支, 热度变化幅度6.9%, 变化量9.05, 收益率变化幅度1.3%, 变化量1.71
# 基建28支, 热度变化幅度9.56%, 变化量11.59, 收益率变化幅度1.04%, 变化量1.26
# 农业16支, 热度变化幅度0.25%, 变化量0.31, 收益率变化幅度0.83%, 变化量1.04
# 科技33支, 热度变化幅度-1.06%, 变化量-1.37, 收益率变化幅度0.6%, 变化量0.77
# 金融26支, 热度变化幅度-0.19%, 变化量-0.21, 收益率变化幅度0.22%, 变化量0.25
# 新能源39支, 热度变化幅度-6.11%, 变化量-8.08, 收益率变化幅度0.2%, 变化量0.26
# 电子43支, 热度变化幅度-2.23%, 变化量-2.89, 收益率变化幅度0.07%, 变化量0.08
# 医药41支, 热度变化幅度-9.03%, 变化量-11.91, 收益率变化幅度-0.14%, 变化量-0.18
# 投资73支, 热度变化幅度-3.19%, 变化量-4.63, 收益率变化幅度-0.19%, 变化量-0.27
# 制造87支, 热度变化幅度-8.03%, 变化量-10.36, 收益率变化幅度-0.24%, 变化量-0.31
# 能源19支, 热度变化幅度-0.49%, 变化量-0.64, 收益率变化幅度-0.41%, 变化量-0.53
# 环保16支, 热度变化幅度-0.23%, 变化量-0.28, 收益率变化幅度-0.72%, 变化量-0.85
# 最近一周热门行业监测：2023-01-06至2023-01-13
# 基建28支, 热度变化幅度9.56%, 变化量11.59, 收益率变化幅度1.04%, 变化量1.26
# 医药41支, 热度变化幅度-9.03%, 变化量-11.91, 收益率变化幅度-0.14%, 变化量-0.18
# 制造87支, 热度变化幅度-8.03%, 变化量-10.36, 收益率变化幅度-0.24%, 变化量-0.31
# 消费26支, 热度变化幅度6.9%, 变化量9.05, 收益率变化幅度1.3%, 变化量1.71
# 新能源39支, 热度变化幅度-6.11%, 变化量-8.08, 收益率变化幅度0.2%, 变化量0.26
# 投资73支, 热度变化幅度-3.19%, 变化量-4.63, 收益率变化幅度-0.19%, 变化量-0.27
# 电子43支, 热度变化幅度-2.23%, 变化量-2.89, 收益率变化幅度0.07%, 变化量0.08
# 科技33支, 热度变化幅度-1.06%, 变化量-1.37, 收益率变化幅度0.6%, 变化量0.77
# 能源19支, 热度变化幅度-0.49%, 变化量-0.64, 收益率变化幅度-0.41%, 变化量-0.53
# 农业16支, 热度变化幅度0.25%, 变化量0.31, 收益率变化幅度0.83%, 变化量1.04
# 环保16支, 热度变化幅度-0.23%, 变化量-0.28, 收益率变化幅度-0.72%, 变化量-0.85
# 金融26支, 热度变化幅度-0.19%, 变化量-0.21, 收益率变化幅度0.22%, 变化量0.25
# 下一周监测：2023-01-13至2023-01-20
# 投资73支, 热度变化幅度-1.83%, 变化量-2.65, 收益率变化幅度3.39%, 变化量4.91
# 科技33支, 热度变化幅度-9.64%, 变化量-12.46, 收益率变化幅度3.32%, 变化量4.29
# 能源19支, 热度变化幅度0.22%, 变化量0.28, 收益率变化幅度3.32%, 变化量4.31
# 电子43支, 热度变化幅度-0.17%, 变化量-0.23, 收益率变化幅度2.93%, 变化量3.81
# 新能源39支, 热度变化幅度-2.27%, 变化量-3.0, 收益率变化幅度2.65%, 变化量3.51
# 基建28支, 热度变化幅度-11.72%, 变化量-14.37, 收益率变化幅度2.18%, 变化量2.67
# 环保16支, 热度变化幅度-0.91%, 变化量-1.08, 收益率变化幅度2.17%, 变化量2.56
# 金融26支, 热度变化幅度2.66%, 变化量2.99, 收益率变化幅度2.15%, 变化量2.41
# 医药41支, 热度变化幅度-8.03%, 变化量-10.58, 收益率变化幅度1.86%, 变化量2.45
# 制造87支, 热度变化幅度-6.82%, 变化量-8.78, 收益率变化幅度1.8%, 变化量2.31
# 农业16支, 热度变化幅度-0.6%, 变化量-0.76, 收益率变化幅度1.57%, 变化量1.99
# 消费26支, 热度变化幅度-7.95%, 变化量-10.57, 收益率变化幅度1.38%, 变化量1.83
# 最近一周热门行业监测：2023-01-13至2023-01-20
# 基建28支, 热度变化幅度-11.72%, 变化量-14.37, 收益率变化幅度2.18%, 变化量2.67
# 科技33支, 热度变化幅度-9.64%, 变化量-12.46, 收益率变化幅度3.32%, 变化量4.29
# 消费26支, 热度变化幅度-7.95%, 变化量-10.57, 收益率变化幅度1.38%, 变化量1.83
# 医药42支, 热度变化幅度-7.92%, 变化量-10.42, 收益率变化幅度1.85%, 变化量2.43
# 制造89支, 热度变化幅度-6.91%, 变化量-8.89, 收益率变化幅度1.84%, 变化量2.37
# 金融26支, 热度变化幅度2.66%, 变化量2.99, 收益率变化幅度2.15%, 变化量2.41
# 新能源38支, 热度变化幅度-2.32%, 变化量-3.07, 收益率变化幅度2.72%, 变化量3.6
# 投资74支, 热度变化幅度-1.83%, 变化量-2.64, 收益率变化幅度3.41%, 变化量4.92
# 环保16支, 热度变化幅度-0.91%, 变化量-1.08, 收益率变化幅度2.17%, 变化量2.56
# 农业16支, 热度变化幅度-0.6%, 变化量-0.76, 收益率变化幅度1.57%, 变化量1.99
# 能源19支, 热度变化幅度0.22%, 变化量0.28, 收益率变化幅度3.32%, 变化量4.31
# 电子43支, 热度变化幅度-0.17%, 变化量-0.23, 收益率变化幅度2.93%, 变化量3.81
# 下一周监测：2023-01-20至2023-02-03
# 制造89支, 热度变化幅度15.61%, 变化量20.46, 收益率变化幅度2.85%, 变化量3.74
# 科技33支, 热度变化幅度0.66%, 变化量0.88, 收益率变化幅度2.79%, 变化量3.73
# 投资74支, 热度变化幅度6.4%, 变化量9.56, 收益率变化幅度2.18%, 变化量3.26
# 电子43支, 热度变化幅度0.77%, 变化量1.03, 收益率变化幅度2.05%, 变化量2.74
# 新能源38支, 热度变化幅度14.57%, 变化量19.81, 收益率变化幅度1.88%, 变化量2.56
# 环保16支, 热度变化幅度4.5%, 变化量5.43, 收益率变化幅度1.65%, 变化量1.99
# 医药42支, 热度变化幅度-0.62%, 变化量-0.83, 收益率变化幅度1.17%, 变化量1.57
# 能源19支, 热度变化幅度0.18%, 变化量0.24, 收益率变化幅度0.92%, 变化量1.24
# 基建28支, 热度变化幅度3.7%, 变化量4.63, 收益率变化幅度0.88%, 变化量1.1
# 消费26支, 热度变化幅度-0.16%, 变化量-0.21, 收益率变化幅度0.86%, 变化量1.16
# 农业16支, 热度变化幅度0.28%, 变化量0.36, 收益率变化幅度0.48%, 变化量0.62
# 金融26支, 热度变化幅度-2.16%, 变化量-2.47, 收益率变化幅度-1.22%, 变化量-1.4
# 最近一周热门行业监测：2023-01-20至2023-02-03
# 制造89支, 热度变化幅度15.61%, 变化量20.46, 收益率变化幅度2.85%, 变化量3.74
# 新能源38支, 热度变化幅度14.57%, 变化量19.81, 收益率变化幅度1.88%, 变化量2.56
# 投资76支, 热度变化幅度6.2%, 变化量9.22, 收益率变化幅度2.18%, 变化量3.24
# 环保17支, 热度变化幅度3.92%, 变化量4.79, 收益率变化幅度1.87%, 变化量2.28
# 基建29支, 热度变化幅度3.44%, 变化量4.3, 收益率变化幅度0.92%, 变化量1.15
# 金融26支, 热度变化幅度-2.16%, 变化量-2.47, 收益率变化幅度-1.22%, 变化量-1.4
# 电子43支, 热度变化幅度0.77%, 变化量1.03, 收益率变化幅度2.05%, 变化量2.74
# 科技33支, 热度变化幅度0.66%, 变化量0.88, 收益率变化幅度2.79%, 变化量3.73
# 医药42支, 热度变化幅度-0.62%, 变化量-0.83, 收益率变化幅度1.17%, 变化量1.57
# 农业16支, 热度变化幅度0.28%, 变化量0.36, 收益率变化幅度0.48%, 变化量0.62
# 能源19支, 热度变化幅度0.18%, 变化量0.24, 收益率变化幅度0.92%, 变化量1.24
# 消费26支, 热度变化幅度-0.16%, 变化量-0.21, 收益率变化幅度0.86%, 变化量1.16
# 下一周监测：2023-02-03至2023-02-10
# 环保17支, 热度变化幅度-0.81%, 变化量-1.01, 收益率变化幅度1.51%, 变化量1.87
# 电子43支, 热度变化幅度-2.41%, 变化量-3.29, 收益率变化幅度0.58%, 变化量0.79
# 消费26支, 热度变化幅度-0.39%, 变化量-0.53, 收益率变化幅度0.46%, 变化量0.62
# 农业16支, 热度变化幅度0.0%, 变化量0.0, 收益率变化幅度0.2%, 变化量0.26
# 基建29支, 热度变化幅度-1.02%, 变化量-1.29, 收益率变化幅度0.11%, 变化量0.14
# 制造89支, 热度变化幅度11.02%, 变化量14.85, 收益率变化幅度-0.05%, 变化量-0.07
# 金融26支, 热度变化幅度-0.52%, 变化量-0.58, 收益率变化幅度-0.32%, 变化量-0.36
# 科技33支, 热度变化幅度3.12%, 变化量4.28, 收益率变化幅度-0.66%, 变化量-0.9
# 投资76支, 热度变化幅度8.79%, 变化量13.35, 收益率变化幅度-0.72%, 变化量-1.09
# 能源19支, 热度变化幅度-0.91%, 变化量-1.23, 收益率变化幅度-0.73%, 变化量-0.99
# 医药42支, 热度变化幅度-6.99%, 变化量-9.46, 收益率变化幅度-1.01%, 变化量-1.37
# 新能源38支, 热度变化幅度-6.83%, 变化量-9.47, 收益率变化幅度-1.17%, 变化量-1.62
# 最近一周热门行业监测：2023-02-03至2023-02-10
# 制造89支, 热度变化幅度11.02%, 变化量14.85, 收益率变化幅度-0.05%, 变化量-0.07
# 投资76支, 热度变化幅度8.79%, 变化量13.35, 收益率变化幅度-0.72%, 变化量-1.09
# 医药42支, 热度变化幅度-6.99%, 变化量-9.46, 收益率变化幅度-1.01%, 变化量-1.37
# 新能源38支, 热度变化幅度-6.83%, 变化量-9.47, 收益率变化幅度-1.17%, 变化量-1.62
# 科技33支, 热度变化幅度3.12%, 变化量4.28, 收益率变化幅度-0.66%, 变化量-0.9
# 电子44支, 热度变化幅度-2.31%, 变化量-3.15, 收益率变化幅度0.6%, 变化量0.82
# 基建29支, 热度变化幅度-1.02%, 变化量-1.29, 收益率变化幅度0.11%, 变化量0.14
# 能源19支, 热度变化幅度-0.91%, 变化量-1.23, 收益率变化幅度-0.73%, 变化量-0.99
# 环保17支, 热度变化幅度-0.81%, 变化量-1.01, 收益率变化幅度1.51%, 变化量1.87
# 金融26支, 热度变化幅度-0.52%, 变化量-0.58, 收益率变化幅度-0.32%, 变化量-0.36
# 消费26支, 热度变化幅度-0.39%, 变化量-0.53, 收益率变化幅度0.46%, 变化量0.62
# 农业16支, 热度变化幅度0.0%, 变化量0.0, 收益率变化幅度0.2%, 变化量0.26
# 下一周监测：2023-02-10至2023-02-17
# 医药42支, 热度变化幅度28.57%, 变化量38.31, 收益率变化幅度0.73%, 变化量0.98
# 环保17支, 热度变化幅度2.06%, 变化量2.61, 收益率变化幅度-0.4%, 变化量-0.5
# 农业16支, 热度变化幅度0.04%, 变化量0.05, 收益率变化幅度-1.36%, 变化量-1.75
# 消费26支, 热度变化幅度1.84%, 变化量2.52, 收益率变化幅度-1.54%, 变化量-2.11
# 基建29支, 热度变化幅度-2.73%, 变化量-3.45, 收益率变化幅度-1.66%, 变化量-2.1
# 金融26支, 热度变化幅度-0.01%, 变化量-0.01, 收益率变化幅度-1.68%, 变化量-1.9
# 电子44支, 热度变化幅度3.96%, 变化量5.44, 收益率变化幅度-1.78%, 变化量-2.45
# 能源19支, 热度变化幅度0.28%, 变化量0.38, 收益率变化幅度-1.88%, 变化量-2.52
# 制造89支, 热度变化幅度-4.71%, 变化量-6.34, 收益率变化幅度-1.91%, 变化量-2.58
# 投资76支, 热度变化幅度-10.34%, 变化量-15.6, 收益率变化幅度-2.49%, 变化量-3.76
# 科技33支, 热度变化幅度5.33%, 变化量7.27, 收益率变化幅度-2.57%, 变化量-3.51
# 新能源38支, 热度变化幅度-8.02%, 变化量-10.99, 收益率变化幅度-3.66%, 变化量-5.01
# 最近一周热门行业监测：2023-02-10至2023-02-17
# 医药42支, 热度变化幅度28.57%, 变化量38.31, 收益率变化幅度0.73%, 变化量0.98
# 投资76支, 热度变化幅度-10.34%, 变化量-15.6, 收益率变化幅度-2.49%, 变化量-3.76
# 新能源38支, 热度变化幅度-8.02%, 变化量-10.99, 收益率变化幅度-3.66%, 变化量-5.01
# 科技33支, 热度变化幅度5.33%, 变化量7.27, 收益率变化幅度-2.57%, 变化量-3.51
# 制造89支, 热度变化幅度-4.71%, 变化量-6.34, 收益率变化幅度-1.91%, 变化量-2.58
# 电子44支, 热度变化幅度3.96%, 变化量5.44, 收益率变化幅度-1.78%, 变化量-2.45
# 基建29支, 热度变化幅度-2.73%, 变化量-3.45, 收益率变化幅度-1.66%, 变化量-2.1
# 环保17支, 热度变化幅度2.06%, 变化量2.61, 收益率变化幅度-0.4%, 变化量-0.5
# 消费26支, 热度变化幅度1.84%, 变化量2.52, 收益率变化幅度-1.54%, 变化量-2.11
# 能源19支, 热度变化幅度0.28%, 变化量0.38, 收益率变化幅度-1.88%, 变化量-2.52
# 农业16支, 热度变化幅度0.04%, 变化量0.05, 收益率变化幅度-1.36%, 变化量-1.75
# 金融26支, 热度变化幅度-0.01%, 变化量-0.01, 收益率变化幅度-1.68%, 变化量-1.9
# 下一周监测：2023-02-17至2023-02-24
# 能源19支, 热度变化幅度1.24%, 变化量1.64, 收益率变化幅度1.4%, 变化量1.84
# 电子44支, 热度变化幅度1.34%, 变化量1.8, 收益率变化幅度1.33%, 变化量1.79
# 新能源38支, 热度变化幅度7.55%, 变化量9.96, 收益率变化幅度1.2%, 变化量1.59
# 基建29支, 热度变化幅度-1.02%, 变化量-1.26, 收益率变化幅度1.14%, 变化量1.41
# 科技33支, 热度变化幅度-0.95%, 变化量-1.26, 收益率变化幅度1.02%, 变化量1.36
# 农业16支, 热度变化幅度0.02%, 变化量0.03, 收益率变化幅度0.95%, 变化量1.21
# 消费26支, 热度变化幅度-2.32%, 变化量-3.12, 收益率变化幅度0.86%, 变化量1.16
# 制造89支, 热度变化幅度-4.49%, 变化量-5.94, 收益率变化幅度0.72%, 变化量0.96
# 金融26支, 热度变化幅度0.3%, 变化量0.33, 收益率变化幅度0.43%, 变化量0.48
# 投资76支, 热度变化幅度1.97%, 变化量2.9, 收益率变化幅度0.3%, 变化量0.45
# 医药42支, 热度变化幅度-7.13%, 变化量-9.63, 收益率变化幅度-0.4%, 变化量-0.54
# 环保17支, 热度变化幅度-7.38%, 变化量-9.28, 收益率变化幅度-0.73%, 变化量-0.92
# 最近一周热门行业监测：2023-02-17至2023-02-24
# 科技35支, 热度变化幅度-10.17%, 变化量-13.88, 收益率变化幅度1.22%, 变化量1.67
# 新能源38支, 热度变化幅度7.55%, 变化量9.96, 收益率变化幅度1.2%, 变化量1.59
# 环保17支, 热度变化幅度-7.38%, 变化量-9.28, 收益率变化幅度-0.73%, 变化量-0.92
# 医药42支, 热度变化幅度-7.13%, 变化量-9.63, 收益率变化幅度-0.4%, 变化量-0.54
# 制造90支, 热度变化幅度-4.21%, 变化量-5.56, 收益率变化幅度0.73%, 变化量0.96
# 消费26支, 热度变化幅度-2.32%, 变化量-3.12, 收益率变化幅度0.86%, 变化量1.16
# 投资78支, 热度变化幅度1.78%, 变化量2.61, 收益率变化幅度0.3%, 变化量0.44
# 能源19支, 热度变化幅度1.24%, 变化量1.64, 收益率变化幅度1.4%, 变化量1.84
# 基建29支, 热度变化幅度-1.02%, 变化量-1.26, 收益率变化幅度1.14%, 变化量1.41
# 电子45支, 热度变化幅度0.93%, 变化量1.26, 收益率变化幅度1.33%, 变化量1.8
# 金融26支, 热度变化幅度0.3%, 变化量0.33, 收益率变化幅度0.43%, 变化量0.48
# 农业16支, 热度变化幅度0.02%, 变化量0.03, 收益率变化幅度0.95%, 变化量1.21
# 下一周监测：2023-02-24至2023-03-03
# 基建29支, 热度变化幅度3.94%, 变化量4.95, 收益率变化幅度2.46%, 变化量3.09
# 科技35支, 热度变化幅度14.92%, 变化量20.61, 收益率变化幅度2.11%, 变化量2.92
# 能源19支, 热度变化幅度1.9%, 变化量2.54, 收益率变化幅度1.24%, 变化量1.66
# 环保17支, 热度变化幅度2.83%, 变化量3.54, 收益率变化幅度1.2%, 变化量1.5
# 医药42支, 热度变化幅度3.43%, 变化量4.61, 收益率变化幅度0.91%, 变化量1.22
# 金融26支, 热度变化幅度-0.38%, 变化量-0.42, 收益率变化幅度0.86%, 变化量0.96
# 投资78支, 热度变化幅度-6.86%, 变化量-10.08, 收益率变化幅度0.4%, 变化量0.58
# 消费26支, 热度变化幅度-1.61%, 变化量-2.19, 收益率变化幅度0.1%, 变化量0.14
# 农业16支, 热度变化幅度-1.13%, 变化量-1.46, 收益率变化幅度-0.04%, 变化量-0.06
# 制造90支, 热度变化幅度-9.52%, 变化量-12.67, 收益率变化幅度-0.18%, 变化量-0.25
# 电子45支, 热度变化幅度9.54%, 变化量13.04, 收益率变化幅度-0.41%, 变化量-0.56
# 新能源38支, 热度变化幅度2.13%, 变化量2.85, 收益率变化幅度-0.7%, 变化量-0.94
# 最近一周热门行业监测：2023-02-24至2023-03-03
# 科技35支, 热度变化幅度14.92%, 变化量20.61, 收益率变化幅度2.11%, 变化量2.92
# 电子45支, 热度变化幅度9.54%, 变化量13.04, 收益率变化幅度-0.41%, 变化量-0.56
# 制造89支, 热度变化幅度-9.47%, 变化量-12.61, 收益率变化幅度-0.12%, 变化量-0.16
# 投资78支, 热度变化幅度-6.86%, 变化量-10.08, 收益率变化幅度0.4%, 变化量0.58
# 基建29支, 热度变化幅度3.94%, 变化量4.95, 收益率变化幅度2.46%, 变化量3.09
# 医药42支, 热度变化幅度3.43%, 变化量4.61, 收益率变化幅度0.91%, 变化量1.22
# 环保17支, 热度变化幅度2.83%, 变化量3.54, 收益率变化幅度1.2%, 变化量1.5
# 新能源38支, 热度变化幅度2.13%, 变化量2.85, 收益率变化幅度-0.7%, 变化量-0.94
# 能源19支, 热度变化幅度1.9%, 变化量2.54, 收益率变化幅度1.24%, 变化量1.66
# 消费26支, 热度变化幅度-1.61%, 变化量-2.19, 收益率变化幅度0.1%, 变化量0.14
# 农业16支, 热度变化幅度-1.13%, 变化量-1.46, 收益率变化幅度-0.04%, 变化量-0.06
# 金融26支, 热度变化幅度-0.38%, 变化量-0.42, 收益率变化幅度0.86%, 变化量0.96
# 下一周监测：2023-03-03至2023-03-10
# 电子45支, 热度变化幅度33.08%, 变化量45.05, 收益率变化幅度1.57%, 变化量2.14
# 科技35支, 热度变化幅度0.51%, 变化量0.72, 收益率变化幅度-0.37%, 变化量-0.52
# 医药42支, 热度变化幅度-9.6%, 变化量-13.04, 收益率变化幅度-0.42%, 变化量-0.57
# 农业16支, 热度变化幅度1.07%, 变化量1.38, 收益率变化幅度-1.06%, 变化量-1.37
# 基建29支, 热度变化幅度21.21%, 变化量27.29, 收益率变化幅度-1.22%, 变化量-1.56
# 环保17支, 热度变化幅度-1.62%, 变化量-2.05, 收益率变化幅度-1.27%, 变化量-1.6
# 新能源38支, 热度变化幅度-2.68%, 变化量-3.55, 收益率变化幅度-1.34%, 变化量-1.78
# ...
# 环保17支, 热度变化幅度-2.42%, 变化量-3.02, 收益率变化幅度-0.59%, 变化量-0.73
# 投资77支, 热度变化幅度0.99%, 变化量1.43, 收益率变化幅度-0.79%, 变化量-1.13
# 农业16支, 热度变化幅度0.8%, 变化量1.02, 收益率变化幅度0.52%, 变化量0.66
# 医药41支, 热度变化幅度0.78%, 变化量1.05, 收益率变化幅度-0.1%, 变化量-0.13
# 电子45支, 热度变化幅度-0.14%, 变化量-0.19, 收益率变化幅度1.76%, 变化量2.44
# 金融26支, 热度变化幅度-0.08%, 变化量-0.09, 收益率变化幅度-0.05%, 变化量-0.06
# 下一周监测：2023-03-17至2023-03-24
# 科技34支, 热度变化幅度-5.74%, 变化量-8.08, 收益率变化幅度2.49%, 变化量3.5
# 新能源38支, 热度变化幅度0.82%, 变化量1.05, 收益率变化幅度2.26%, 变化量2.89
# 制造87支, 热度变化幅度1.5%, 变化量1.94, 收益率变化幅度2.04%, 变化量2.64
# 投资77支, 热度变化幅度-1.51%, 变化量-2.15, 收益率变化幅度1.7%, 变化量2.43
# 能源19支, 热度变化幅度-1.22%, 变化量-1.62, 收益率变化幅度0.9%, 变化量1.19
# 消费26支, 热度变化幅度-2.82%, 变化量-3.78, 收益率变化幅度0.74%, 变化量0.99
# 电子45支, 热度变化幅度-27.0%, 变化量-38.0, 收益率变化幅度0.71%, 变化量1.0
# 环保17支, 热度变化幅度1.33%, 变化量1.66, 收益率变化幅度0.53%, 变化量0.66
# 金融26支, 热度变化幅度0.0%, 变化量0.0, 收益率变化幅度0.12%, 变化量0.13
# 农业16支, 热度变化幅度-1.8%, 变化量-2.31, 收益率变化幅度0.09%, 变化量0.12
# 医药41支, 热度变化幅度-5.81%, 变化量-7.84, 收益率变化幅度-0.48%, 变化量-0.65
# 基建29支, 热度变化幅度-5.49%, 变化量-7.24, 收益率变化幅度-0.54%, 变化量-0.71
# 最近一周热门行业监测：2023-03-17至2023-03-24
# 电子45支, 热度变化幅度-27.0%, 变化量-38.0, 收益率变化幅度0.71%, 变化量1.0
# 医药41支, 热度变化幅度-5.81%, 变化量-7.84, 收益率变化幅度-0.48%, 变化量-0.65
# 基建29支, 热度变化幅度-5.49%, 变化量-7.24, 收益率变化幅度-0.54%, 变化量-0.71
# 科技33支, 热度变化幅度-3.9%, 变化量-5.41, 收益率变化幅度3.07%, 变化量4.25
# 消费26支, 热度变化幅度-2.82%, 变化量-3.78, 收益率变化幅度0.74%, 变化量0.99
# 农业16支, 热度变化幅度-1.8%, 变化量-2.31, 收益率变化幅度0.09%, 变化量0.12
# 投资77支, 热度变化幅度-1.51%, 变化量-2.15, 收益率变化幅度1.7%, 变化量2.43
# 制造88支, 热度变化幅度1.47%, 变化量1.9, 收益率变化幅度2.06%, 变化量2.66
# 环保17支, 热度变化幅度1.33%, 变化量1.66, 收益率变化幅度0.53%, 变化量0.66
# 能源19支, 热度变化幅度-1.22%, 变化量-1.62, 收益率变化幅度0.9%, 变化量1.19
# 新能源38支, 热度变化幅度0.82%, 变化量1.05, 收益率变化幅度2.26%, 变化量2.89
# 金融26支, 热度变化幅度0.0%, 变化量0.0, 收益率变化幅度0.12%, 变化量0.13
# 下一周监测：2023-03-24至2023-03-31
# 农业16支, 热度变化幅度2.03%, 变化量2.6, 收益率变化幅度1.1%, 变化量1.41
# 医药41支, 热度变化幅度-2.58%, 变化量-3.47, 收益率变化幅度0.56%, 变化量0.76
# 消费26支, 热度变化幅度-1.78%, 变化量-2.4, 收益率变化幅度0.39%, 变化量0.52
# 电子45支, 热度变化幅度-0.05%, 变化量-0.07, 收益率变化幅度0.11%, 变化量0.16
# 新能源38支, 热度变化幅度-2.52%, 变化量-3.3, 收益率变化幅度0.03%, 变化量0.04
# 能源19支, 热度变化幅度1.47%, 变化量1.96, 收益率变化幅度-0.09%, 变化量-0.12
# 金融26支, 热度变化幅度-0.11%, 变化量-0.12, 收益率变化幅度-0.21%, 变化量-0.23
# 制造88支, 热度变化幅度-7.12%, 变化量-9.38, 收益率变化幅度-0.51%, 变化量-0.68
# 环保17支, 热度变化幅度0.09%, 变化量0.11, 收益率变化幅度-0.82%, 变化量-1.02
# 投资77支, 热度变化幅度-3.79%, 变化量-5.5, 收益率变化幅度-0.95%, 变化量-1.38
# 基建29支, 热度变化幅度-11.29%, 变化量-14.8, 收益率变化幅度-0.95%, 变化量-1.25
# 科技33支, 热度变化幅度-13.58%, 变化量-19.41, 收益率变化幅度-1.76%, 变化量-2.51
# 最近一周热门行业监测：2023-03-24至2023-03-31
# 基建29支, 热度变化幅度-11.29%, 变化量-14.8, 收益率变化幅度-0.95%, 变化量-1.25
# 科技31支, 热度变化幅度-7.75%, 变化量-10.97, 收益率变化幅度-1.31%, 变化量-1.86
# 制造88支, 热度变化幅度-7.12%, 变化量-9.38, 收益率变化幅度-0.51%, 变化量-0.68
# 投资77支, 热度变化幅度-3.79%, 变化量-5.5, 收益率变化幅度-0.95%, 变化量-1.38
# 医药41支, 热度变化幅度-2.58%, 变化量-3.47, 收益率变化幅度0.56%, 变化量0.76
# 新能源39支, 热度变化幅度-2.5%, 变化量-3.26, 收益率变化幅度0.04%, 变化量0.05
# 农业16支, 热度变化幅度2.03%, 变化量2.6, 收益率变化幅度1.1%, 变化量1.41
# 消费26支, 热度变化幅度-1.78%, 变化量-2.4, 收益率变化幅度0.39%, 变化量0.52
# 能源19支, 热度变化幅度1.47%, 变化量1.96, 收益率变化幅度-0.09%, 变化量-0.12
# 环保18支, 热度变化幅度-1.35%, 变化量-1.68, 收益率变化幅度-0.81%, 变化量-1.01
# 金融26支, 热度变化幅度-0.11%, 变化量-0.12, 收益率变化幅度-0.21%, 变化量-0.23
# 电子45支, 热度变化幅度-0.05%, 变化量-0.07, 收益率变化幅度0.11%, 变化量0.16
# 下一周监测：2023-03-31至2023-04-07
# 电子45支, 热度变化幅度-6.77%, 变化量-9.6, 收益率变化幅度2.83%, 变化量4.02
# 基建29支, 热度变化幅度-4.48%, 变化量-5.82, 收益率变化幅度1.57%, 变化量2.04
# 农业16支, 热度变化幅度3.54%, 变化量4.59, 收益率变化幅度1.51%, 变化量1.95
# 医药41支, 热度变化幅度0.02%, 变化量0.03, 收益率变化幅度1.5%, 变化量2.02
# 科技31支, 热度变化幅度-7.86%, 变化量-10.98, 收益率变化幅度1.29%, 变化量1.8
# 能源19支, 热度变化幅度-1.25%, 变化量-1.68, 收益率变化幅度1.0%, 变化量1.33
# 金融26支, 热度变化幅度0.13%, 变化量0.15, 收益率变化幅度0.9%, 变化量1.0
# 环保18支, 热度变化幅度2.21%, 变化量2.73, 收益率变化幅度0.84%, 变化量1.04
# 制造88支, 热度变化幅度1.11%, 变化量1.46, 收益率变化幅度0.8%, 变化量1.05
# 消费26支, 热度变化幅度-0.74%, 变化量-1.0, 收益率变化幅度0.41%, 变化量0.56
# 新能源39支, 热度变化幅度-1.91%, 变化量-2.5, 收益率变化幅度0.33%, 变化量0.43
# 投资77支, 热度变化幅度-1.01%, 变化量-1.45, 收益率变化幅度0.15%, 变化量0.22
# 最近一周热门行业监测：2023-03-31至2023-04-07
# 科技31支, 热度变化幅度-7.86%, 变化量-10.98, 收益率变化幅度1.29%, 变化量1.8
# 电子45支, 热度变化幅度-6.77%, 变化量-9.6, 收益率变化幅度2.83%, 变化量4.02
# 基建30支, 热度变化幅度-5.13%, 变化量-6.68, 收益率变化幅度1.71%, 变化量2.23
# 农业16支, 热度变化幅度3.54%, 变化量4.59, 收益率变化幅度1.51%, 变化量1.95
# 环保18支, 热度变化幅度2.21%, 变化量2.73, 收益率变化幅度0.84%, 变化量1.04
# 新能源39支, 热度变化幅度-1.91%, 变化量-2.5, 收益率变化幅度0.33%, 变化量0.43
# 能源19支, 热度变化幅度-1.25%, 变化量-1.68, 收益率变化幅度1.0%, 变化量1.33
# 消费27支, 热度变化幅度-1.12%, 变化量-1.52, 收益率变化幅度0.54%, 变化量0.74
# 制造89支, 热度变化幅度1.1%, 变化量1.45, 收益率变化幅度0.87%, 变化量1.14
# 投资77支, 热度变化幅度-1.01%, 变化量-1.45, 收益率变化幅度0.15%, 变化量0.22
# 金融26支, 热度变化幅度0.13%, 变化量0.15, 收益率变化幅度0.9%, 变化量1.0
# 医药42支, 热度变化幅度-0.03%, 变化量-0.04, 收益率变化幅度1.51%, 变化量2.03
# 下一周监测：2023-04-07至2023-04-14
# 基建30支, 热度变化幅度-0.47%, 变化量-0.63, 收益率变化幅度0.75%, 变化量0.99
# 金融26支, 热度变化幅度-0.03%, 变化量-0.03, 收益率变化幅度0.23%, 变化量0.26
# 能源19支, 热度变化幅度0.36%, 变化量0.49, 收益率变化幅度0.1%, 变化量0.14
# 制造89支, 热度变化幅度0.73%, 变化量0.97, 收益率变化幅度-0.46%, 变化量-0.61
# 医药42支, 热度变化幅度-6.36%, 变化量-8.7, 收益率变化幅度-0.64%, 变化量-0.87
# 新能源39支, 热度变化幅度1.33%, 变化量1.74, 收益率变化幅度-0.69%, 变化量-0.9
# 环保18支, 热度变化幅度-3.97%, 变化量-4.94, 收益率变化幅度-0.77%, 变化量-0.95
# 投资77支, 热度变化幅度4.38%, 变化量6.31, 收益率变化幅度-1.21%, 变化量-1.75
# 科技31支, 热度变化幅度2.27%, 变化量3.21, 收益率变化幅度-1.27%, 变化量-1.8
# 消费27支, 热度变化幅度-3.47%, 变化量-4.73, 收益率变化幅度-1.34%, 变化量-1.83
# 农业16支, 热度变化幅度0.54%, 变化量0.71, 收益率变化幅度-1.45%, 变化量-1.9
# 电子45支, 热度变化幅度-7.47%, 变化量-10.91, 收益率变化幅度-1.46%, 变化量-2.13
# 最近一周热门行业监测：2023-04-07至2023-04-14
# 电子45支, 热度变化幅度-7.47%, 变化量-10.91, 收益率变化幅度-1.46%, 变化量-2.13
# 医药42支, 热度变化幅度-6.36%, 变化量-8.7, 收益率变化幅度-0.64%, 变化量-0.87
# 投资77支, 热度变化幅度4.38%, 变化量6.31, 收益率变化幅度-1.21%, 变化量-1.75
# 环保18支, 热度变化幅度-3.97%, 变化量-4.94, 收益率变化幅度-0.77%, 变化量-0.95
# 消费28支, 热度变化幅度-3.35%, 变化量-4.57, 收益率变化幅度-1.54%, 变化量-2.1
# 科技30支, 热度变化幅度3.03%, 变化量4.28, 收益率变化幅度-1.07%, 变化量-1.52
# 新能源39支, 热度变化幅度1.33%, 变化量1.74, 收益率变化幅度-0.69%, 变化量-0.9
# 农业16支, 热度变化幅度0.54%, 变化量0.71, 收益率变化幅度-1.45%, 变化量-1.9
# 基建30支, 热度变化幅度-0.47%, 变化量-0.63, 收益率变化幅度0.75%, 变化量0.99
# 制造89支, 热度变化幅度0.42%, 变化量0.56, 收益率变化幅度-0.44%, 变化量-0.59
# 能源19支, 热度变化幅度0.36%, 变化量0.49, 收益率变化幅度0.1%, 变化量0.14
# 金融26支, 热度变化幅度-0.03%, 变化量-0.03, 收益率变化幅度0.23%, 变化量0.26
# 下一周监测：2023-04-14至2023-04-21
# 金融26支, 热度变化幅度0.3%, 变化量0.34, 收益率变化幅度0.03%, 变化量0.03
# 能源19支, 热度变化幅度0.92%, 变化量1.25, 收益率变化幅度-1.39%, 变化量-1.88
# 基建30支, 热度变化幅度-0.09%, 变化量-0.12, 收益率变化幅度-1.81%, 变化量-2.41
# 消费28支, 热度变化幅度2.58%, 变化量3.46, 收益率变化幅度-1.9%, 变化量-2.55
# 环保18支, 热度变化幅度1.03%, 变化量1.27, 收益率变化幅度-2.34%, 变化量-2.89
# 制造89支, 热度变化幅度3.32%, 变化量4.39, 收益率变化幅度-2.37%, 变化量-3.13
# 投资77支, 热度变化幅度1.91%, 变化量2.72, 收益率变化幅度-2.5%, 变化量-3.56
# 医药42支, 热度变化幅度4.32%, 变化量5.88, 收益率变化幅度-2.62%, 变化量-3.56
# 农业16支, 热度变化幅度-3.73%, 变化量-4.84, 收益率变化幅度-2.65%, 变化量-3.44
# 电子45支, 热度变化幅度6.5%, 变化量9.35, 收益率变化幅度-3.11%, 变化量-4.47
# 新能源39支, 热度变化幅度0.42%, 变化量0.55, 收益率变化幅度-3.38%, 变化量-4.39
# 科技30支, 热度变化幅度1.14%, 变化量1.6, 收益率变化幅度-4.3%, 变化量-6.01
# 最近一周热门行业监测：2023-04-14至2023-04-21
# 电子45支, 热度变化幅度6.5%, 变化量9.35, 收益率变化幅度-3.11%, 变化量-4.47
# 医药42支, 热度变化幅度4.32%, 变化量5.88, 收益率变化幅度-2.62%, 变化量-3.56
# 农业16支, 热度变化幅度-3.73%, 变化量-4.84, 收益率变化幅度-2.65%, 变化量-3.44
# 制造89支, 热度变化幅度3.32%, 变化量4.39, 收益率变化幅度-2.37%, 变化量-3.13
# 消费28支, 热度变化幅度2.58%, 变化量3.46, 收益率变化幅度-1.9%, 变化量-2.55
# 投资78支, 热度变化幅度1.83%, 变化量2.61, 收益率变化幅度-2.48%, 变化量-3.53
# 科技30支, 热度变化幅度1.14%, 变化量1.6, 收益率变化幅度-4.3%, 变化量-6.01
# 环保18支, 热度变化幅度1.03%, 变化量1.27, 收益率变化幅度-2.34%, 变化量-2.89
# 能源19支, 热度变化幅度0.92%, 变化量1.25, 收益率变化幅度-1.39%, 变化量-1.88
# 新能源39支, 热度变化幅度0.42%, 变化量0.55, 收益率变化幅度-3.38%, 变化量-4.39
# 金融26支, 热度变化幅度0.3%, 变化量0.34, 收益率变化幅度0.03%, 变化量0.03
# 基建30支, 热度变化幅度-0.09%, 变化量-0.12, 收益率变化幅度-1.81%, 变化量-2.41
# 下一周监测：2023-04-21至2023-04-28
# 基建30支, 热度变化幅度-2.16%, 变化量-2.84, 收益率变化幅度2.22%, 变化量2.92
# 环保18支, 热度变化幅度6.57%, 变化量7.93, 收益率变化幅度1.69%, 变化量2.04
# 科技30支, 热度变化幅度17.26%, 变化量23.08, 收益率变化幅度1.2%, 变化量1.6
# 医药42支, 热度变化幅度15.45%, 变化量20.46, 收益率变化幅度1.18%, 变化量1.56
# 金融26支, 热度变化幅度0.07%, 变化量0.08, 收益率变化幅度1.15%, 变化量1.28
# 新能源39支, 热度变化幅度6.11%, 变化量7.68, 收益率变化幅度0.79%, 变化量0.99
# 能源19支, 热度变化幅度-0.92%, 变化量-1.23, 收益率变化幅度0.6%, 变化量0.8
# 消费28支, 热度变化幅度1.91%, 变化量2.51, 收益率变化幅度0.6%, 变化量0.79
# 制造89支, 热度变化幅度-1.4%, 变化量-1.8, 收益率变化幅度0.25%, 变化量0.33
# 农业16支, 热度变化幅度-0.75%, 变化量-0.95, 收益率变化幅度0.19%, 变化量0.24
# 投资78支, 热度变化幅度1.94%, 变化量2.69, 收益率变化幅度-0.81%, 变化量-1.12
# 电子45支, 热度变化幅度-0.1%, 变化量-0.13, 收益率变化幅度-1.47%, 变化量-2.04
# 最近一周热门行业监测：2023-04-21至2023-04-28
# 医药42支, 热度变化幅度15.45%, 变化量20.46, 收益率变化幅度1.18%, 变化量1.56
# 科技31支, 热度变化幅度13.65%, 变化量18.41, 收益率变化幅度1.18%, 变化量1.59
# 环保18支, 热度变化幅度6.57%, 变化量7.93, 收益率变化幅度1.69%, 变化量2.04
# 新能源39支, 热度变化幅度6.11%, 变化量7.68, 收益率变化幅度0.79%, 变化量0.99
# 基建30支, 热度变化幅度-2.16%, 变化量-2.84, 收益率变化幅度2.22%, 变化量2.92
# 投资77支, 热度变化幅度1.94%, 变化量2.69, 收益率变化幅度-0.77%, 变化量-1.07
# 消费28支, 热度变化幅度1.91%, 变化量2.51, 收益率变化幅度0.6%, 变化量0.79
# 制造89支, 热度变化幅度-1.4%, 变化量-1.8, 收益率变化幅度0.25%, 变化量0.33
# 能源20支, 热度变化幅度-0.97%, 变化量-1.28, 收益率变化幅度0.51%, 变化量0.68
# 电子47支, 热度变化幅度-0.76%, 变化量-1.06, 收益率变化幅度-1.55%, 变化量-2.16
# 农业16支, 热度变化幅度-0.75%, 变化量-0.95, 收益率变化幅度0.19%, 变化量0.24
# 金融26支, 热度变化幅度0.07%, 变化量0.08, 收益率变化幅度1.15%, 变化量1.28
# 下一周监测：2023-04-28至2023-05-05
# 金融26支, 热度变化幅度0.53%, 变化量0.6, 收益率变化幅度0.47%, 变化量0.54
# 基建30支, 热度变化幅度19.56%, 变化量26.23, 收益率变化幅度0.34%, 变化量0.46
# 能源20支, 热度变化幅度1.64%, 变化量2.18, 收益率变化幅度-0.36%, 变化量-0.47
# 环保18支, 热度变化幅度-5.67%, 变化量-6.96, 收益率变化幅度-0.88%, 变化量-1.08
# 消费28支, 热度变化幅度-1.54%, 变化量-2.04, 收益率变化幅度-1.21%, 变化量-1.6
# 科技31支, 热度变化幅度-6.83%, 变化量-9.32, 收益率变化幅度-1.28%, 变化量-1.75
# 农业16支, 热度变化幅度-0.86%, 变化量-1.09, 收益率变化幅度-1.36%, 变化量-1.72
# 新能源39支, 热度变化幅度-5.36%, 变化量-6.8, 收益率变化幅度-1.54%, 变化量-1.95
# 制造89支, 热度变化幅度-1.6%, 变化量-2.07, 收益率变化幅度-1.57%, 变化量-2.03
# 医药42支, 热度变化幅度-13.46%, 变化量-18.04, 收益率变化幅度-1.76%, 变化量-2.36
# 投资77支, 热度变化幅度-7.04%, 变化量-9.68, 收益率变化幅度-1.91%, 变化量-2.63
# 电子47支, 热度变化幅度-11.78%, 变化量-16.12, 收益率变化幅度-2.2%, 变化量-3.01
# 最近一周热门行业监测：2023-04-28至2023-05-05
# 基建32支, 热度变化幅度18.27%, 变化量24.32, 收益率变化幅度0.24%, 变化量0.32
# 医药42支, 热度变化幅度-13.46%, 变化量-18.04, 收益率变化幅度-1.76%, 变化量-2.36
# 电子48支, 热度变化幅度-11.59%, 变化量-15.84, 收益率变化幅度-2.22%, 变化量-3.03
# 投资78支, 热度变化幅度-6.98%, 变化量-9.58, 收益率变化幅度-1.91%, 变化量-2.62
# 科技32支, 热度变化幅度-6.47%, 变化量-8.82, 收益率变化幅度-1.15%, 变化量-1.57
# 环保18支, 热度变化幅度-5.67%, 变化量-6.96, 收益率变化幅度-0.88%, 变化量-1.08
# 新能源38支, 热度变化幅度-4.03%, 变化量-5.08, 收益率变化幅度-1.46%, 变化量-1.84
# 能源20支, 热度变化幅度1.64%, 变化量2.18, 收益率变化幅度-0.36%, 变化量-0.47
# 制造91支, 热度变化幅度-1.62%, 变化量-2.09, 收益率变化幅度-1.57%, 变化量-2.02
# 农业16支, 热度变化幅度-0.86%, 变化量-1.09, 收益率变化幅度-1.36%, 变化量-1.72
# 消费27支, 热度变化幅度-0.83%, 变化量-1.06, 收益率变化幅度-1.05%, 变化量-1.34
# 金融26支, 热度变化幅度0.53%, 变化量0.6, 收益率变化幅度0.47%, 变化量0.54
# 下一周监测：2023-05-05至2023-05-12
# 农业16支, 热度变化幅度1.15%, 变化量1.44, 收益率变化幅度-0.35%, 变化量-0.43
# 金融26支, 热度变化幅度1.96%, 变化量2.22, 收益率变化幅度-0.42%, 变化量-0.47
# 环保18支, 热度变化幅度7.01%, 变化量8.53, 收益率变化幅度-0.6%, 变化量-0.72
# 新能源38支, 热度变化幅度1.09%, 变化量1.35, 收益率变化幅度-0.83%, 变化量-1.04
# 消费27支, 热度变化幅度-2.82%, 变化量-3.57, 收益率变化幅度-1.19%, 变化量-1.51
# 能源20支, 热度变化幅度-1.99%, 变化量-2.64, 收益率变化幅度-1.22%, 变化量-1.62
# 制造91支, 热度变化幅度0.1%, 变化量0.12, 收益率变化幅度-1.62%, 变化量-2.05
# 投资78支, 热度变化幅度1.11%, 变化量1.5, 收益率变化幅度-1.83%, 变化量-2.47
# 电子48支, 热度变化幅度1.57%, 变化量2.1, 收益率变化幅度-2.19%, 变化量-2.93
# 医药42支, 热度变化幅度4.62%, 变化量6.08, 收益率变化幅度-2.46%, 变化量-3.23
# 基建32支, 热度变化幅度-11.31%, 变化量-15.09, 收益率变化幅度-2.8%, 变化量-3.73
# 科技32支, 热度变化幅度-7.97%, 变化量-10.73, 收益率变化幅度-2.83%, 变化量-3.81
# 最近一周热门行业监测：2023-05-05至2023-05-12
# 基建33支, 热度变化幅度-11.01%, 变化量-14.65, 收益率变化幅度-2.74%, 变化量-3.65
# 科技32支, 热度变化幅度-7.97%, 变化量-10.73, 收益率变化幅度-2.83%, 变化量-3.81
# 环保18支, 热度变化幅度7.01%, 变化量8.53, 收益率变化幅度-0.6%, 变化量-0.72
# 医药42支, 热度变化幅度4.62%, 变化量6.08, 收益率变化幅度-2.46%, 变化量-3.23
# 消费28支, 热度变化幅度-2.99%, 变化量-3.8, 收益率变化幅度-1.11%, 变化量-1.41
# 能源20支, 热度变化幅度-1.99%, 变化量-2.64, 收益率变化幅度-1.22%, 变化量-1.62
# 金融26支, 热度变化幅度1.96%, 变化量2.22, 收益率变化幅度-0.42%, 变化量-0.47
# 电子48支, 热度变化幅度1.57%, 变化量2.1, 收益率变化幅度-2.19%, 变化量-2.93
# 新能源39支, 热度变化幅度1.05%, 变化量1.3, 收益率变化幅度-0.83%, 变化量-1.03
# 投资81支, 热度变化幅度1.04%, 变化量1.39, 收益率变化幅度-1.82%, 变化量-2.44
# 农业17支, 热度变化幅度0.97%, 变化量1.21, 收益率变化幅度-0.44%, 变化量-0.55
# 制造93支, 热度变化幅度0.37%, 变化量0.47, 收益率变化幅度-1.2%, 变化量-1.52
# 下一周监测：2023-05-12至2023-05-19
# 环保18支, 热度变化幅度11.61%, 变化量14.04, 收益率变化幅度3.43%, 变化量4.15
# 电子48支, 热度变化幅度7.32%, 变化量9.57, 收益率变化幅度2.98%, 变化量3.89
# 科技32支, 热度变化幅度-1.62%, 变化量-2.11, 收益率变化幅度2.3%, 变化量3.01
# 制造93支, 热度变化幅度1.35%, 变化量1.69, 收益率变化幅度2.07%, 变化量2.6
# 新能源39支, 热度变化幅度0.52%, 变化量0.64, 收益率变化幅度1.87%, 变化量2.3
# 消费28支, 热度变化幅度-0.54%, 变化量-0.68, 收益率变化幅度1.4%, 变化量1.75
# 投资81支, 热度变化幅度0.29%, 变化量0.39, 收益率变化幅度1.39%, 变化量1.82
# 医药42支, 热度变化幅度-3.74%, 变化量-4.8, 收益率变化幅度1.31%, 变化量1.68
# 农业17支, 热度变化幅度0.75%, 变化量0.92, 收益率变化幅度1.27%, 变化量1.57
# 能源20支, 热度变化幅度0.2%, 变化量0.26, 收益率变化幅度1.1%, 变化量1.44
# 基建33支, 热度变化幅度-3.01%, 变化量-3.9, 收益率变化幅度0.65%, 变化量0.84
# 金融26支, 热度变化幅度-2.42%, 变化量-2.74, 收益率变化幅度0.36%, 变化量0.4
# 最近一周热门行业监测：2023-05-12至2023-05-19
# 环保17支, 热度变化幅度12.21%, 变化量14.82, 收益率变化幅度3.53%, 变化量4.28
# 电子48支, 热度变化幅度7.32%, 变化量9.57, 收益率变化幅度2.98%, 变化量3.89
# 基建32支, 热度变化幅度-6.86%, 变化量-8.86, 收益率变化幅度0.44%, 变化量0.56
# 医药41支, 热度变化幅度-2.65%, 变化量-3.35, 收益率变化幅度1.46%, 变化量1.85
# 金融26支, 热度变化幅度-2.42%, 变化量-2.74, 收益率变化幅度0.36%, 变化量0.4
# 科技32支, 热度变化幅度-1.62%, 变化量-2.11, 收益率变化幅度2.3%, 变化量3.01
# 制造93支, 热度变化幅度1.35%, 变化量1.69, 收益率变化幅度2.07%, 变化量2.6
# 农业17支, 热度变化幅度0.75%, 变化量0.92, 收益率变化幅度1.27%, 变化量1.57
# 消费28支, 热度变化幅度-0.54%, 变化量-0.68, 收益率变化幅度1.4%, 变化量1.75
# 新能源39支, 热度变化幅度0.52%, 变化量0.64, 收益率变化幅度1.87%, 变化量2.3
# 投资81支, 热度变化幅度0.29%, 变化量0.39, 收益率变化幅度1.39%, 变化量1.82
# 能源21支, 热度变化幅度0.11%, 变化量0.15, 收益率变化幅度0.96%, 变化量1.26
# 下一周监测：2023-05-19至2023-05-26
# 能源21支, 热度变化幅度17.24%, 变化量22.85, 收益率变化幅度1.65%, 变化量2.19
# 环保17支, 热度变化幅度-4.5%, 变化量-5.65, 收益率变化幅度1.32%, 变化量1.66
# 医药41支, 热度变化幅度7.0%, 变化量8.97, 收益率变化幅度0.79%, 变化量1.02
# 科技32支, 热度变化幅度-6.07%, 变化量-8.13, 收益率变化幅度0.4%, 变化量0.53
# 制造93支, 热度变化幅度-1.7%, 变化量-2.18, 收益率变化幅度0.07%, 变化量0.1
# 消费28支, 热度变化幅度0.0%, 变化量0.0, 收益率变化幅度0.05%, 变化量0.06
# 农业17支, 热度变化幅度-0.91%, 变化量-1.14, 收益率变化幅度0.02%, 变化量0.02
# 电子48支, 热度变化幅度-5.77%, 变化量-7.77, 收益率变化幅度-0.14%, 变化量-0.19
# 新能源39支, 热度变化幅度-0.17%, 变化量-0.21, 收益率变化幅度-0.26%, 变化量-0.33
# 投资81支, 热度变化幅度-3.58%, 变化量-4.78, 收益率变化幅度-0.9%, 变化量-1.2
# 金融26支, 热度变化幅度-0.27%, 变化量-0.31, 收益率变化幅度-0.95%, 变化量-1.08
# 基建32支, 热度变化幅度0.82%, 变化量1.06, 收益率变化幅度-1.15%, 变化量-1.49
# 最近一周热门行业监测：2023-05-19至2023-05-26
# 能源21支, 热度变化幅度17.24%, 变化量22.85, 收益率变化幅度1.65%, 变化量2.19
# 医药41支, 热度变化幅度7.0%, 变化量8.97, 收益率变化幅度0.79%, 变化量1.02
# 科技32支, 热度变化幅度-6.07%, 变化量-8.13, 收益率变化幅度0.4%, 变化量0.53
# 电子50支, 热度变化幅度-5.61%, 变化量-7.53, 收益率变化幅度-0.09%, 变化量-0.12
# 环保17支, 热度变化幅度-4.5%, 变化量-5.65, 收益率变化幅度1.32%, 变化量1.66
# 投资81支, 热度变化幅度-3.75%, 变化量-5.01, 收益率变化幅度-0.88%, 变化量-1.18
# 制造93支, 热度变化幅度-1.7%, 变化量-2.18, 收益率变化幅度0.07%, 变化量0.1
# 农业17支, 热度变化幅度-0.91%, 变化量-1.14, 收益率变化幅度0.02%, 变化量0.02
# 基建32支, 热度变化幅度0.82%, 变化量1.06, 收益率变化幅度-1.15%, 变化量-1.49
# 消费29支, 热度变化幅度-0.82%, 变化量-1.05, 收益率变化幅度-0.06%, 变化量-0.07
# 金融26支, 热度变化幅度-0.27%, 变化量-0.31, 收益率变化幅度-0.95%, 变化量-1.08
# 新能源39支, 热度变化幅度-0.17%, 变化量-0.21, 收益率变化幅度-0.26%, 变化量-0.33
# 下一周监测：2023-05-26至2023-06-02
# 科技32支, 热度变化幅度29.23%, 变化量39.3, 收益率变化幅度5.24%, 变化量7.04
# 基建32支, 热度变化幅度-0.7%, 变化量-0.89, 收益率变化幅度2.39%, 变化量3.07
# 电子50支, 热度变化幅度1.88%, 变化量2.52, 收益率变化幅度2.03%, 变化量2.72
# 投资81支, 热度变化幅度2.38%, 变化量3.15, 收益率变化幅度1.54%, 变化量2.04
# 能源21支, 热度变化幅度-5.2%, 变化量-7.01, 收益率变化幅度1.31%, 变化量1.76
# 环保17支, 热度变化幅度-9.05%, 变化量-11.52, 收益率变化幅度1.29%, 变化量1.65
# 制造93支, 热度变化幅度-3.29%, 变化量-4.22, 收益率变化幅度1.29%, 变化量1.66
# 消费29支, 热度变化幅度0.01%, 变化量0.01, 收益率变化幅度0.82%, 变化量1.05
# 农业17支, 热度变化幅度-1.46%, 变化量-1.83, 收益率变化幅度0.57%, 变化量0.72
# 金融26支, 热度变化幅度-0.15%, 变化量-0.17, 收益率变化幅度0.45%, 变化量0.5
# 新能源39支, 热度变化幅度-0.27%, 变化量-0.34, 收益率变化幅度0.18%, 变化量0.22
# 医药41支, 热度变化幅度-12.13%, 变化量-15.68, 收益率变化幅度0.01%, 变化量0.01
# 最近一周热门行业监测：2023-05-26至2023-06-02
# 科技33支, 热度变化幅度27.92%, 变化量37.54, 收益率变化幅度5.31%, 变化量7.14
# 环保17支, 热度变化幅度-9.05%, 变化量-11.52, 收益率变化幅度1.29%, 变化量1.65
# 能源21支, 热度变化幅度-5.2%, 变化量-7.01, 收益率变化幅度1.31%, 变化量1.76
# 制造93支, 热度变化幅度-3.3%, 变化量-4.23, 收益率变化幅度1.31%, 变化量1.68
# 医药40支, 热度变化幅度-3.16%, 变化量-4.02, 收益率变化幅度0.14%, 变化量0.18
# 投资81支, 热度变化幅度2.38%, 变化量3.15, 收益率变化幅度1.54%, 变化量2.04
# 电子50支, 热度变化幅度1.88%, 变化量2.52, 收益率变化幅度2.03%, 变化量2.72
# 农业17支, 热度变化幅度-1.46%, 变化量-1.83, 收益率变化幅度0.57%, 变化量0.72
# 基建32支, 热度变化幅度-0.7%, 变化量-0.89, 收益率变化幅度2.39%, 变化量3.07
# 新能源40支, 热度变化幅度-0.32%, 变化量-0.4, 收益率变化幅度0.11%, 变化量0.14
# 金融26支, 热度变化幅度-0.15%, 变化量-0.17, 收益率变化幅度0.45%, 变化量0.5
# 消费29支, 热度变化幅度0.01%, 变化量0.01, 收益率变化幅度0.82%, 变化量1.05
# 下一周监测：2023-06-02至2023-06-09
# 科技33支, 热度变化幅度18.72%, 变化量26.51, 收益率变化幅度1.35%, 变化量1.91
# 环保17支, 热度变化幅度-0.29%, 变化量-0.37, 收益率变化幅度1.31%, 变化量1.69
# 基建32支, 热度变化幅度8.09%, 变化量10.63, 收益率变化幅度0.75%, 变化量0.99
# 农业17支, 热度变化幅度5.16%, 变化量6.5, 收益率变化幅度0.55%, 变化量0.69
# 金融26支, 热度变化幅度-0.06%, 变化量-0.07, 收益率变化幅度0.14%, 变化量0.16
# 投资81支, 热度变化幅度3.58%, 变化量4.81, 收益率变化幅度-0.18%, 变化量-0.24
# 能源21支, 热度变化幅度-5.41%, 变化量-7.39, 收益率变化幅度-0.29%, 变化量-0.39
# 医药40支, 热度变化幅度3.02%, 变化量3.85, 收益率变化幅度-0.29%, 变化量-0.37
# 制造93支, 热度变化幅度5.94%, 变化量7.71, 收益率变化幅度-0.61%, 变化量-0.8
# 消费29支, 热度变化幅度0.49%, 变化量0.64, 收益率变化幅度-1.1%, 变化量-1.43
# 电子50支, 热度变化幅度-5.19%, 变化量-7.09, 收益率变化幅度-1.29%, 变化量-1.76
# 新能源40支, 热度变化幅度-1.71%, 变化量-2.13, 收益率变化幅度-1.44%, 变化量-1.79
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 77
#      74 lwh = []
#      75 for cd in select:
# ---> 77     if DTBS['B'][cd][ctnm] == cat:
#      78         twp.append(DTBS['A'][cd][days[i]]['dp'])
#      80         wks = []
#
# KeyError: 'yqq'

# %%
DTBS['D']['fri']

#poly1d([-0.01660211,  0.39120567, -1.6725735 ,  9.71142054])

# %%
cat1all = []

for cd in DTBS['A'].keys():
    cat1all.append(DTBS['B'][cd]['yqq'])

cat1all = list(set(cat1all))
cat1all

# %%
cats = ['消费',
 '环保',
 '农业',
 '新能源',
 '电子',
 '能源',
 '医药',
 '投资',
 '金融',
 '科技',
 '制造',
 '基建']
a = 0
for i in cats:
    count = 0
    for cd in DTBS['A'].keys():
        if DTBS['A'][cd]['2023-05-19']['ia'] and DTBS['B'][cd]['yqq'] == i:
            count += 1
            a += 1
            
    print(i + '行业共有' + str(count) + '支.')
print(a)

# %%
for i in cat2all:
    count = 0
    for cd in DTBS['A'].keys():
        if DTBS['A'][cd]['2023-05-19']['ia'] and DTBS['B'][cd]['cat2'] == i:
            count += 1
            
    print(i[:-6] + '行业共有' + str(count) + '支.')

# %%
xp = np.linspace(1,20,2000)
yp = [p(i) for i in xp]
plt.plot(xp,yp)

# %%
DTBS['A']['110068.SH']['2023-06-26']

# %%
DTBS['B']['110068.SH']

# %%
DTBS['D']['day'][2:1213]

# %%
DTBS['D']['mon'][200:]

# %%
DTBS['D']['mon'].append('2023-07-03')

# %%
DTBS['G']['600985.SH']
